# %%
import matplotlib.pyplot as plt
#%matplotlib inline
from PIL import Image # Install Pillow -> conda install anaconda::pillow or pip install pillow
import os
from skimage.io import  imread, imshow # Install scikit-image -> conda install scikit-image or pip install scikit-image
import torch
from torchvision import datasets, transforms
from torch.utils.data import Dataset, DataLoader, Subset
from sklearn.metrics import confusion_matrix, balanced_accuracy_score,  mean_squared_error, r2_score, f1_score
from sklearn.model_selection import KFold, train_test_split
import numpy as np

#import torch
import torch.nn as nn
import torch.optim as optim
from torch.functional import F
from torch.nn import Dropout

import warnings
warnings.filterwarnings("ignore")

# %%
# Check if the code is running on Google Colab
try:
    import google.colab
    IN_COLAB = True
except ImportError:
    IN_COLAB = False

if IN_COLAB:
    # Mount Google Drive
    from google.colab import drive
    drive.mount('/content/drive')

    train_dataset_path = '/content/drive/MyDrive/Nicoli/data-students/TRAIN'
    test_dataset_path = '/content/drive/MyDrive/Nicoli/data-students/TEST'
else:
    # Load data from local file
    train_dataset_path = 'data-students/TRAIN'
    test_dataset_path = 'data-students/TEST'

# Now you can use file_path to load your data
#print("File path:", file_path)

#FIXED VARIABLES
IMG_WIDTH = 75
IMG_HEIGHT = 75
BATCH_SIZE = 32

#testing variables
seed = 42

# %%
#!pip install rembg
from rembg import remove
import io

def remove_background_pil(image):
    # Convert PIL image to bytes
    with io.BytesIO() as output_buffer:
        image.save(output_buffer, format='PNG')
        image_bytes = output_buffer.getvalue()

    # Use rembg to remove the background
    result = remove(image_bytes)

    # Convert the result binary data back to a PIL image
    result_image = Image.open(io.BytesIO(result))

    # Fill transparent pixels with black
    result_image = fill_transparent_pixels_with_black(result_image)

    # Convert the image to RGB mode if it's not already
    if result_image.mode != 'RGB':
        result_image = result_image.convert('RGB')

    return result_image

def fill_transparent_pixels_with_black(image):
    # Convert image to RGBA mode if it's not already
    if image.mode != 'RGBA':
        image = image.convert('RGBA')

    # Get the image data as a pixel access object
    pixel_data = image.load()

    # Iterate over each pixel
    width, height = image.size
    for x in range(width):
        for y in range(height):
            # Check if the pixel is transparent
            if pixel_data[x, y][3] == 0:
                # Set the pixel color to black (RGB: 0, 0, 0, Alpha: 255)
                pixel_data[x, y] = (0, 0, 0, 255)

    return image

# %%
from torchvision.transforms import v2

# Define your custom transformation function
augmentation = transforms.Compose([v2.RandomAffine(degrees=(-20, 20), translate=(0.1, 0.2), scale=(0.5, 0.9))])

def removeBackground(image):
    # Apply your custom background removal function
    processed_image = remove_background_pil(image) # remove_background(removal_model, image)

    # Apply other transformations if needed
    transform = transforms.Compose([
        transforms.Resize((IMG_WIDTH, IMG_HEIGHT)),
        transforms.ToTensor(),
        #transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
    ])

    return transform(processed_image)

def Augment(image):
    # Apply your custom background removal function
    transform = transforms.Compose([
        augmentation,
        transforms.Resize((IMG_WIDTH, IMG_HEIGHT)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
    ])

    return transform(image)

def input_transform(image):
    # Apply your custom background removal function
    transform = transforms.Compose([
        augmentation,
        transforms.Resize((IMG_WIDTH, IMG_HEIGHT)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
    ])

    return transform(image)

normal_transform = transforms.Compose([
        transforms.Resize((IMG_WIDTH, IMG_HEIGHT)),
        transforms.ToTensor(),
        #transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ])

# %%
#COMBINE DATASET WITH RANDOMLY AUGMENTED DATASETS

torch.cuda.is_available()
True
from torchvision.transforms import v2
import shutil
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

#background_removed_path = '/content/drive/MyDrive/Nicoli/data-students/TRAIN-NOBG'

background_removed_path = 'data-students/TRAIN-NOBG'

'''
# Assuming you already have your original dataset and transformed dataset
original_dataset = datasets.ImageFolder(root=train_dataset_path, transform=normal_transform)

# Create a DataLoader
dataloader = DataLoader(original_dataset, batch_size=None, shuffle=False)

# Iterate through the DataLoader
for image_path, target in original_dataset.imgs:
    class_name = original_dataset.classes[target]
    class_path = os.path.join(background_removed_path, class_name)
    os.makedirs(class_path, exist_ok=True)

    # Load the image
    image = Image.open(image_path)

    # Apply the transformation
    transformed_image = removeBackground(image)

    # Save the transformed image in the corresponding class folder
    image_filename = os.path.basename(image_path)
    image_save_path = os.path.join(class_path, image_filename)
    transformed_image_pil = transforms.ToPILImage()(transformed_image)
    transformed_image_pil.save(image_save_path)  # Save the transformed image

'''
# Out:
# '\n# Assuming you already have your original dataset and transformed dataset\noriginal_dataset = datasets.ImageFolder(root=train_dataset_path, transform=normal_transform)\n\n# Create a DataLoader\ndataloader = DataLoader(original_dataset, batch_size=None, shuffle=False)\n\n# Iterate through the DataLoader\nfor image_path, target in original_dataset.imgs:\n    class_name = original_dataset.classes[target]\n    class_path = os.path.join(background_removed_path, class_name)\n    os.makedirs(class_path, exist_ok=True)\n\n    # Load the image\n    image = Image.open(image_path)\n\n    # Apply the transformation\n    transformed_image = removeBackground(image)\n\n    # Save the transformed image in the corresponding class folder\n    image_filename = os.path.basename(image_path)\n    image_save_path = os.path.join(class_path, image_filename)\n    transformed_image_pil = transforms.ToPILImage()(transformed_image)\n    transformed_image_pil.save(image_save_path)  # Save the transformed image\n\n'

# %%
from torch.utils.data import ConcatDataset
nobg_dataset = datasets.ImageFolder(root=background_removed_path, transform=normal_transform)


# Define how many times you want to enlarge the dataset
enlarge_factor = 1

# Create a list to hold the datasets
combined_datasets = [nobg_dataset]

# Add the transformed dataset to the list multiple times
for _ in range(enlarge_factor):
    transformed_dataset = datasets.ImageFolder(root=background_removed_path, transform=Augment)
    combined_datasets.append(transformed_dataset)

# Concatenate the datasets into a single dataset
enlarged_dataset = ConcatDataset(combined_datasets)


test_set_size = 0.4
#get train & test for K-MEANS
train_val_dataset, test_dataset = train_test_split(enlarged_dataset, test_size = test_set_size, random_state=seed) #random_state = randomizer seed
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False)

# %%
len(enlarged_dataset)
# Out:
# 1036

# %%
#to print the label (AUXILIAR)
label_str = [
    "12 - Don't Go Left or Right",
    "13 - Don't Go Right",
    "24 - Go Right",
    "37 - Children crossing",
    "38 - Dangerous curve to the right",
    "39 - Dangerous curve to the left",
    "44 - Go left or straight",
    "50 - Fences",
    "6 - Speed limit (70km/h)"
]
label_str_id = [
    "12",
    "13",
    "24",
    "37",
    "38",
    "39",
    "44",
    "50",
    "6"
]

# %%
def voting(trained_models,data_loader,type, modelName):
    #type = 1 -> data loader with no labels (test folder)
    #type = 0 -> data loader with labels

    iter = len(trained_models)
    #save the models
    for i, model in enumerate(trained_models):
        filename = f"model_fold_" + str(i) + "_" + modelName + ".pth"
        torch.save(model, filename)


    if type == 0: #data loader with labels
        #pred matrix
        predictions = []
        for i in range(iter):
            filename = f"model_fold_" + str(i) + "_" + modelName + ".pth"
            torch.save(model, filename)
            model.eval()
            #device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
            model.to(device)
            i = 0
            with torch.no_grad():
                    model_predictions = []

                    for inputs, labels in data_loader:
                        inputs, labels = inputs.to(device), labels.to(device)
                        outputs = model(inputs)
                        _, predicted = outputs.max(1)
                        model_predictions.append(predicted)
                    predictions_aux = torch.cat(model_predictions, dim=0).cpu()
                    predictions.append(predictions_aux)

        predictions_matrix = np.vstack(predictions)

        #voting
        num_classes = predictions_matrix.max() + 1

        class_votes = np.zeros((num_classes, predictions_matrix.shape[1])) #(num_classes, num_predictions)

        for col in range(predictions_matrix.shape[1]):
            unique_classes, class_counts = np.unique(predictions_matrix[:, col], return_counts=True)
            class_votes[unique_classes, col] = class_counts

        most_voted_classes = np.argmax(class_votes, axis=0) #pred

        #labels
        full_dataset = []
        for batch in data_loader:
            inputs, labels = batch
            full_dataset.append((inputs, labels))
            y = torch.cat([labels for _, labels in full_dataset], dim=0) #labels

        # evaluation
        # Compute confusion matrix and F1 score

        conf_mat = confusion_matrix(y, most_voted_classes)
        f1 = f1_score(y, most_voted_classes, average='weighted')
        bal_acc = balanced_accuracy_score(y, most_voted_classes)
        #precision = precision_score(y, most_voted_classes, average='weighted')
        #recall = recall_score(y, most_voted_classes, average='weighted')

        print('Confusion Matrix:\n', conf_mat)
        print('F1 Score: ', f1)
        print('B_acc: ', bal_acc)
        #print('Precision: ', precision)
        #print('Recall: ', recall)

        return y, most_voted_classes

    else: #from test folder - no labels
        predictions = []
        for i in range(iter):
            model = torch.load(f"model_fold_{i}.pth")
            model.eval()
            #device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
            model.to(device)
            i = 0
            with torch.no_grad():
                    model_predictions = []

                    for i, inputs in enumerate(data_loader):
                        inputs = inputs.to(device)
                        outputs = model(inputs)
                        predicted = torch.argmax(outputs, dim=1)
                        model_predictions.append(predicted)
                    predictions_aux = torch.cat(model_predictions, dim=0).cpu()
                    predictions.append(predictions_aux)

        predictions_matrix = np.vstack(predictions)

        #voting
        num_classes = predictions_matrix.max() + 1

        class_votes = np.zeros((num_classes, predictions_matrix.shape[1])) #(num_classes, num_predictions)

        for col in range(predictions_matrix.shape[1]):
            unique_classes, class_counts = np.unique(predictions_matrix[:, col], return_counts=True)
            class_votes[unique_classes, col] = class_counts

        most_voted_classes = np.argmax(class_votes, axis=0) #pred

        return most_voted_classes

# %%
 # PREDICT TEST FOLDER AND CREATE CSV FILE ----------------------------------------------------

def createCSV(model, test_dataset_loader,type, name):
    import csv

    data = []

    #directory where you want to save the CSV file
    try:
        import google.colab
        IN_COLAB = True
    except ImportError:
        IN_COLAB = False

    if IN_COLAB:
        save_dir = '/content/drive/MyDrive/Nicoli'
    else:
        #save_dir = r"C:\Users\Nicoli Leal\Desktop\MEEC\2 semestre\Aprendizagem Computacional Avançada\Project-1"
        save_dir = "/home/stefanotrenti/AML/project"


    #file name
    csv_file = os.path.join(save_dir, name)

    if type == "voting":
      most_voted_classes = voting(model, test_dataset_loader,1)
      for i in range(len(most_voted_classes)):
        predicted_class = int(most_voted_classes[i])  # Extract the integer value
        data.append({"ID": i+1, "Class": label_str_id[predicted_class]}) #, "Name": label_str[test_predictions]})

    else:
      for i, images in enumerate(test_dataset_loader):

          images = images.to(device)
          # Forward pass
          outputs = model(images)
          test_predictions = torch.argmax(outputs, dim=1)

          images = images.cpu().numpy()
          predicted_classes = test_predictions.cpu().numpy()

          # Iterate over the batch
          predicted_class = int(predicted_classes[0])  # Extract the integer value
          data.append({"ID": i+1, "Class": label_str_id[predicted_class]}) #, "Name": label_str[test_predictions]})


    # Define the field names
    fields = ["ID", "Class"]#, "Name"]

    # Write data to CSV file
    with open(csv_file, mode='w', newline='') as file:
        writer = csv.DictWriter(file, fieldnames=fields)

        # Write the header
        writer.writeheader()

        # Write the data rows
        for row in data:
            writer.writerow(row)

    print("CSV file created successfully.")
    return

# %%
# DEFINE EVALUATE FUNCTION
def evaluate_network(model,dataset_loader, to_device=True):
    # X given input data
    # y corresponding target labels
    full_dataset = []
    for batch in dataset_loader:
        # Assuming each batch is a tuple (inputs, labels)
        inputs, labels = batch
        full_dataset.append((inputs, labels))

        # Concatenate all data points into a single tensor
        X = torch.cat([inputs for inputs, _ in full_dataset], dim=0)
        y = torch.cat([labels for _, labels in full_dataset], dim=0)


    # Set the model to evaluation mode
    model.eval()
    if to_device:
      # Assuming you're using GPU (if available)
        #device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        X = X.to(device)
        y = y.to(device)
        #model = model.to(device)

    # Run the model on the test data
    with torch.no_grad():
        outputs = model(X)
        _, predicted = torch.max(outputs.data, 1)

    # Convert tensors to numpy arrays
    if to_device:
        predicted = predicted.to("cpu")

    predicted_np = predicted.cpu().numpy()
    test_target_np = y.cpu().numpy()


    # Compute confusion matrix and F1 score
    conf_mat = confusion_matrix(test_target_np, predicted_np)
    f1 = f1_score(test_target_np, predicted_np, average='weighted')
    bal_acc = balanced_accuracy_score(y.cpu(), predicted_np)

    #print('Confusion Matrix:\n', conf_mat)
    print('F1 Score: ', f1)
    print('B_acc: ', bal_acc)

    return conf_mat, f1, bal_acc

# %%
import os,sys

def saveResults(model, directory, name, modelName, optim, loss):
    # Create the directory if it doesn't exist
    os.makedirs(directory, exist_ok=True)
    
    # Join the directory path with the file name
    results_path = os.path.join(directory, name)
    
    # Check if the file exists
    file_exists = os.path.isfile(results_path)
    
    # Open the file in append mode or write mode depending on whether the file exists
    with open(results_path, 'a' if file_exists else 'w') as f:
        # Redirect stdout to the file
        sys.stdout = f
        print(" ---------------------------------------------------------------------------------------------------------------------- ")
        print(" ----------------------------- Model parameters ------------------------------")
        print("model name:" + modelName)
        print('learning rate  = 0.001')
        print('epochs = 50')
        print('folds = 5')
        print('batch size = 64')
        print('Test set size  = ',test_set_size)
        print("enlarge_factor =", enlarge_factor)
        print('loss = '+ loss)
        print('optimizer = '+ optim)
        print(" ------------------------------- Evaluation  ---------------------------------")
        evaluate_network(model, test_loader)
        print(" ---------------------------------------------------------------------------------------------------------------------- ")
 
    # Reset stdout to its default value (console)
    sys.stdout = sys.__stdout__

# %%
# DEFINE THE FIT FUNCTION

def fit(train_loader, val_loader, model, criterion, optimizer, n_epochs, l2 ,to_device=True):
    #Train the network
    loss_values = []
    balanced_accuracy_values = []
    l2_lambda=l2
    for epoch in range(n_epochs):

        model.train()
        running_loss = 0.0

        for X, y in train_loader:
            # Move data to GPU
            X, y = X.to(device), y.to(device)

            #Forward pass
            y_pred = model(X)

            #if criterion -> MSELoss
            #y_one_hot = F.one_hot(y, num_classes=9).float()
            if isinstance(criterion, nn.MSELoss):
                y_one_hot = F.one_hot(y, num_classes=9).float()
                loss = criterion(y_pred, y_one_hot)
            else:
                loss = criterion(y_pred, y)


            # L2 regularization
            l2_reg = 0
            for param in model.parameters():
                l2_reg += torch.norm(param)**2

            loss += l2_lambda * l2_reg

            running_loss += loss.item()

            #Backward pass and optimization
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

        train_loss = running_loss / len(train_loader)
        train_acc = balanced_accuracy_score(y.tolist(),y_pred.argmax(dim=1).tolist())

        #Validation
        model.eval()
        val_loss = 0.0

        with torch.no_grad():
          for X, y in val_loader:
            X, y = X.to(device), y.to(device)

            y_pred = model(X)
            if isinstance(criterion, nn.MSELoss):
                y_one_hot = F.one_hot(y, num_classes=9).float()
                loss = criterion(y_pred, y_one_hot)
            else:
                loss = criterion(y_pred, y)
            val_loss += loss.item()

        val_loss = val_loss/len(val_loader)
        val_acc = balanced_accuracy_score(y.tolist(),y_pred.argmax(dim=1).tolist())

        print(f'Epoch [{epoch + 1}/{n_epochs}], '
              f'Train Loss: {train_loss:.4f}, Train Acc: {train_acc*100:.2f}%, '
              f'Val Loss: {val_loss:.4f}, Val Acc: {val_acc*100:.2f}%')

    return train_loss, balanced_accuracy_values, model

# %%
def Train_K_FOLDS(k_model, epochs, lr, folds, batch_size, l2, input_size, hidden_size, output_size, optim_type, loss_type):

    kf = KFold(n_splits=folds, shuffle=True, random_state=seed)

    models = []
    index=0
    i = 0
    best_accuracy = 0
    best_model = k_model(input_size, hidden_size, output_size)
    second_best_model = k_model(input_size, hidden_size, output_size)
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    for fold, (train_index, val_index) in enumerate(kf.split(train_val_dataset)):

        model = k_model(input_size, hidden_size, output_size)
        model.to(device)
        second_best_model.to(device)

        #Creating DataLoaders for training and validation
        train_sampler = torch.utils.data.SubsetRandomSampler(train_index)
        val_sampler = torch.utils.data.SubsetRandomSampler(val_index)
        #
        train_loader = DataLoader(train_val_dataset, batch_size=batch_size, sampler=train_sampler)
        val_loader = DataLoader(train_val_dataset, batch_size=batch_size, sampler=val_sampler)

        #CHOOSE LOSS
        if loss_type == 'MSELoss' or loss_type == 'BCELoss':
            criterion = nn.MSELoss()
            
        elif loss_type == 'cross_entropy':
            criterion = nn.CrossEntropyLoss()
        elif loss_type == 'BCELoss':
            criterion = nn.BCELoss()
        else:
            raise ValueError(f"Unsupported loss type: {loss_type}")
            
        #CHOOSE OPTIMIZER
        if optim_type == 'adam':
            optimizer = optim.Adam(model.parameters(), lr=lr)
        elif optim_type == 'SGD':
            optimizer = optim.SGD(model.parameters(), lr=lr)
        elif optim_type == 'RMSprop':
            optimizer = optim.RMSprop(model.parameters(), lr=lr)
        else:
            raise ValueError(f"Unsupported optimizer type: {optim_type}")

        # Train the model
        train_loss, train_acc,  trained_model = fit(train_loader, val_loader, model, criterion, optimizer, epochs, l2, to_device=False)
        #models.append(trained_model)
        conf_matrix, F_score, bal_acc = evaluate_network(trained_model, val_loader)
        if(bal_acc > best_accuracy):
            best_accuracy = bal_acc
            index = i
            if(fold >1):second_best_model = best_model
            best_model = model

        print("Best model has index ", index , "\n")


    models.append(best_model)
    models.append(second_best_model)

    return best_model, models

# %% [markdown]
# #MLP

# %%
class MLP_v1(nn.Module):
    def __init__(self, input_size, hidden_size, output_size, dropout_rate=0.1):
        super(MLP_v1, self).__init__()
        self.lin1 = nn.Linear(input_size, hidden_size)
        self.relu = nn.ReLU()

        self.dropout = Dropout(dropout_rate)
        #hidden
        self.lin2 = nn.Linear(hidden_size, hidden_size)

        self.lin3 = nn.Linear(hidden_size, hidden_size)

        #hidden
        self.lin4 = nn.Linear(hidden_size, output_size)

    def forward(self, x):
        x = x.view(x.size(0), -1)  # Flatten input tensor
        x = self.lin1(x)
        x = self.relu(x)
        x = self.dropout(x)  # Apply dropout
        #hidden
        x = self.lin2(x)
        x = self.relu(x)
        x = self.dropout(x)  # Apply dropout

        x = self.lin3(x)
        x = self.relu(x)
        x = self.dropout(x)  # Apply dropout

        #hidden
        x = self.lin4(x)
        return x
    
    def get_architecture_name(self):
        name = 'MLP_v1'
        return name

# %%
class MLP_v2(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super(MLP_v2, self).__init__()
        self.lin1 = nn.Linear(input_size, hidden_size)
        self.relu = nn.ReLU()

        #hidden
        self.lin2 = nn.Linear(hidden_size, hidden_size)

        self.lin3 = nn.Linear(hidden_size, hidden_size)

        #hidden
        self.lin4 = nn.Linear(hidden_size, output_size)

    def forward(self, x):
        x = x.view(x.size(0), -1)  # Flatten input tensor
        x = self.lin1(x)
        x = self.relu(x)

        #hidden
        x = self.lin2(x)
        x = self.relu(x)

        x = self.lin3(x)
        x = self.relu(x)

        #hidden
        x = self.lin4(x)
        return x
    
    def get_architecture_name(self):
        name = 'MLP_v2'
        return name

# %%
class MLP_v3(nn.Module):
    def __init__(self, input_size, hidden_size, output_size, dropout_rate=0.1):
        super(MLP_v3, self).__init__()
        self.lin1 = nn.Linear(input_size, hidden_size)
        self.relu = nn.ReLU()

        self.dropout = Dropout(dropout_rate)
        #hidden
        self.lin2 = nn.Linear(hidden_size, hidden_size)

        self.lin3 = nn.Linear(hidden_size, hidden_size)

        self.lin4 = nn.Linear(hidden_size, hidden_size)

        self.lin5 = nn.Linear(hidden_size, hidden_size)

        #hidden
        self.lin6 = nn.Linear(hidden_size, output_size)

    def forward(self, x):
        x = x.view(x.size(0), -1)  # Flatten input tensor
        x = self.lin1(x)
        x = self.relu(x)
        x = self.dropout(x)  # Apply dropout
        #hidden
        x = self.lin2(x)
        x = self.relu(x)
        x = self.dropout(x)  # Apply dropout

        x = self.lin3(x)
        x = self.relu(x)
        x = self.dropout(x)  # Apply dropout

        x = self.lin4(x)
        x = self.relu(x)
        x = self.dropout(x)  # Apply dropout

        x = self.lin4(x)
        x = self.relu(x)
        x = self.dropout(x)  # Apply dropout
        #hidden
        x = self.lin6(x)
        return x
    
    def get_architecture_name(self):
        name = 'MLP_v3'
        return name

# %%
class MLP_v4(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super(MLP_v4, self).__init__()
        self.lin1 = nn.Linear(input_size, hidden_size)
        self.relu = nn.ReLU()

        #hidden
        self.lin2 = nn.Linear(hidden_size, hidden_size)

        self.lin3 = nn.Linear(hidden_size, hidden_size)

        self.lin4 = nn.Linear(hidden_size, hidden_size)

        self.lin5 = nn.Linear(hidden_size, hidden_size)

        #hidden
        self.lin6 = nn.Linear(hidden_size, output_size)

    def forward(self, x):
        x = x.view(x.size(0), -1)  # Flatten input tensor
        x = self.lin1(x)
        x = self.relu(x)

        #hidden
        x = self.lin2(x)
        x = self.relu(x)

        x = self.lin3(x)
        x = self.relu(x)

        x = self.lin4(x)
        x = self.relu(x)

        x = self.lin4(x)
        x = self.relu(x)

        #hidden
        x = self.lin6(x)
        return x
    
    def get_architecture_name(self):
        name = 'MLP_v4'
        return name

# %%
class MLP_v4_sig(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super(MLP_v4_sig, self).__init__()
        self.lin1 = nn.Linear(input_size, hidden_size)
        self.sigmoid = nn.Sigmoid()  # Change ReLU to Sigmoid

        # Hidden
        self.lin2 = nn.Linear(hidden_size, hidden_size)

        self.lin3 = nn.Linear(hidden_size, hidden_size)

        self.lin4 = nn.Linear(hidden_size, hidden_size)

        self.lin5 = nn.Linear(hidden_size, hidden_size)

        # Hidden
        self.lin6 = nn.Linear(hidden_size, output_size)

    def forward(self, x):
        x = x.view(x.size(0), -1)  # Flatten input tensor
        x = self.lin1(x)
        x = self.sigmoid(x)  # Change ReLU to Sigmoid

        # Hidden
        x = self.lin2(x)
        x = self.sigmoid(x)  # Change ReLU to Sigmoid

        x = self.lin3(x)
        x = self.sigmoid(x)  # Change ReLU to Sigmoid

        x = self.lin4(x)
        x = self.sigmoid(x)  # Change ReLU to Sigmoid

        x = self.lin4(x)
        x = self.sigmoid(x)  # Change ReLU to Sigmoid

        # Hidden
        x = self.lin6(x)
        return x
    
    def get_architecture_name(self):
        name = 'MLP_v4_sig'
        return name

# %%
class MLP_v4_tanh(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super(MLP_v4_tanh, self).__init__()
        self.lin1 = nn.Linear(input_size, hidden_size)
        self.tanh = nn.Tanh()  # Change ReLU to Tanh

        # Hidden
        self.lin2 = nn.Linear(hidden_size, hidden_size)

        self.lin3 = nn.Linear(hidden_size, hidden_size)

        self.lin4 = nn.Linear(hidden_size, hidden_size)

        self.lin5 = nn.Linear(hidden_size, hidden_size)

        # Hidden
        self.lin6 = nn.Linear(hidden_size, output_size)

    def forward(self, x):
        x = x.view(x.size(0), -1)  # Flatten input tensor
        x = self.lin1(x)
        x = self.tanh(x)  # Change ReLU to Tanh

        # Hidden
        x = self.lin2(x)
        x = self.tanh(x)  # Change ReLU to Tanh

        x = self.lin3(x)
        x = self.tanh(x)  # Change ReLU to Tanh

        x = self.lin4(x)
        x = self.tanh(x)  # Change ReLU to Tanh

        x = self.lin4(x)
        x = self.tanh(x)  # Change ReLU to Tanh

        # Hidden
        x = self.lin6(x)
        return x
    
    def get_architecture_name(self):
        name = 'MLP_v4_tanh'
        return name

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)

#Initialize model, loss function, and optimizer
input_size = IMG_WIDTH * IMG_HEIGHT * 3 #RGB
#n of classes
output_size = 9

save_dir = '/home/stefanotrenti/AML/project/AOL_test'
name = 'AOL_function_tests_MLP.txt'

optimizers = ['adam','SGD','RMSprop']
losses = ['cross_entropy','MSELoss','BCELoss']


best_model_v4, _ = Train_K_FOLDS(MLP_v4, 50, 0.0001, 10, 32, 0.01, input_size, 128, output_size, 'adam', 'cross_entropy')
filename_v4 = best_model_v4.get_architecture_name() + '.txt'
saveResults(best_model_v4,save_dir,name,filename_v4, 'adam', 'cross_entropy')

best_model_v4, _ = Train_K_FOLDS(MLP_v4, 50, 0.0001, 10, 32, 0.01, input_size, 128, output_size, 'adam', 'MSELoss')
filename_v4 = best_model_v4.get_architecture_name() + '.txt'
saveResults(best_model_v4,save_dir,name,filename_v4, 'adam', 'MSELoss')

best_model_v4, _ = Train_K_FOLDS(MLP_v4, 50, 0.0001, 10, 32, 0.01, input_size, 128, output_size, 'adam', 'BCELoss')
filename_v4 = best_model_v4.get_architecture_name() + '.txt'
saveResults(best_model_v4,save_dir,name,filename_v4, 'adam', 'BCELoss')


best_model_v4, _ = Train_K_FOLDS(MLP_v4, 50, 0.0001, 10, 32, 0.01, input_size, 128, output_size, 'SGD', 'cross_entropy')
filename_v4 = best_model_v4.get_architecture_name() + '.txt'
saveResults(best_model_v4,save_dir,name,filename_v4, 'SGD', 'cross_entropy')

best_model_v4, _ = Train_K_FOLDS(MLP_v4, 50, 0.0001, 10, 32, 0.01, input_size, 128, output_size, 'SGD', 'MSELoss')
filename_v4 = best_model_v4.get_architecture_name() + '.txt'
saveResults(best_model_v4,save_dir,name,filename_v4, 'SGD', 'MSELoss')

best_model_v4, _ = Train_K_FOLDS(MLP_v4, 50, 0.0001, 10, 32, 0.01, input_size, 128, output_size, 'SGD', 'BCELoss')
filename_v4 = best_model_v4.get_architecture_name() + '.txt'
saveResults(best_model_v4,save_dir,name,filename_v4, 'SGD', 'BCELoss')


best_model_v4, _ = Train_K_FOLDS(MLP_v4, 50, 0.0001, 10, 32, 0.01, input_size, 128, output_size, 'RMSprop', 'cross_entropy')
filename_v4 = best_model_v4.get_architecture_name() + '.txt'
saveResults(best_model_v4,save_dir,name,filename_v4, 'RMSprop', 'cross_entropy')

best_model_v4, _ = Train_K_FOLDS(MLP_v4, 50, 0.0001, 10, 32, 0.01, input_size, 128, output_size, 'RMSprop', 'MSELoss')
filename_v4 = best_model_v4.get_architecture_name() + '.txt'
saveResults(best_model_v4,save_dir,name,filename_v4, 'RMSprop', 'MSELoss')

best_model_v4, _ = Train_K_FOLDS(MLP_v4, 50, 0.0001, 10, 32, 0.01, input_size, 128, output_size, 'RMSprop', 'BCELoss')
filename_v4 = best_model_v4.get_architecture_name() + '.txt'
saveResults(best_model_v4,save_dir,name,filename_v4, 'RMSprop', 'BCELoss')
# Out:
# cuda:0
# Epoch [1/50], Train Loss: 4.2380, Train Acc: 0.00%, Val Loss: 2.1700, Val Acc: 11.11%
# Epoch [2/50], Train Loss: 3.9778, Train Acc: 16.67%, Val Loss: 2.1666, Val Acc: 11.11%
# Epoch [3/50], Train Loss: 3.7938, Train Acc: 12.50%, Val Loss: 2.1502, Val Acc: 12.96%
# Epoch [4/50], Train Loss: 3.6401, Train Acc: 26.67%, Val Loss: 2.1055, Val Acc: 16.67%
# Epoch [5/50], Train Loss: 3.5014, Train Acc: 13.33%, Val Loss: 2.0372, Val Acc: 22.50%
# Epoch [6/50], Train Loss: 3.3576, Train Acc: 20.00%, Val Loss: 1.9458, Val Acc: 21.85%
# Epoch [7/50], Train Loss: 3.2340, Train Acc: 37.50%, Val Loss: 1.9064, Val Acc: 32.73%
# Epoch [8/50], Train Loss: 3.1430, Train Acc: 28.57%, Val Loss: 1.8038, Val Acc: 32.50%
# Epoch [9/50], Train Loss: 3.0579, Train Acc: 22.22%, Val Loss: 1.6871, Val Acc: 38.75%
# Epoch [10/50], Train Loss: 2.8942, Train Acc: 35.71%, Val Loss: 1.5365, Val Acc: 31.11%
# Epoch [11/50], Train Loss: 2.7445, Train Acc: 58.33%, Val Loss: 1.4232, Val Acc: 32.59%
# Epoch [12/50], Train Loss: 2.6139, Train Acc: 41.67%, Val Loss: 1.3198, Val Acc: 37.04%
# Epoch [13/50], Train Loss: 2.5276, Train Acc: 46.88%, Val Loss: 1.2445, Val Acc: 44.07%
# Epoch [14/50], Train Loss: 2.3953, Train Acc: 59.17%, Val Loss: 1.1506, Val Acc: 53.12%
# Epoch [15/50], Train Loss: 2.3180, Train Acc: 60.00%, Val Loss: 1.1765, Val Acc: 47.50%
# Epoch [16/50], Train Loss: 2.3122, Train Acc: 51.67%, Val Loss: 1.1447, Val Acc: 45.83%
# Epoch [17/50], Train Loss: 2.1926, Train Acc: 68.89%, Val Loss: 1.2763, Val Acc: 40.74%
# Epoch [18/50], Train Loss: 2.2214, Train Acc: 62.50%, Val Loss: 1.1434, Val Acc: 46.88%
# Epoch [19/50], Train Loss: 2.1047, Train Acc: 50.00%, Val Loss: 1.0580, Val Acc: 42.22%
# Epoch [20/50], Train Loss: 2.0046, Train Acc: 42.86%, Val Loss: 1.0379, Val Acc: 52.08%
# Epoch [21/50], Train Loss: 1.9606, Train Acc: 42.86%, Val Loss: 1.1412, Val Acc: 41.67%
# Epoch [22/50], Train Loss: 1.9452, Train Acc: 61.11%, Val Loss: 1.0229, Val Acc: 40.74%
# Epoch [23/50], Train Loss: 1.8984, Train Acc: 57.14%, Val Loss: 0.9473, Val Acc: 58.33%
# Epoch [24/50], Train Loss: 1.8444, Train Acc: 71.43%, Val Loss: 0.9703, Val Acc: 54.63%
# Epoch [25/50], Train Loss: 1.8247, Train Acc: 57.14%, Val Loss: 1.1794, Val Acc: 43.21%
# Epoch [26/50], Train Loss: 1.8920, Train Acc: 35.71%, Val Loss: 0.9445, Val Acc: 50.00%
# Epoch [27/50], Train Loss: 1.7652, Train Acc: 50.00%, Val Loss: 0.9397, Val Acc: 48.15%
# Epoch [28/50], Train Loss: 1.7291, Train Acc: 66.67%, Val Loss: 0.9398, Val Acc: 54.69%
# Epoch [29/50], Train Loss: 1.7172, Train Acc: 100.00%, Val Loss: 0.9151, Val Acc: 41.67%
# Epoch [30/50], Train Loss: 1.7031, Train Acc: 75.00%, Val Loss: 0.9439, Val Acc: 46.85%
# Epoch [31/50], Train Loss: 1.6884, Train Acc: 75.00%, Val Loss: 0.9726, Val Acc: 51.67%
# Epoch [32/50], Train Loss: 1.6432, Train Acc: 66.67%, Val Loss: 0.9234, Val Acc: 50.00%
# Epoch [33/50], Train Loss: 1.5975, Train Acc: 71.43%, Val Loss: 0.9001, Val Acc: 53.70%
# Epoch [34/50], Train Loss: 1.5851, Train Acc: 61.46%, Val Loss: 0.9039, Val Acc: 64.81%
# Epoch [35/50], Train Loss: 1.5606, Train Acc: 100.00%, Val Loss: 0.8983, Val Acc: 49.52%
# Epoch [36/50], Train Loss: 1.5296, Train Acc: 71.43%, Val Loss: 0.9390, Val Acc: 57.41%
# Epoch [37/50], Train Loss: 1.5160, Train Acc: 70.00%, Val Loss: 0.8924, Val Acc: 56.11%
# Epoch [38/50], Train Loss: 1.4832, Train Acc: 66.67%, Val Loss: 0.9066, Val Acc: 62.08%
# Epoch [39/50], Train Loss: 1.4928, Train Acc: 68.57%, Val Loss: 0.9134, Val Acc: 69.44%
# Epoch [40/50], Train Loss: 1.4951, Train Acc: 85.71%, Val Loss: 0.9847, Val Acc: 62.22%
# Epoch [41/50], Train Loss: 1.4447, Train Acc: 66.67%, Val Loss: 0.9469, Val Acc: 46.11%
# Epoch [42/50], Train Loss: 1.4415, Train Acc: 72.92%, Val Loss: 0.8793, Val Acc: 65.56%
# Epoch [43/50], Train Loss: 1.4661, Train Acc: 54.76%, Val Loss: 0.8668, Val Acc: 61.67%
# Epoch [44/50], Train Loss: 1.4423, Train Acc: 94.44%, Val Loss: 0.8629, Val Acc: 72.50%
# Epoch [45/50], Train Loss: 1.4040, Train Acc: 77.78%, Val Loss: 0.8990, Val Acc: 59.38%
# Epoch [46/50], Train Loss: 1.3981, Train Acc: 83.33%, Val Loss: 0.9992, Val Acc: 43.75%
# Epoch [47/50], Train Loss: 1.3631, Train Acc: 87.50%, Val Loss: 0.9015, Val Acc: 45.56%
# Epoch [48/50], Train Loss: 1.3581, Train Acc: 86.11%, Val Loss: 0.9493, Val Acc: 62.59%
# Epoch [49/50], Train Loss: 1.3717, Train Acc: 80.95%, Val Loss: 1.0467, Val Acc: 43.89%
# Epoch [50/50], Train Loss: 1.3768, Train Acc: 94.44%, Val Loss: 0.8838, Val Acc: 56.67%
# F1 Score:  0.7130255987398844
# B_acc:  0.6148148148148148
# Best model has index  0
#
# Epoch [1/50], Train Loss: 4.2375, Train Acc: 33.33%, Val Loss: 2.1470, Val Acc: 11.11%
# Epoch [2/50], Train Loss: 3.9839, Train Acc: 17.86%, Val Loss: 2.0857, Val Acc: 19.44%
# Epoch [3/50], Train Loss: 3.7924, Train Acc: 19.05%, Val Loss: 2.0592, Val Acc: 19.69%
# Epoch [4/50], Train Loss: 3.6331, Train Acc: 22.22%, Val Loss: 2.0146, Val Acc: 18.41%
# Epoch [5/50], Train Loss: 3.4889, Train Acc: 16.67%, Val Loss: 1.9328, Val Acc: 19.05%
# Epoch [6/50], Train Loss: 3.3438, Train Acc: 22.22%, Val Loss: 1.8341, Val Acc: 20.83%
# Epoch [7/50], Train Loss: 3.2202, Train Acc: 31.43%, Val Loss: 1.7475, Val Acc: 17.53%
# Epoch [8/50], Train Loss: 3.1041, Train Acc: 22.22%, Val Loss: 1.6662, Val Acc: 30.56%
# Epoch [9/50], Train Loss: 3.0135, Train Acc: 50.00%, Val Loss: 1.7786, Val Acc: 33.33%
# Epoch [10/50], Train Loss: 2.8774, Train Acc: 50.00%, Val Loss: 1.4988, Val Acc: 27.78%
# Epoch [11/50], Train Loss: 2.7794, Train Acc: 22.22%, Val Loss: 1.3952, Val Acc: 37.50%
# Epoch [12/50], Train Loss: 2.6079, Train Acc: 48.00%, Val Loss: 1.2666, Val Acc: 36.11%
# Epoch [13/50], Train Loss: 2.5004, Train Acc: 37.50%, Val Loss: 1.1673, Val Acc: 37.04%
# Epoch [14/50], Train Loss: 2.4127, Train Acc: 43.75%, Val Loss: 1.1538, Val Acc: 33.33%
# Epoch [15/50], Train Loss: 2.3129, Train Acc: 72.22%, Val Loss: 1.1245, Val Acc: 53.57%
# Epoch [16/50], Train Loss: 2.2721, Train Acc: 40.62%, Val Loss: 1.0490, Val Acc: 48.15%
# Epoch [17/50], Train Loss: 2.2372, Train Acc: 35.71%, Val Loss: 1.0393, Val Acc: 53.06%
# Epoch [18/50], Train Loss: 2.1582, Train Acc: 64.29%, Val Loss: 0.9749, Val Acc: 60.62%
# Epoch [19/50], Train Loss: 2.1210, Train Acc: 31.25%, Val Loss: 0.9481, Val Acc: 38.89%
# Epoch [20/50], Train Loss: 2.0801, Train Acc: 71.11%, Val Loss: 0.9384, Val Acc: 51.67%
# Epoch [21/50], Train Loss: 2.0083, Train Acc: 41.67%, Val Loss: 0.9469, Val Acc: 43.40%
# Epoch [22/50], Train Loss: 1.9786, Train Acc: 45.24%, Val Loss: 0.8803, Val Acc: 50.00%
# Epoch [23/50], Train Loss: 1.9440, Train Acc: 75.00%, Val Loss: 1.0428, Val Acc: 53.12%
# Epoch [24/50], Train Loss: 1.9097, Train Acc: 61.11%, Val Loss: 0.8281, Val Acc: 50.00%
# Epoch [25/50], Train Loss: 1.8640, Train Acc: 39.29%, Val Loss: 0.7880, Val Acc: 55.56%
# Epoch [26/50], Train Loss: 1.8268, Train Acc: 69.05%, Val Loss: 0.7412, Val Acc: 68.75%
# Epoch [27/50], Train Loss: 1.7665, Train Acc: 50.00%, Val Loss: 0.8276, Val Acc: 52.38%
# Epoch [28/50], Train Loss: 1.7964, Train Acc: 66.67%, Val Loss: 1.0011, Val Acc: 50.42%
# Epoch [29/50], Train Loss: 1.7729, Train Acc: 64.29%, Val Loss: 0.7999, Val Acc: 52.12%
# Epoch [30/50], Train Loss: 1.7325, Train Acc: 53.75%, Val Loss: 0.7564, Val Acc: 73.81%
# Epoch [31/50], Train Loss: 1.6996, Train Acc: 43.33%, Val Loss: 0.7214, Val Acc: 60.19%
# Epoch [32/50], Train Loss: 1.6528, Train Acc: 51.85%, Val Loss: 0.6737, Val Acc: 59.26%
# Epoch [33/50], Train Loss: 1.6118, Train Acc: 51.85%, Val Loss: 0.7088, Val Acc: 50.00%
# Epoch [34/50], Train Loss: 1.6418, Train Acc: 57.14%, Val Loss: 0.6525, Val Acc: 62.08%
# Epoch [35/50], Train Loss: 1.6412, Train Acc: 64.29%, Val Loss: 0.9885, Val Acc: 52.30%
# Epoch [36/50], Train Loss: 1.6185, Train Acc: 82.86%, Val Loss: 0.6979, Val Acc: 56.48%
# Epoch [37/50], Train Loss: 1.5378, Train Acc: 80.00%, Val Loss: 0.6027, Val Acc: 62.50%
# Epoch [38/50], Train Loss: 1.5005, Train Acc: 92.86%, Val Loss: 0.7219, Val Acc: 69.64%
# Epoch [39/50], Train Loss: 1.5293, Train Acc: 88.33%, Val Loss: 0.5824, Val Acc: 50.00%
# Epoch [40/50], Train Loss: 1.4633, Train Acc: 73.33%, Val Loss: 0.7051, Val Acc: 53.70%
# Epoch [41/50], Train Loss: 1.4546, Train Acc: 55.56%, Val Loss: 0.5929, Val Acc: 74.07%
# Epoch [42/50], Train Loss: 1.4298, Train Acc: 75.00%, Val Loss: 0.5910, Val Acc: 72.22%
# Epoch [43/50], Train Loss: 1.4109, Train Acc: 75.00%, Val Loss: 0.5826, Val Acc: 62.50%
# Epoch [44/50], Train Loss: 1.4023, Train Acc: 59.52%, Val Loss: 0.6241, Val Acc: 64.58%
# Epoch [45/50], Train Loss: 1.4076, Train Acc: 61.11%, Val Loss: 0.6175, Val Acc: 58.15%
# Epoch [46/50], Train Loss: 1.3796, Train Acc: 100.00%, Val Loss: 0.5866, Val Acc: 69.79%
# Epoch [47/50], Train Loss: 1.3762, Train Acc: 83.33%, Val Loss: 0.5525, Val Acc: 80.95%
# Epoch [48/50], Train Loss: 1.3863, Train Acc: 53.70%, Val Loss: 0.5391, Val Acc: 62.96%
# Epoch [49/50], Train Loss: 1.3727, Train Acc: 68.75%, Val Loss: 0.6991, Val Acc: 78.57%
# Epoch [50/50], Train Loss: 1.4280, Train Acc: 54.76%, Val Loss: 0.6351, Val Acc: 88.10%
# F1 Score:  0.8351902051143039
# B_acc:  0.6888888888888889
# Best model has index  0
#
# Epoch [1/50], Train Loss: 4.2386, Train Acc: 6.67%, Val Loss: 2.2050, Val Acc: 6.30%
# Epoch [2/50], Train Loss: 3.9879, Train Acc: 33.33%, Val Loss: 2.2032, Val Acc: 9.82%
# Epoch [3/50], Train Loss: 3.8102, Train Acc: 30.00%, Val Loss: 2.1732, Val Acc: 13.33%
# Epoch [4/50], Train Loss: 3.6422, Train Acc: 40.00%, Val Loss: 2.1371, Val Acc: 17.22%
# Epoch [5/50], Train Loss: 3.4980, Train Acc: 21.43%, Val Loss: 2.0472, Val Acc: 15.56%
# Epoch [6/50], Train Loss: 3.3464, Train Acc: 32.00%, Val Loss: 1.9975, Val Acc: 21.35%
# Epoch [7/50], Train Loss: 3.2425, Train Acc: 28.57%, Val Loss: 1.9396, Val Acc: 29.63%
# Epoch [8/50], Train Loss: 3.1271, Train Acc: 22.22%, Val Loss: 1.8811, Val Acc: 22.92%
# Epoch [9/50], Train Loss: 2.9946, Train Acc: 22.92%, Val Loss: 1.8026, Val Acc: 25.00%
# Epoch [10/50], Train Loss: 2.8650, Train Acc: 14.29%, Val Loss: 1.6512, Val Acc: 34.26%
# Epoch [11/50], Train Loss: 2.7353, Train Acc: 33.33%, Val Loss: 1.5498, Val Acc: 33.33%
# Epoch [12/50], Train Loss: 2.6034, Train Acc: 42.86%, Val Loss: 1.4754, Val Acc: 29.63%
# Epoch [13/50], Train Loss: 2.5110, Train Acc: 40.62%, Val Loss: 1.4073, Val Acc: 48.89%
# Epoch [14/50], Train Loss: 2.4157, Train Acc: 60.00%, Val Loss: 1.3199, Val Acc: 32.92%
# Epoch [15/50], Train Loss: 2.3524, Train Acc: 48.57%, Val Loss: 1.3979, Val Acc: 50.00%
# Epoch [16/50], Train Loss: 2.2803, Train Acc: 58.33%, Val Loss: 1.2234, Val Acc: 50.00%
# Epoch [17/50], Train Loss: 2.2023, Train Acc: 47.62%, Val Loss: 1.1423, Val Acc: 41.96%
# Epoch [18/50], Train Loss: 2.1278, Train Acc: 64.29%, Val Loss: 1.1920, Val Acc: 46.25%
# Epoch [19/50], Train Loss: 2.0916, Train Acc: 74.29%, Val Loss: 1.1193, Val Acc: 46.88%
# Epoch [20/50], Train Loss: 2.0154, Train Acc: 63.33%, Val Loss: 1.1324, Val Acc: 41.67%
# Epoch [21/50], Train Loss: 1.9536, Train Acc: 75.00%, Val Loss: 1.0903, Val Acc: 45.83%
# Epoch [22/50], Train Loss: 1.9256, Train Acc: 52.08%, Val Loss: 1.1261, Val Acc: 53.12%
# Epoch [23/50], Train Loss: 1.9422, Train Acc: 45.83%, Val Loss: 1.1448, Val Acc: 47.92%
# Epoch [24/50], Train Loss: 1.8845, Train Acc: 62.50%, Val Loss: 1.0406, Val Acc: 46.67%
# Epoch [25/50], Train Loss: 1.8523, Train Acc: 66.67%, Val Loss: 1.0331, Val Acc: 52.50%
# Epoch [26/50], Train Loss: 1.9520, Train Acc: 62.50%, Val Loss: 1.0596, Val Acc: 55.00%
# Epoch [27/50], Train Loss: 1.7864, Train Acc: 61.11%, Val Loss: 1.0284, Val Acc: 50.00%
# Epoch [28/50], Train Loss: 1.7591, Train Acc: 76.19%, Val Loss: 1.0146, Val Acc: 58.33%
# Epoch [29/50], Train Loss: 1.7070, Train Acc: 64.29%, Val Loss: 0.9792, Val Acc: 35.71%
# Epoch [30/50], Train Loss: 1.7070, Train Acc: 75.00%, Val Loss: 1.0245, Val Acc: 48.15%
# Epoch [31/50], Train Loss: 1.6694, Train Acc: 75.00%, Val Loss: 1.0376, Val Acc: 52.78%
# Epoch [32/50], Train Loss: 1.6414, Train Acc: 58.33%, Val Loss: 0.9970, Val Acc: 46.88%
# Epoch [33/50], Train Loss: 1.5877, Train Acc: 60.71%, Val Loss: 0.9253, Val Acc: 40.62%
# Epoch [34/50], Train Loss: 1.5880, Train Acc: 66.67%, Val Loss: 1.1504, Val Acc: 56.25%
# Epoch [35/50], Train Loss: 1.5781, Train Acc: 78.57%, Val Loss: 1.0032, Val Acc: 55.19%
# Epoch [36/50], Train Loss: 1.5515, Train Acc: 56.25%, Val Loss: 1.0644, Val Acc: 46.91%
# Epoch [37/50], Train Loss: 1.5531, Train Acc: 83.33%, Val Loss: 1.0704, Val Acc: 50.00%
# Epoch [38/50], Train Loss: 1.5597, Train Acc: 64.29%, Val Loss: 0.8516, Val Acc: 60.42%
# Epoch [39/50], Train Loss: 1.5545, Train Acc: 62.50%, Val Loss: 0.9180, Val Acc: 60.00%
# Epoch [40/50], Train Loss: 1.5660, Train Acc: 75.00%, Val Loss: 1.0251, Val Acc: 40.00%
# Epoch [41/50], Train Loss: 1.5403, Train Acc: 72.22%, Val Loss: 0.8822, Val Acc: 51.85%
# Epoch [42/50], Train Loss: 1.4764, Train Acc: 75.00%, Val Loss: 0.9642, Val Acc: 51.85%
# Epoch [43/50], Train Loss: 1.4647, Train Acc: 66.67%, Val Loss: 1.0104, Val Acc: 55.42%
# Epoch [44/50], Train Loss: 1.4325, Train Acc: 71.43%, Val Loss: 1.0633, Val Acc: 45.37%
# Epoch [45/50], Train Loss: 1.4282, Train Acc: 75.00%, Val Loss: 0.8557, Val Acc: 45.83%
# Epoch [46/50], Train Loss: 1.3624, Train Acc: 100.00%, Val Loss: 0.9436, Val Acc: 51.85%
# Epoch [47/50], Train Loss: 1.5254, Train Acc: 78.57%, Val Loss: 0.9227, Val Acc: 58.33%
# Epoch [48/50], Train Loss: 1.4833, Train Acc: 80.95%, Val Loss: 1.1022, Val Acc: 51.13%
# Epoch [49/50], Train Loss: 1.4429, Train Acc: 80.95%, Val Loss: 0.8228, Val Acc: 59.63%
# Epoch [50/50], Train Loss: 1.3572, Train Acc: 83.33%, Val Loss: 0.8069, Val Acc: 42.59%
# F1 Score:  0.5952015142407849
# B_acc:  0.49682539682539684
# Best model has index  0
#
# Epoch [1/50], Train Loss: 4.2670, Train Acc: 3.12%, Val Loss: 2.1856, Val Acc: 7.41%
# Epoch [2/50], Train Loss: 4.0201, Train Acc: 16.67%, Val Loss: 2.1708, Val Acc: 17.28%
# Epoch [3/50], Train Loss: 3.8375, Train Acc: 16.67%, Val Loss: 2.1340, Val Acc: 9.63%
# Epoch [4/50], Train Loss: 3.6950, Train Acc: 50.00%, Val Loss: 2.1171, Val Acc: 14.37%
# Epoch [5/50], Train Loss: 3.5639, Train Acc: 25.71%, Val Loss: 2.0519, Val Acc: 17.78%
# Epoch [6/50], Train Loss: 3.4561, Train Acc: 23.81%, Val Loss: 2.0080, Val Acc: 11.81%
# Epoch [7/50], Train Loss: 3.3249, Train Acc: 25.00%, Val Loss: 1.9547, Val Acc: 12.50%
# Epoch [8/50], Train Loss: 3.2047, Train Acc: 20.83%, Val Loss: 1.8840, Val Acc: 18.85%
# Epoch [9/50], Train Loss: 3.1060, Train Acc: 12.50%, Val Loss: 1.8335, Val Acc: 20.00%
# Epoch [10/50], Train Loss: 2.9945, Train Acc: 66.67%, Val Loss: 1.7526, Val Acc: 29.63%
# Epoch [11/50], Train Loss: 2.8999, Train Acc: 50.00%, Val Loss: 1.6299, Val Acc: 25.54%
# Epoch [12/50], Train Loss: 2.7592, Train Acc: 52.86%, Val Loss: 1.5291, Val Acc: 31.08%
# Epoch [13/50], Train Loss: 2.6247, Train Acc: 61.11%, Val Loss: 1.4762, Val Acc: 32.99%
# Epoch [14/50], Train Loss: 2.5191, Train Acc: 37.50%, Val Loss: 1.3478, Val Acc: 43.75%
# Epoch [15/50], Train Loss: 2.3963, Train Acc: 50.00%, Val Loss: 1.2563, Val Acc: 37.96%
# Epoch [16/50], Train Loss: 2.2917, Train Acc: 38.89%, Val Loss: 1.2198, Val Acc: 38.78%
# Epoch [17/50], Train Loss: 2.1946, Train Acc: 75.00%, Val Loss: 1.1647, Val Acc: 57.14%
# Epoch [18/50], Train Loss: 2.1521, Train Acc: 60.00%, Val Loss: 1.0639, Val Acc: 47.62%
# Epoch [19/50], Train Loss: 2.0689, Train Acc: 66.67%, Val Loss: 1.0459, Val Acc: 49.38%
# Epoch [20/50], Train Loss: 2.0076, Train Acc: 61.90%, Val Loss: 0.9923, Val Acc: 48.15%
# Epoch [21/50], Train Loss: 1.9566, Train Acc: 55.56%, Val Loss: 0.9857, Val Acc: 47.62%
# Epoch [22/50], Train Loss: 1.9236, Train Acc: 45.83%, Val Loss: 1.0119, Val Acc: 61.25%
# Epoch [23/50], Train Loss: 1.9708, Train Acc: 45.83%, Val Loss: 0.9672, Val Acc: 59.72%
# Epoch [24/50], Train Loss: 1.8990, Train Acc: 68.75%, Val Loss: 0.9704, Val Acc: 48.44%
# Epoch [25/50], Train Loss: 1.8328, Train Acc: 44.44%, Val Loss: 0.9502, Val Acc: 60.32%
# Epoch [26/50], Train Loss: 1.7799, Train Acc: 71.43%, Val Loss: 0.9933, Val Acc: 57.50%
# Epoch [27/50], Train Loss: 1.7742, Train Acc: 67.86%, Val Loss: 1.0603, Val Acc: 54.17%
# Epoch [28/50], Train Loss: 1.8157, Train Acc: 45.83%, Val Loss: 0.9281, Val Acc: 34.29%
# Epoch [29/50], Train Loss: 1.7202, Train Acc: 64.29%, Val Loss: 0.9628, Val Acc: 55.56%
# Epoch [30/50], Train Loss: 1.6750, Train Acc: 73.81%, Val Loss: 0.9108, Val Acc: 51.85%
# Epoch [31/50], Train Loss: 1.6440, Train Acc: 80.00%, Val Loss: 0.9093, Val Acc: 62.04%
# Epoch [32/50], Train Loss: 1.6428, Train Acc: 66.67%, Val Loss: 0.9661, Val Acc: 44.64%
# Epoch [33/50], Train Loss: 1.6498, Train Acc: 42.86%, Val Loss: 0.9367, Val Acc: 67.20%
# Epoch [34/50], Train Loss: 1.6188, Train Acc: 65.00%, Val Loss: 1.1180, Val Acc: 46.30%
# Epoch [35/50], Train Loss: 1.6274, Train Acc: 60.00%, Val Loss: 0.9247, Val Acc: 50.93%
# Epoch [36/50], Train Loss: 1.5717, Train Acc: 80.00%, Val Loss: 0.9518, Val Acc: 75.89%
# Epoch [37/50], Train Loss: 1.5869, Train Acc: 50.00%, Val Loss: 0.9718, Val Acc: 63.33%
# Epoch [38/50], Train Loss: 1.5784, Train Acc: 86.11%, Val Loss: 1.2274, Val Acc: 50.83%
# Epoch [39/50], Train Loss: 1.6200, Train Acc: 71.67%, Val Loss: 0.8970, Val Acc: 53.12%
# Epoch [40/50], Train Loss: 1.5212, Train Acc: 67.50%, Val Loss: 0.8894, Val Acc: 53.33%
# Epoch [41/50], Train Loss: 1.5184, Train Acc: 86.11%, Val Loss: 0.9831, Val Acc: 57.50%
# Epoch [42/50], Train Loss: 1.5209, Train Acc: 62.50%, Val Loss: 1.0953, Val Acc: 53.57%
# Epoch [43/50], Train Loss: 1.5171, Train Acc: 66.67%, Val Loss: 0.9617, Val Acc: 66.67%
# Epoch [44/50], Train Loss: 1.4649, Train Acc: 58.33%, Val Loss: 0.9960, Val Acc: 61.90%
# Epoch [45/50], Train Loss: 1.4242, Train Acc: 85.71%, Val Loss: 0.8720, Val Acc: 52.98%
# Epoch [46/50], Train Loss: 1.4151, Train Acc: 65.00%, Val Loss: 1.0245, Val Acc: 50.93%
# Epoch [47/50], Train Loss: 1.4405, Train Acc: 60.42%, Val Loss: 0.9151, Val Acc: 60.04%
# Epoch [48/50], Train Loss: 1.5286, Train Acc: 65.28%, Val Loss: 1.1574, Val Acc: 57.04%
# Epoch [49/50], Train Loss: 1.5702, Train Acc: 45.00%, Val Loss: 0.9898, Val Acc: 52.92%
# Epoch [50/50], Train Loss: 1.4159, Train Acc: 68.75%, Val Loss: 0.9336, Val Acc: 47.22%
# F1 Score:  0.6334353460159912
# B_acc:  0.513973063973064
# Best model has index  0
#
# Epoch [1/50], Train Loss: 4.2238, Train Acc: 27.78%, Val Loss: 2.1422, Val Acc: 17.78%
# Epoch [2/50], Train Loss: 3.9671, Train Acc: 8.57%, Val Loss: 2.0915, Val Acc: 18.57%
# Epoch [3/50], Train Loss: 3.7787, Train Acc: 20.83%, Val Loss: 2.0433, Val Acc: 20.31%
# Epoch [4/50], Train Loss: 3.6222, Train Acc: 14.29%, Val Loss: 1.9317, Val Acc: 20.80%
# Epoch [5/50], Train Loss: 3.4763, Train Acc: 0.00%, Val Loss: 1.8428, Val Acc: 12.28%
# Epoch [6/50], Train Loss: 3.3513, Train Acc: 35.71%, Val Loss: 1.7783, Val Acc: 23.21%
# Epoch [7/50], Train Loss: 3.2417, Train Acc: 16.67%, Val Loss: 1.7476, Val Acc: 16.32%
# Epoch [8/50], Train Loss: 3.1340, Train Acc: 20.83%, Val Loss: 1.6643, Val Acc: 16.67%
# Epoch [9/50], Train Loss: 3.0400, Train Acc: 30.95%, Val Loss: 1.6161, Val Acc: 34.13%
# Epoch [10/50], Train Loss: 2.9335, Train Acc: 45.83%, Val Loss: 1.4728, Val Acc: 48.98%
# Epoch [11/50], Train Loss: 2.8000, Train Acc: 41.67%, Val Loss: 1.3818, Val Acc: 35.83%
# Epoch [12/50], Train Loss: 2.6706, Train Acc: 55.56%, Val Loss: 1.2501, Val Acc: 41.67%
# Epoch [13/50], Train Loss: 2.5740, Train Acc: 44.44%, Val Loss: 1.2980, Val Acc: 44.64%
# Epoch [14/50], Train Loss: 2.4810, Train Acc: 58.33%, Val Loss: 1.1115, Val Acc: 39.76%
# Epoch [15/50], Train Loss: 2.3750, Train Acc: 75.00%, Val Loss: 1.0544, Val Acc: 42.71%
# Epoch [16/50], Train Loss: 2.3121, Train Acc: 50.00%, Val Loss: 0.9774, Val Acc: 49.63%
# Epoch [17/50], Train Loss: 2.2205, Train Acc: 66.67%, Val Loss: 0.9547, Val Acc: 48.96%
# Epoch [18/50], Train Loss: 2.1537, Train Acc: 50.00%, Val Loss: 0.9108, Val Acc: 37.35%
# Epoch [19/50], Train Loss: 2.0714, Train Acc: 50.00%, Val Loss: 0.9324, Val Acc: 52.38%
# Epoch [20/50], Train Loss: 2.0913, Train Acc: 34.38%, Val Loss: 0.9402, Val Acc: 47.04%
# Epoch [21/50], Train Loss: 2.0736, Train Acc: 28.57%, Val Loss: 0.8572, Val Acc: 40.00%
# Epoch [22/50], Train Loss: 1.9486, Train Acc: 41.67%, Val Loss: 0.7978, Val Acc: 40.74%
# Epoch [23/50], Train Loss: 1.9067, Train Acc: 42.86%, Val Loss: 0.8041, Val Acc: 58.85%
# Epoch [24/50], Train Loss: 1.8564, Train Acc: 50.00%, Val Loss: 0.8986, Val Acc: 39.86%
# Epoch [25/50], Train Loss: 1.8659, Train Acc: 83.33%, Val Loss: 0.7928, Val Acc: 48.75%
# Epoch [26/50], Train Loss: 1.8095, Train Acc: 62.50%, Val Loss: 0.7753, Val Acc: 60.42%
# Epoch [27/50], Train Loss: 1.7670, Train Acc: 61.67%, Val Loss: 0.7522, Val Acc: 43.10%
# Epoch [28/50], Train Loss: 1.7501, Train Acc: 50.00%, Val Loss: 0.7506, Val Acc: 55.83%
# Epoch [29/50], Train Loss: 1.7357, Train Acc: 78.57%, Val Loss: 0.8117, Val Acc: 52.98%
# Epoch [30/50], Train Loss: 1.7629, Train Acc: 66.67%, Val Loss: 0.9356, Val Acc: 44.17%
# Epoch [31/50], Train Loss: 1.7770, Train Acc: 43.75%, Val Loss: 1.0510, Val Acc: 56.12%
# Epoch [32/50], Train Loss: 1.8406, Train Acc: 61.90%, Val Loss: 0.7526, Val Acc: 55.06%
# Epoch [33/50], Train Loss: 1.7058, Train Acc: 52.38%, Val Loss: 0.9650, Val Acc: 47.30%
# Epoch [34/50], Train Loss: 1.7191, Train Acc: 64.29%, Val Loss: 0.7973, Val Acc: 68.33%
# Epoch [35/50], Train Loss: 1.6456, Train Acc: 56.67%, Val Loss: 0.7610, Val Acc: 46.11%
# Epoch [36/50], Train Loss: 1.6353, Train Acc: 52.38%, Val Loss: 0.8044, Val Acc: 50.00%
# Epoch [37/50], Train Loss: 1.6035, Train Acc: 52.38%, Val Loss: 0.7848, Val Acc: 59.17%
# Epoch [38/50], Train Loss: 1.5441, Train Acc: 75.00%, Val Loss: 0.7800, Val Acc: 51.25%
# Epoch [39/50], Train Loss: 1.5208, Train Acc: 66.67%, Val Loss: 0.7859, Val Acc: 54.46%
# Epoch [40/50], Train Loss: 1.4975, Train Acc: 80.95%, Val Loss: 0.7751, Val Acc: 61.67%
# Epoch [41/50], Train Loss: 1.5180, Train Acc: 57.14%, Val Loss: 1.0677, Val Acc: 58.16%
# Epoch [42/50], Train Loss: 1.5580, Train Acc: 75.00%, Val Loss: 0.8964, Val Acc: 47.14%
# Epoch [43/50], Train Loss: 1.5216, Train Acc: 46.67%, Val Loss: 0.8830, Val Acc: 86.11%
# Epoch [44/50], Train Loss: 1.4991, Train Acc: 88.00%, Val Loss: 0.9009, Val Acc: 47.94%
# Epoch [45/50], Train Loss: 1.4745, Train Acc: 58.33%, Val Loss: 0.8485, Val Acc: 53.31%
# Epoch [46/50], Train Loss: 1.4460, Train Acc: 62.50%, Val Loss: 0.9364, Val Acc: 50.00%
# Epoch [47/50], Train Loss: 1.4081, Train Acc: 62.50%, Val Loss: 0.8336, Val Acc: 63.27%
# Epoch [48/50], Train Loss: 1.4340, Train Acc: 50.00%, Val Loss: 0.8826, Val Acc: 51.46%
# Epoch [49/50], Train Loss: 1.3960, Train Acc: 85.71%, Val Loss: 1.0195, Val Acc: 39.66%
# Epoch [50/50], Train Loss: 1.4773, Train Acc: 83.33%, Val Loss: 1.1329, Val Acc: 37.86%
# F1 Score:  0.6483129403040415
# B_acc:  0.48290598290598286
# Best model has index  0
#
# Epoch [1/50], Train Loss: 4.2337, Train Acc: 18.57%, Val Loss: 2.1610, Val Acc: 14.58%
# Epoch [2/50], Train Loss: 3.9770, Train Acc: 25.00%, Val Loss: 2.1281, Val Acc: 16.67%
# Epoch [3/50], Train Loss: 3.7856, Train Acc: 16.67%, Val Loss: 2.1016, Val Acc: 16.25%
# Epoch [4/50], Train Loss: 3.6379, Train Acc: 68.00%, Val Loss: 2.0598, Val Acc: 28.16%
# Epoch [5/50], Train Loss: 3.5120, Train Acc: 22.22%, Val Loss: 2.0029, Val Acc: 27.50%
# Epoch [6/50], Train Loss: 3.3681, Train Acc: 12.50%, Val Loss: 1.9171, Val Acc: 20.00%
# Epoch [7/50], Train Loss: 3.2352, Train Acc: 20.83%, Val Loss: 1.8339, Val Acc: 27.62%
# Epoch [8/50], Train Loss: 3.1382, Train Acc: 25.00%, Val Loss: 1.8176, Val Acc: 23.33%
# Epoch [9/50], Train Loss: 3.0528, Train Acc: 20.83%, Val Loss: 1.7773, Val Acc: 29.46%
# Epoch [10/50], Train Loss: 2.9632, Train Acc: 33.33%, Val Loss: 1.6708, Val Acc: 31.25%
# Epoch [11/50], Train Loss: 2.8319, Train Acc: 33.33%, Val Loss: 1.5793, Val Acc: 40.00%
# Epoch [12/50], Train Loss: 2.6817, Train Acc: 33.33%, Val Loss: 1.4655, Val Acc: 50.00%
# Epoch [13/50], Train Loss: 2.5629, Train Acc: 39.58%, Val Loss: 1.3580, Val Acc: 39.76%
# Epoch [14/50], Train Loss: 2.4366, Train Acc: 42.86%, Val Loss: 1.3512, Val Acc: 59.56%
# Epoch [15/50], Train Loss: 2.3802, Train Acc: 39.29%, Val Loss: 1.3293, Val Acc: 45.00%
# Epoch [16/50], Train Loss: 2.2738, Train Acc: 33.33%, Val Loss: 1.2186, Val Acc: 46.88%
# Epoch [17/50], Train Loss: 2.1795, Train Acc: 42.86%, Val Loss: 1.1843, Val Acc: 36.83%
# Epoch [18/50], Train Loss: 2.1095, Train Acc: 42.86%, Val Loss: 1.1182, Val Acc: 50.00%
# Epoch [19/50], Train Loss: 2.0638, Train Acc: 71.43%, Val Loss: 1.1620, Val Acc: 57.14%
# Epoch [20/50], Train Loss: 2.0125, Train Acc: 66.67%, Val Loss: 1.2492, Val Acc: 54.17%
# Epoch [21/50], Train Loss: 2.0113, Train Acc: 58.33%, Val Loss: 1.1763, Val Acc: 52.08%
# Epoch [22/50], Train Loss: 1.9244, Train Acc: 66.67%, Val Loss: 1.1331, Val Acc: 54.17%
# Epoch [23/50], Train Loss: 1.9275, Train Acc: 52.08%, Val Loss: 1.0485, Val Acc: 50.34%
# Epoch [24/50], Train Loss: 1.8439, Train Acc: 43.06%, Val Loss: 1.1129, Val Acc: 37.50%
# Epoch [25/50], Train Loss: 1.8726, Train Acc: 45.83%, Val Loss: 1.1739, Val Acc: 47.50%
# Epoch [26/50], Train Loss: 1.8427, Train Acc: 68.00%, Val Loss: 1.1152, Val Acc: 44.48%
# Epoch [27/50], Train Loss: 1.7559, Train Acc: 59.38%, Val Loss: 1.1159, Val Acc: 49.37%
# Epoch [28/50], Train Loss: 1.7673, Train Acc: 66.67%, Val Loss: 1.1138, Val Acc: 50.00%
# Epoch [29/50], Train Loss: 1.6965, Train Acc: 62.50%, Val Loss: 1.1304, Val Acc: 54.76%
# Epoch [30/50], Train Loss: 1.6656, Train Acc: 87.50%, Val Loss: 1.2078, Val Acc: 63.33%
# Epoch [31/50], Train Loss: 1.6604, Train Acc: 66.67%, Val Loss: 1.0802, Val Acc: 57.02%
# Epoch [32/50], Train Loss: 1.5961, Train Acc: 60.00%, Val Loss: 1.0614, Val Acc: 53.33%
# Epoch [33/50], Train Loss: 1.5860, Train Acc: 44.44%, Val Loss: 1.1026, Val Acc: 52.50%
# Epoch [34/50], Train Loss: 1.7224, Train Acc: 47.62%, Val Loss: 1.0938, Val Acc: 55.78%
# Epoch [35/50], Train Loss: 1.6090, Train Acc: 66.67%, Val Loss: 1.0790, Val Acc: 50.00%
# Epoch [36/50], Train Loss: 1.5804, Train Acc: 54.76%, Val Loss: 1.1232, Val Acc: 51.67%
# Epoch [37/50], Train Loss: 1.5246, Train Acc: 52.38%, Val Loss: 1.1099, Val Acc: 43.54%
# Epoch [38/50], Train Loss: 1.5361, Train Acc: 40.00%, Val Loss: 1.0968, Val Acc: 66.67%
# Epoch [39/50], Train Loss: 1.5266, Train Acc: 84.00%, Val Loss: 1.0821, Val Acc: 53.33%
# Epoch [40/50], Train Loss: 1.4816, Train Acc: 50.00%, Val Loss: 1.1214, Val Acc: 62.86%
# Epoch [41/50], Train Loss: 1.4807, Train Acc: 73.33%, Val Loss: 1.0922, Val Acc: 46.46%
# Epoch [42/50], Train Loss: 1.4706, Train Acc: 50.00%, Val Loss: 1.1600, Val Acc: 50.62%
# Epoch [43/50], Train Loss: 1.4291, Train Acc: 70.83%, Val Loss: 1.1955, Val Acc: 51.25%
# Epoch [44/50], Train Loss: 1.4767, Train Acc: 80.95%, Val Loss: 1.1709, Val Acc: 60.15%
# Epoch [45/50], Train Loss: 1.4099, Train Acc: 64.29%, Val Loss: 1.1318, Val Acc: 43.75%
# Epoch [46/50], Train Loss: 1.3993, Train Acc: 61.11%, Val Loss: 1.1738, Val Acc: 49.05%
# Epoch [47/50], Train Loss: 1.4288, Train Acc: 83.33%, Val Loss: 1.0880, Val Acc: 52.22%
# Epoch [48/50], Train Loss: 1.4190, Train Acc: 60.00%, Val Loss: 1.2202, Val Acc: 52.38%
# Epoch [49/50], Train Loss: 1.4085, Train Acc: 66.67%, Val Loss: 1.1766, Val Acc: 32.64%
# Epoch [50/50], Train Loss: 1.3684, Train Acc: 79.76%, Val Loss: 1.0960, Val Acc: 60.36%
# F1 Score:  0.6197333167616147
# B_acc:  0.5241477272727273
# Best model has index  0
#
# Epoch [1/50], Train Loss: 4.2437, Train Acc: 10.00%, Val Loss: 2.1959, Val Acc: 11.11%
# Epoch [2/50], Train Loss: 3.9954, Train Acc: 16.67%, Val Loss: 2.2042, Val Acc: 13.49%
# Epoch [3/50], Train Loss: 3.8109, Train Acc: 25.71%, Val Loss: 2.1547, Val Acc: 17.50%
# Epoch [4/50], Train Loss: 3.6636, Train Acc: 18.75%, Val Loss: 2.1269, Val Acc: 29.64%
# Epoch [5/50], Train Loss: 3.5193, Train Acc: 22.22%, Val Loss: 2.0669, Val Acc: 15.74%
# Epoch [6/50], Train Loss: 3.3721, Train Acc: 23.33%, Val Loss: 2.0131, Val Acc: 14.07%
# Epoch [7/50], Train Loss: 3.2349, Train Acc: 21.43%, Val Loss: 1.9532, Val Acc: 22.50%
# Epoch [8/50], Train Loss: 3.1130, Train Acc: 28.57%, Val Loss: 1.9287, Val Acc: 22.50%
# Epoch [9/50], Train Loss: 2.9764, Train Acc: 25.00%, Val Loss: 1.8152, Val Acc: 30.95%
# Epoch [10/50], Train Loss: 2.8532, Train Acc: 25.00%, Val Loss: 1.7194, Val Acc: 39.58%
# Epoch [11/50], Train Loss: 2.7063, Train Acc: 38.10%, Val Loss: 1.6393, Val Acc: 33.33%
# Epoch [12/50], Train Loss: 2.5912, Train Acc: 40.48%, Val Loss: 1.6094, Val Acc: 36.90%
# Epoch [13/50], Train Loss: 2.4737, Train Acc: 64.29%, Val Loss: 1.5319, Val Acc: 35.56%
# Epoch [14/50], Train Loss: 2.3757, Train Acc: 50.00%, Val Loss: 1.4861, Val Acc: 34.26%
# Epoch [15/50], Train Loss: 2.3972, Train Acc: 41.67%, Val Loss: 1.4731, Val Acc: 42.59%
# Epoch [16/50], Train Loss: 2.3178, Train Acc: 66.67%, Val Loss: 1.3859, Val Acc: 36.46%
# Epoch [17/50], Train Loss: 2.1673, Train Acc: 66.67%, Val Loss: 1.3169, Val Acc: 45.37%
# Epoch [18/50], Train Loss: 2.1204, Train Acc: 40.00%, Val Loss: 1.3532, Val Acc: 45.08%
# Epoch [19/50], Train Loss: 2.0685, Train Acc: 66.67%, Val Loss: 1.2350, Val Acc: 42.96%
# Epoch [20/50], Train Loss: 2.0238, Train Acc: 60.00%, Val Loss: 1.2566, Val Acc: 50.00%
# Epoch [21/50], Train Loss: 1.9894, Train Acc: 66.67%, Val Loss: 1.2485, Val Acc: 54.52%
# Epoch [22/50], Train Loss: 1.9380, Train Acc: 50.00%, Val Loss: 1.2121, Val Acc: 50.31%
# Epoch [23/50], Train Loss: 1.9060, Train Acc: 71.43%, Val Loss: 1.1632, Val Acc: 56.25%
# Epoch [24/50], Train Loss: 1.8642, Train Acc: 75.00%, Val Loss: 1.2339, Val Acc: 55.28%
# Epoch [25/50], Train Loss: 1.8304, Train Acc: 52.38%, Val Loss: 1.1924, Val Acc: 54.17%
# Epoch [26/50], Train Loss: 1.8101, Train Acc: 62.50%, Val Loss: 1.1174, Val Acc: 46.34%
# Epoch [27/50], Train Loss: 1.7827, Train Acc: 42.86%, Val Loss: 1.1181, Val Acc: 51.48%
# Epoch [28/50], Train Loss: 1.7334, Train Acc: 62.50%, Val Loss: 1.1140, Val Acc: 53.70%
# Epoch [29/50], Train Loss: 1.7194, Train Acc: 41.67%, Val Loss: 1.2091, Val Acc: 45.28%
# Epoch [30/50], Train Loss: 1.6908, Train Acc: 78.33%, Val Loss: 1.2084, Val Acc: 42.50%
# Epoch [31/50], Train Loss: 1.6619, Train Acc: 71.43%, Val Loss: 1.2140, Val Acc: 52.50%
# Epoch [32/50], Train Loss: 1.6860, Train Acc: 66.67%, Val Loss: 1.1118, Val Acc: 46.83%
# Epoch [33/50], Train Loss: 1.6151, Train Acc: 62.50%, Val Loss: 1.1040, Val Acc: 47.78%
# Epoch [34/50], Train Loss: 1.6317, Train Acc: 50.00%, Val Loss: 1.2336, Val Acc: 50.00%
# Epoch [35/50], Train Loss: 1.5962, Train Acc: 75.00%, Val Loss: 1.0675, Val Acc: 49.17%
# Epoch [36/50], Train Loss: 1.5722, Train Acc: 73.33%, Val Loss: 1.1857, Val Acc: 55.36%
# Epoch [37/50], Train Loss: 1.6042, Train Acc: 42.86%, Val Loss: 1.4093, Val Acc: 43.95%
# Epoch [38/50], Train Loss: 1.5871, Train Acc: 80.00%, Val Loss: 1.0608, Val Acc: 57.41%
# Epoch [39/50], Train Loss: 1.5406, Train Acc: 71.43%, Val Loss: 1.2208, Val Acc: 52.78%
# Epoch [40/50], Train Loss: 1.5247, Train Acc: 73.81%, Val Loss: 1.2201, Val Acc: 47.69%
# Epoch [41/50], Train Loss: 1.5019, Train Acc: 70.83%, Val Loss: 1.0984, Val Acc: 48.06%
# Epoch [42/50], Train Loss: 1.4877, Train Acc: 85.71%, Val Loss: 1.3376, Val Acc: 56.17%
# Epoch [43/50], Train Loss: 1.4712, Train Acc: 83.33%, Val Loss: 1.1348, Val Acc: 61.67%
# Epoch [44/50], Train Loss: 1.4346, Train Acc: 50.00%, Val Loss: 1.2310, Val Acc: 48.33%
# Epoch [45/50], Train Loss: 1.4349, Train Acc: 64.29%, Val Loss: 1.6206, Val Acc: 50.74%
# Epoch [46/50], Train Loss: 1.4657, Train Acc: 50.00%, Val Loss: 1.2213, Val Acc: 48.07%
# Epoch [47/50], Train Loss: 1.4056, Train Acc: 35.71%, Val Loss: 1.3487, Val Acc: 46.46%
# Epoch [48/50], Train Loss: 1.4409, Train Acc: 81.25%, Val Loss: 1.2580, Val Acc: 45.56%
# Epoch [49/50], Train Loss: 1.4090, Train Acc: 74.44%, Val Loss: 1.1072, Val Acc: 51.11%
# Epoch [50/50], Train Loss: 1.3940, Train Acc: 66.67%, Val Loss: 1.1473, Val Acc: 56.88%
# F1 Score:  0.5787740751837426
# B_acc:  0.5522045855379188
# Best model has index  0
#
# Epoch [1/50], Train Loss: 4.2479, Train Acc: 9.52%, Val Loss: 2.1305, Val Acc: 20.31%
# Epoch [2/50], Train Loss: 3.9976, Train Acc: 26.04%, Val Loss: 2.0768, Val Acc: 10.94%
# Epoch [3/50], Train Loss: 3.8099, Train Acc: 14.29%, Val Loss: 2.0604, Val Acc: 19.44%
# Epoch [4/50], Train Loss: 3.6530, Train Acc: 16.67%, Val Loss: 1.9877, Val Acc: 25.00%
# Epoch [5/50], Train Loss: 3.5131, Train Acc: 25.00%, Val Loss: 1.9111, Val Acc: 22.22%
# Epoch [6/50], Train Loss: 3.3552, Train Acc: 25.00%, Val Loss: 1.8227, Val Acc: 20.63%
# Epoch [7/50], Train Loss: 3.2379, Train Acc: 33.33%, Val Loss: 1.7339, Val Acc: 22.92%
# Epoch [8/50], Train Loss: 3.0913, Train Acc: 31.55%, Val Loss: 1.6715, Val Acc: 28.61%
# Epoch [9/50], Train Loss: 2.9789, Train Acc: 33.33%, Val Loss: 1.5225, Val Acc: 30.61%
# Epoch [10/50], Train Loss: 2.8188, Train Acc: 40.62%, Val Loss: 1.3649, Val Acc: 32.80%
# Epoch [11/50], Train Loss: 2.6567, Train Acc: 37.50%, Val Loss: 1.2099, Val Acc: 45.24%
# Epoch [12/50], Train Loss: 2.5317, Train Acc: 50.00%, Val Loss: 1.1582, Val Acc: 41.67%
# Epoch [13/50], Train Loss: 2.4150, Train Acc: 46.43%, Val Loss: 1.0381, Val Acc: 47.92%
# Epoch [14/50], Train Loss: 2.3428, Train Acc: 52.08%, Val Loss: 1.0688, Val Acc: 47.50%
# Epoch [15/50], Train Loss: 2.3267, Train Acc: 55.56%, Val Loss: 1.1412, Val Acc: 43.54%
# Epoch [16/50], Train Loss: 2.2362, Train Acc: 42.86%, Val Loss: 0.9300, Val Acc: 50.00%
# Epoch [17/50], Train Loss: 2.1181, Train Acc: 66.67%, Val Loss: 0.8899, Val Acc: 42.86%
# Epoch [18/50], Train Loss: 2.0660, Train Acc: 57.14%, Val Loss: 0.8462, Val Acc: 36.11%
# Epoch [19/50], Train Loss: 2.0151, Train Acc: 56.25%, Val Loss: 0.8453, Val Acc: 51.39%
# Epoch [20/50], Train Loss: 1.9608, Train Acc: 72.22%, Val Loss: 0.7965, Val Acc: 36.11%
# Epoch [21/50], Train Loss: 1.9165, Train Acc: 67.86%, Val Loss: 0.7779, Val Acc: 57.24%
# Epoch [22/50], Train Loss: 1.8579, Train Acc: 71.43%, Val Loss: 0.8037, Val Acc: 52.71%
# Epoch [23/50], Train Loss: 1.8438, Train Acc: 61.11%, Val Loss: 0.7939, Val Acc: 52.59%
# Epoch [24/50], Train Loss: 1.8059, Train Acc: 75.00%, Val Loss: 0.8351, Val Acc: 54.76%
# Epoch [25/50], Train Loss: 1.8163, Train Acc: 61.90%, Val Loss: 0.7996, Val Acc: 45.46%
# Epoch [26/50], Train Loss: 1.7655, Train Acc: 76.19%, Val Loss: 0.7738, Val Acc: 72.99%
# Epoch [27/50], Train Loss: 1.7113, Train Acc: 55.56%, Val Loss: 0.7672, Val Acc: 49.38%
# Epoch [28/50], Train Loss: 1.6682, Train Acc: 80.56%, Val Loss: 0.8805, Val Acc: 71.55%
# Epoch [29/50], Train Loss: 1.7350, Train Acc: 46.43%, Val Loss: 0.7064, Val Acc: 62.38%
# Epoch [30/50], Train Loss: 1.6415, Train Acc: 63.89%, Val Loss: 0.6884, Val Acc: 60.71%
# Epoch [31/50], Train Loss: 1.6290, Train Acc: 62.50%, Val Loss: 0.7047, Val Acc: 58.33%
# Epoch [32/50], Train Loss: 1.6209, Train Acc: 80.00%, Val Loss: 1.1200, Val Acc: 54.64%
# Epoch [33/50], Train Loss: 1.6601, Train Acc: 56.25%, Val Loss: 0.7167, Val Acc: 72.92%
# Epoch [34/50], Train Loss: 1.5947, Train Acc: 90.48%, Val Loss: 0.6489, Val Acc: 55.83%
# Epoch [35/50], Train Loss: 1.5561, Train Acc: 62.50%, Val Loss: 0.6451, Val Acc: 64.58%
# Epoch [36/50], Train Loss: 1.5259, Train Acc: 91.67%, Val Loss: 0.7737, Val Acc: 73.96%
# Epoch [37/50], Train Loss: 1.5355, Train Acc: 52.38%, Val Loss: 0.6597, Val Acc: 54.37%
# Epoch [38/50], Train Loss: 1.5222, Train Acc: 54.76%, Val Loss: 0.9593, Val Acc: 71.85%
# Epoch [39/50], Train Loss: 1.5275, Train Acc: 78.57%, Val Loss: 0.6064, Val Acc: 68.30%
# Epoch [40/50], Train Loss: 1.4654, Train Acc: 76.19%, Val Loss: 0.6575, Val Acc: 73.54%
# Epoch [41/50], Train Loss: 1.4418, Train Acc: 71.43%, Val Loss: 0.6670, Val Acc: 63.93%
# Epoch [42/50], Train Loss: 1.4229, Train Acc: 100.00%, Val Loss: 0.7081, Val Acc: 57.86%
# Epoch [43/50], Train Loss: 1.4550, Train Acc: 80.00%, Val Loss: 0.7054, Val Acc: 65.12%
# Epoch [44/50], Train Loss: 1.4974, Train Acc: 83.33%, Val Loss: 0.7338, Val Acc: 58.33%
# Epoch [45/50], Train Loss: 1.4210, Train Acc: 67.86%, Val Loss: 0.6271, Val Acc: 67.50%
# Epoch [46/50], Train Loss: 1.3800, Train Acc: 75.00%, Val Loss: 0.6414, Val Acc: 77.78%
# Epoch [47/50], Train Loss: 1.3446, Train Acc: 100.00%, Val Loss: 0.6834, Val Acc: 76.34%
# Epoch [48/50], Train Loss: 1.3896, Train Acc: 47.92%, Val Loss: 0.7032, Val Acc: 77.78%
# Epoch [49/50], Train Loss: 1.4106, Train Acc: 85.71%, Val Loss: 0.6494, Val Acc: 72.92%
# Epoch [50/50], Train Loss: 1.3036, Train Acc: 85.71%, Val Loss: 0.6247, Val Acc: 70.42%
# F1 Score:  0.7877379553101115
# B_acc:  0.7195835029168363
# Best model has index  0
#
# Epoch [1/50], Train Loss: 4.2232, Train Acc: 27.98%, Val Loss: 2.1734, Val Acc: 10.37%
# Epoch [2/50], Train Loss: 3.9844, Train Acc: 20.83%, Val Loss: 2.1654, Val Acc: 13.04%
# Epoch [3/50], Train Loss: 3.8033, Train Acc: 12.50%, Val Loss: 2.1354, Val Acc: 7.54%
# Epoch [4/50], Train Loss: 3.6474, Train Acc: 30.71%, Val Loss: 2.0945, Val Acc: 24.65%
# Epoch [5/50], Train Loss: 3.5120, Train Acc: 8.33%, Val Loss: 2.0407, Val Acc: 10.19%
# Epoch [6/50], Train Loss: 3.3439, Train Acc: 23.81%, Val Loss: 1.9771, Val Acc: 25.00%
# Epoch [7/50], Train Loss: 3.2128, Train Acc: 16.67%, Val Loss: 1.9050, Val Acc: 22.92%
# Epoch [8/50], Train Loss: 3.0599, Train Acc: 50.00%, Val Loss: 1.8045, Val Acc: 32.50%
# Epoch [9/50], Train Loss: 2.9164, Train Acc: 21.43%, Val Loss: 1.7178, Val Acc: 29.14%
# Epoch [10/50], Train Loss: 2.7766, Train Acc: 42.86%, Val Loss: 1.6269, Val Acc: 31.11%
# Epoch [11/50], Train Loss: 2.7004, Train Acc: 27.38%, Val Loss: 1.5207, Val Acc: 44.38%
# Epoch [12/50], Train Loss: 2.5593, Train Acc: 38.89%, Val Loss: 1.4732, Val Acc: 39.29%
# Epoch [13/50], Train Loss: 2.4553, Train Acc: 77.78%, Val Loss: 1.4109, Val Acc: 52.50%
# Epoch [14/50], Train Loss: 2.3729, Train Acc: 55.56%, Val Loss: 1.3983, Val Acc: 40.62%
# Epoch [15/50], Train Loss: 2.3544, Train Acc: 40.62%, Val Loss: 1.2754, Val Acc: 45.83%
# Epoch [16/50], Train Loss: 2.2577, Train Acc: 42.86%, Val Loss: 1.2051, Val Acc: 46.88%
# Epoch [17/50], Train Loss: 2.1377, Train Acc: 50.00%, Val Loss: 1.1509, Val Acc: 44.44%
# Epoch [18/50], Train Loss: 2.0874, Train Acc: 45.83%, Val Loss: 1.0946, Val Acc: 41.85%
# Epoch [19/50], Train Loss: 2.0376, Train Acc: 50.00%, Val Loss: 1.0656, Val Acc: 46.30%
# Epoch [20/50], Train Loss: 2.0262, Train Acc: 50.00%, Val Loss: 1.1040, Val Acc: 48.15%
# Epoch [21/50], Train Loss: 1.9987, Train Acc: 57.14%, Val Loss: 1.0513, Val Acc: 54.37%
# Epoch [22/50], Train Loss: 1.9414, Train Acc: 64.29%, Val Loss: 1.0837, Val Acc: 42.22%
# Epoch [23/50], Train Loss: 1.8921, Train Acc: 59.17%, Val Loss: 0.9852, Val Acc: 67.86%
# Epoch [24/50], Train Loss: 1.9374, Train Acc: 43.75%, Val Loss: 1.1849, Val Acc: 44.44%
# Epoch [25/50], Train Loss: 1.8485, Train Acc: 50.00%, Val Loss: 0.9664, Val Acc: 45.37%
# Epoch [26/50], Train Loss: 1.7909, Train Acc: 80.00%, Val Loss: 0.9345, Val Acc: 73.81%
# Epoch [27/50], Train Loss: 1.7475, Train Acc: 66.67%, Val Loss: 1.0463, Val Acc: 50.00%
# Epoch [28/50], Train Loss: 1.7525, Train Acc: 66.67%, Val Loss: 0.9985, Val Acc: 55.56%
# Epoch [29/50], Train Loss: 1.7113, Train Acc: 77.78%, Val Loss: 0.8690, Val Acc: 67.92%
# Epoch [30/50], Train Loss: 1.7052, Train Acc: 41.67%, Val Loss: 0.9132, Val Acc: 57.22%
# Epoch [31/50], Train Loss: 1.6600, Train Acc: 57.14%, Val Loss: 0.8573, Val Acc: 52.60%
# Epoch [32/50], Train Loss: 1.6272, Train Acc: 62.50%, Val Loss: 0.8659, Val Acc: 65.62%
# Epoch [33/50], Train Loss: 1.6038, Train Acc: 87.50%, Val Loss: 0.8397, Val Acc: 57.22%
# Epoch [34/50], Train Loss: 1.5939, Train Acc: 58.33%, Val Loss: 0.8300, Val Acc: 77.71%
# Epoch [35/50], Train Loss: 1.6197, Train Acc: 33.33%, Val Loss: 0.7740, Val Acc: 65.83%
# Epoch [36/50], Train Loss: 1.5594, Train Acc: 60.00%, Val Loss: 0.9047, Val Acc: 59.07%
# Epoch [37/50], Train Loss: 1.6230, Train Acc: 67.86%, Val Loss: 1.0223, Val Acc: 65.62%
# Epoch [38/50], Train Loss: 1.6348, Train Acc: 54.17%, Val Loss: 0.8070, Val Acc: 70.83%
# Epoch [39/50], Train Loss: 1.7012, Train Acc: 69.44%, Val Loss: 0.8862, Val Acc: 76.19%
# Epoch [40/50], Train Loss: 1.5669, Train Acc: 83.33%, Val Loss: 0.7436, Val Acc: 83.33%
# Epoch [41/50], Train Loss: 1.4997, Train Acc: 83.33%, Val Loss: 0.8569, Val Acc: 53.89%
# Epoch [42/50], Train Loss: 1.5190, Train Acc: 61.90%, Val Loss: 0.7144, Val Acc: 75.00%
# Epoch [43/50], Train Loss: 1.4812, Train Acc: 83.33%, Val Loss: 0.7504, Val Acc: 72.50%
# Epoch [44/50], Train Loss: 1.4733, Train Acc: 71.88%, Val Loss: 0.6684, Val Acc: 68.75%
# Epoch [45/50], Train Loss: 1.4583, Train Acc: 78.57%, Val Loss: 0.6852, Val Acc: 71.88%
# Epoch [46/50], Train Loss: 1.4575, Train Acc: 75.00%, Val Loss: 0.7234, Val Acc: 72.08%
# Epoch [47/50], Train Loss: 1.3965, Train Acc: 62.50%, Val Loss: 0.7718, Val Acc: 70.62%
# Epoch [48/50], Train Loss: 1.3725, Train Acc: 87.50%, Val Loss: 0.7719, Val Acc: 76.88%
# Epoch [49/50], Train Loss: 1.4674, Train Acc: 80.21%, Val Loss: 0.7868, Val Acc: 73.12%
# Epoch [50/50], Train Loss: 1.4029, Train Acc: 71.43%, Val Loss: 0.6587, Val Acc: 69.38%
# F1 Score:  0.7525181690679587
# B_acc:  0.6398108064774731
# Best model has index  0
#
# Epoch [1/50], Train Loss: 4.2448, Train Acc: 14.29%, Val Loss: 2.1632, Val Acc: 15.56%
# Epoch [2/50], Train Loss: 3.9899, Train Acc: 2.86%, Val Loss: 2.1471, Val Acc: 11.85%
# Epoch [3/50], Train Loss: 3.7986, Train Acc: 25.00%, Val Loss: 2.1236, Val Acc: 11.16%
# Epoch [4/50], Train Loss: 3.6543, Train Acc: 21.43%, Val Loss: 2.0791, Val Acc: 21.25%
# Epoch [5/50], Train Loss: 3.5215, Train Acc: 7.14%, Val Loss: 2.0323, Val Acc: 15.21%
# Epoch [6/50], Train Loss: 3.3780, Train Acc: 32.14%, Val Loss: 1.9343, Val Acc: 15.24%
# Epoch [7/50], Train Loss: 3.2420, Train Acc: 38.89%, Val Loss: 1.9062, Val Acc: 16.67%
# Epoch [8/50], Train Loss: 3.1139, Train Acc: 34.17%, Val Loss: 1.8965, Val Acc: 21.88%
# Epoch [9/50], Train Loss: 2.9926, Train Acc: 38.10%, Val Loss: 1.7288, Val Acc: 37.50%
# Epoch [10/50], Train Loss: 2.8602, Train Acc: 35.71%, Val Loss: 1.6489, Val Acc: 35.74%
# Epoch [11/50], Train Loss: 2.6866, Train Acc: 55.00%, Val Loss: 1.5894, Val Acc: 35.00%
# Epoch [12/50], Train Loss: 2.5350, Train Acc: 38.89%, Val Loss: 1.4568, Val Acc: 38.61%
# Epoch [13/50], Train Loss: 2.4049, Train Acc: 46.67%, Val Loss: 1.4054, Val Acc: 32.78%
# Epoch [14/50], Train Loss: 2.3346, Train Acc: 62.50%, Val Loss: 1.3946, Val Acc: 34.26%
# Epoch [15/50], Train Loss: 2.2810, Train Acc: 27.38%, Val Loss: 1.4066, Val Acc: 42.41%
# Epoch [16/50], Train Loss: 2.2226, Train Acc: 42.86%, Val Loss: 1.3407, Val Acc: 40.56%
# Epoch [17/50], Train Loss: 2.0872, Train Acc: 64.29%, Val Loss: 1.3289, Val Acc: 41.67%
# Epoch [18/50], Train Loss: 2.0396, Train Acc: 44.44%, Val Loss: 1.3005, Val Acc: 32.44%
# Epoch [19/50], Train Loss: 2.0435, Train Acc: 66.67%, Val Loss: 1.3388, Val Acc: 42.59%
# Epoch [20/50], Train Loss: 1.9911, Train Acc: 54.76%, Val Loss: 1.3859, Val Acc: 38.39%
# Epoch [21/50], Train Loss: 1.9216, Train Acc: 64.29%, Val Loss: 1.3216, Val Acc: 53.75%
# Epoch [22/50], Train Loss: 1.8951, Train Acc: 53.33%, Val Loss: 1.2206, Val Acc: 59.72%
# Epoch [23/50], Train Loss: 1.8407, Train Acc: 72.22%, Val Loss: 1.2386, Val Acc: 43.06%
# Epoch [24/50], Train Loss: 1.8283, Train Acc: 37.50%, Val Loss: 1.1732, Val Acc: 58.95%
# Epoch [25/50], Train Loss: 1.7818, Train Acc: 60.71%, Val Loss: 1.2459, Val Acc: 38.52%
# Epoch [26/50], Train Loss: 1.7857, Train Acc: 41.67%, Val Loss: 1.3668, Val Acc: 49.07%
# Epoch [27/50], Train Loss: 1.7647, Train Acc: 66.67%, Val Loss: 1.2823, Val Acc: 47.09%
# Epoch [28/50], Train Loss: 1.6963, Train Acc: 66.67%, Val Loss: 1.3806, Val Acc: 35.32%
# Epoch [29/50], Train Loss: 1.6781, Train Acc: 66.67%, Val Loss: 1.2119, Val Acc: 39.63%
# Epoch [30/50], Train Loss: 1.6510, Train Acc: 78.57%, Val Loss: 1.1934, Val Acc: 35.19%
# Epoch [31/50], Train Loss: 1.6636, Train Acc: 85.71%, Val Loss: 1.1732, Val Acc: 54.96%
# Epoch [32/50], Train Loss: 1.6549, Train Acc: 55.00%, Val Loss: 1.1577, Val Acc: 43.70%
# Epoch [33/50], Train Loss: 1.6158, Train Acc: 76.19%, Val Loss: 1.1581, Val Acc: 51.85%
# Epoch [34/50], Train Loss: 1.5752, Train Acc: 57.14%, Val Loss: 1.3390, Val Acc: 47.92%
# Epoch [35/50], Train Loss: 1.5704, Train Acc: 61.11%, Val Loss: 1.1781, Val Acc: 38.10%
# Epoch [36/50], Train Loss: 1.5247, Train Acc: 64.29%, Val Loss: 1.3025, Val Acc: 39.68%
# Epoch [37/50], Train Loss: 1.5322, Train Acc: 56.25%, Val Loss: 1.1815, Val Acc: 58.93%
# Epoch [38/50], Train Loss: 1.5559, Train Acc: 66.67%, Val Loss: 1.1613, Val Acc: 47.78%
# Epoch [39/50], Train Loss: 1.5027, Train Acc: 80.95%, Val Loss: 1.1642, Val Acc: 55.06%
# Epoch [40/50], Train Loss: 1.4942, Train Acc: 61.11%, Val Loss: 1.4192, Val Acc: 51.75%
# Epoch [41/50], Train Loss: 1.4601, Train Acc: 71.43%, Val Loss: 1.0425, Val Acc: 50.93%
# Epoch [42/50], Train Loss: 1.4558, Train Acc: 87.50%, Val Loss: 1.3638, Val Acc: 48.15%
# Epoch [43/50], Train Loss: 1.4117, Train Acc: 83.33%, Val Loss: 1.1746, Val Acc: 60.42%
# Epoch [44/50], Train Loss: 1.4923, Train Acc: 62.50%, Val Loss: 1.0794, Val Acc: 62.96%
# Epoch [45/50], Train Loss: 1.4353, Train Acc: 62.50%, Val Loss: 1.2445, Val Acc: 51.11%
# Epoch [46/50], Train Loss: 1.4652, Train Acc: 62.96%, Val Loss: 1.0947, Val Acc: 53.33%
# Epoch [47/50], Train Loss: 1.4360, Train Acc: 50.00%, Val Loss: 1.1708, Val Acc: 48.61%
# Epoch [48/50], Train Loss: 1.4105, Train Acc: 85.71%, Val Loss: 1.1180, Val Acc: 59.13%
# Epoch [49/50], Train Loss: 1.4046, Train Acc: 71.88%, Val Loss: 1.1456, Val Acc: 55.56%
# Epoch [50/50], Train Loss: 1.3820, Train Acc: 60.71%, Val Loss: 1.1025, Val Acc: 59.26%
# F1 Score:  0.600473324072645
# B_acc:  0.5614348614348614
# Best model has index  0
#
# Epoch [1/50], Train Loss: 2.1348, Train Acc: 0.00%, Val Loss: 0.1075, Val Acc: 11.11%
# Epoch [2/50], Train Loss: 1.8636, Train Acc: 16.67%, Val Loss: 0.1031, Val Acc: 11.85%
# Epoch [3/50], Train Loss: 1.6813, Train Acc: 25.00%, Val Loss: 0.1019, Val Acc: 11.51%
# Epoch [4/50], Train Loss: 1.5526, Train Acc: 22.86%, Val Loss: 0.1000, Val Acc: 19.58%
# Epoch [5/50], Train Loss: 1.4524, Train Acc: 25.00%, Val Loss: 0.0989, Val Acc: 13.58%
# Epoch [6/50], Train Loss: 1.3671, Train Acc: 14.58%, Val Loss: 0.0980, Val Acc: 13.89%
# Epoch [7/50], Train Loss: 1.2902, Train Acc: 16.67%, Val Loss: 0.0969, Val Acc: 11.46%
# Epoch [8/50], Train Loss: 1.2191, Train Acc: 15.71%, Val Loss: 0.0964, Val Acc: 15.91%
# Epoch [9/50], Train Loss: 1.1521, Train Acc: 40.00%, Val Loss: 0.0956, Val Acc: 12.35%
# Epoch [10/50], Train Loss: 1.0894, Train Acc: 11.11%, Val Loss: 0.0964, Val Acc: 18.15%
# Epoch [11/50], Train Loss: 1.0302, Train Acc: 9.52%, Val Loss: 0.0959, Val Acc: 11.11%
# Epoch [12/50], Train Loss: 0.9749, Train Acc: 23.81%, Val Loss: 0.0957, Val Acc: 11.90%
# Epoch [13/50], Train Loss: 0.9211, Train Acc: 14.29%, Val Loss: 0.0957, Val Acc: 19.44%
# Epoch [14/50], Train Loss: 0.8706, Train Acc: 15.48%, Val Loss: 0.0957, Val Acc: 18.04%
# Epoch [15/50], Train Loss: 0.8234, Train Acc: 22.86%, Val Loss: 0.0954, Val Acc: 15.38%
# Epoch [16/50], Train Loss: 0.7789, Train Acc: 20.83%, Val Loss: 0.0954, Val Acc: 20.45%
# Epoch [17/50], Train Loss: 0.7365, Train Acc: 17.14%, Val Loss: 0.0957, Val Acc: 14.63%
# Epoch [18/50], Train Loss: 0.6963, Train Acc: 33.33%, Val Loss: 0.0954, Val Acc: 16.05%
# Epoch [19/50], Train Loss: 0.6589, Train Acc: 22.62%, Val Loss: 0.0955, Val Acc: 14.96%
# Epoch [20/50], Train Loss: 0.6233, Train Acc: 41.67%, Val Loss: 0.0956, Val Acc: 12.65%
# Epoch [21/50], Train Loss: 0.5900, Train Acc: 13.89%, Val Loss: 0.0956, Val Acc: 15.31%
# Epoch [22/50], Train Loss: 0.5583, Train Acc: 29.76%, Val Loss: 0.0955, Val Acc: 12.04%
# Epoch [23/50], Train Loss: 0.5285, Train Acc: 23.33%, Val Loss: 0.0957, Val Acc: 8.15%
# Epoch [24/50], Train Loss: 0.5009, Train Acc: 14.29%, Val Loss: 0.0958, Val Acc: 14.14%
# Epoch [25/50], Train Loss: 0.4745, Train Acc: 22.22%, Val Loss: 0.0959, Val Acc: 19.44%
# Epoch [26/50], Train Loss: 0.4497, Train Acc: 3.57%, Val Loss: 0.0957, Val Acc: 14.63%
# Epoch [27/50], Train Loss: 0.4262, Train Acc: 27.78%, Val Loss: 0.0959, Val Acc: 12.96%
# Epoch [28/50], Train Loss: 0.4044, Train Acc: 17.86%, Val Loss: 0.0959, Val Acc: 12.41%
# Epoch [29/50], Train Loss: 0.3837, Train Acc: 23.33%, Val Loss: 0.0959, Val Acc: 19.38%
# Epoch [30/50], Train Loss: 0.3643, Train Acc: 19.05%, Val Loss: 0.0959, Val Acc: 22.19%
# Epoch [31/50], Train Loss: 0.3462, Train Acc: 23.33%, Val Loss: 0.0960, Val Acc: 14.81%
# Epoch [32/50], Train Loss: 0.3293, Train Acc: 9.38%, Val Loss: 0.0959, Val Acc: 16.67%
# Epoch [33/50], Train Loss: 0.3134, Train Acc: 29.17%, Val Loss: 0.0961, Val Acc: 10.71%
# Epoch [34/50], Train Loss: 0.2983, Train Acc: 3.33%, Val Loss: 0.0961, Val Acc: 10.48%
# Epoch [35/50], Train Loss: 0.2842, Train Acc: 18.75%, Val Loss: 0.0961, Val Acc: 21.67%
# Epoch [36/50], Train Loss: 0.2710, Train Acc: 19.05%, Val Loss: 0.0962, Val Acc: 18.65%
# Epoch [37/50], Train Loss: 0.2586, Train Acc: 8.00%, Val Loss: 0.0961, Val Acc: 13.74%
# ...
# Epoch [23/50], Train Loss: 0.3350, Train Acc: 14.29%, Val Loss: 0.1004, Val Acc: 14.29%
# Epoch [24/50], Train Loss: 0.3135, Train Acc: 14.29%, Val Loss: 0.1004, Val Acc: 11.11%
# Epoch [25/50], Train Loss: 0.2934, Train Acc: 12.50%, Val Loss: 0.1003, Val Acc: 12.50%
# Epoch [26/50], Train Loss: 0.2747, Train Acc: 12.50%, Val Loss: 0.1004, Val Acc: 11.11%
# Epoch [27/50], Train Loss: 0.2574, Train Acc: 16.67%, Val Loss: 0.1003, Val Acc: 12.50%
# Epoch [28/50], Train Loss: 0.2414, Train Acc: 16.67%, Val Loss: 0.1001, Val Acc: 12.50%
# Epoch [29/50], Train Loss: 0.2264, Train Acc: 16.67%, Val Loss: 0.1001, Val Acc: 11.11%
# Epoch [30/50], Train Loss: 0.2127, Train Acc: 20.00%, Val Loss: 0.0998, Val Acc: 11.11%
# Epoch [31/50], Train Loss: 0.2005, Train Acc: 0.00%, Val Loss: 0.0999, Val Acc: 12.50%
# Epoch [32/50], Train Loss: 0.1889, Train Acc: 16.67%, Val Loss: 0.0998, Val Acc: 11.11%
# Epoch [33/50], Train Loss: 0.1785, Train Acc: 14.29%, Val Loss: 0.0997, Val Acc: 12.50%
# Epoch [34/50], Train Loss: 0.1689, Train Acc: 14.29%, Val Loss: 0.0998, Val Acc: 11.11%
# Epoch [35/50], Train Loss: 0.1602, Train Acc: 16.67%, Val Loss: 0.0997, Val Acc: 12.50%
# Epoch [36/50], Train Loss: 0.1524, Train Acc: 12.50%, Val Loss: 0.0997, Val Acc: 12.50%
# Epoch [37/50], Train Loss: 0.1454, Train Acc: 14.29%, Val Loss: 0.0996, Val Acc: 12.50%
# Epoch [38/50], Train Loss: 0.1393, Train Acc: 0.00%, Val Loss: 0.0996, Val Acc: 11.11%
# Epoch [39/50], Train Loss: 0.1336, Train Acc: 14.29%, Val Loss: 0.0996, Val Acc: 12.50%
# Epoch [40/50], Train Loss: 0.1287, Train Acc: 14.29%, Val Loss: 0.0995, Val Acc: 11.11%
# Epoch [41/50], Train Loss: 0.1242, Train Acc: 14.29%, Val Loss: 0.0995, Val Acc: 11.11%
# Epoch [42/50], Train Loss: 0.1205, Train Acc: 14.29%, Val Loss: 0.0994, Val Acc: 12.50%
# Epoch [43/50], Train Loss: 0.1171, Train Acc: 14.29%, Val Loss: 0.0995, Val Acc: 14.29%
# Epoch [44/50], Train Loss: 0.1143, Train Acc: 12.50%, Val Loss: 0.0995, Val Acc: 11.11%
# Epoch [45/50], Train Loss: 0.1118, Train Acc: 16.67%, Val Loss: 0.0995, Val Acc: 11.11%
# Epoch [46/50], Train Loss: 0.1097, Train Acc: 14.29%, Val Loss: 0.0995, Val Acc: 11.11%
# Epoch [47/50], Train Loss: 0.1079, Train Acc: 16.67%, Val Loss: 0.0995, Val Acc: 12.50%
# Epoch [48/50], Train Loss: 0.1064, Train Acc: 14.29%, Val Loss: 0.0995, Val Acc: 11.11%
# Epoch [49/50], Train Loss: 0.1053, Train Acc: 12.50%, Val Loss: 0.0995, Val Acc: 12.50%
# Epoch [50/50], Train Loss: 0.1041, Train Acc: 14.29%, Val Loss: 0.0995, Val Acc: 11.11%
# F1 Score:  0.02949308755760369
# B_acc:  0.1111111111111111
# Best model has index  0
#
# Epoch [1/50], Train Loss: 1.7729, Train Acc: 23.81%, Val Loss: 0.0999, Val Acc: 15.62%
# Epoch [2/50], Train Loss: 1.4381, Train Acc: 16.67%, Val Loss: 0.0959, Val Acc: 17.20%
# Epoch [3/50], Train Loss: 1.2923, Train Acc: 26.67%, Val Loss: 0.0955, Val Acc: 28.12%
# Epoch [4/50], Train Loss: 1.1845, Train Acc: 16.67%, Val Loss: 0.0962, Val Acc: 23.96%
# Epoch [5/50], Train Loss: 1.0952, Train Acc: 38.89%, Val Loss: 0.0948, Val Acc: 24.17%
# Epoch [6/50], Train Loss: 1.0168, Train Acc: 27.00%, Val Loss: 0.0936, Val Acc: 27.14%
# Epoch [7/50], Train Loss: 0.9474, Train Acc: 12.50%, Val Loss: 0.0953, Val Acc: 28.12%
# Epoch [8/50], Train Loss: 0.8842, Train Acc: 22.22%, Val Loss: 0.0939, Val Acc: 15.42%
# Epoch [9/50], Train Loss: 0.8259, Train Acc: 16.67%, Val Loss: 0.0939, Val Acc: 29.69%
# Epoch [10/50], Train Loss: 0.7721, Train Acc: 15.62%, Val Loss: 0.0947, Val Acc: 25.00%
# Epoch [11/50], Train Loss: 0.7228, Train Acc: 21.43%, Val Loss: 0.0939, Val Acc: 24.31%
# Epoch [12/50], Train Loss: 0.6769, Train Acc: 16.67%, Val Loss: 0.0953, Val Acc: 23.15%
# Epoch [13/50], Train Loss: 0.6338, Train Acc: 20.00%, Val Loss: 0.0960, Val Acc: 24.11%
# Epoch [14/50], Train Loss: 0.5934, Train Acc: 24.17%, Val Loss: 0.0954, Val Acc: 22.86%
# Epoch [15/50], Train Loss: 0.5557, Train Acc: 33.33%, Val Loss: 0.0942, Val Acc: 27.58%
# Epoch [16/50], Train Loss: 0.5206, Train Acc: 12.50%, Val Loss: 0.0942, Val Acc: 25.48%
# Epoch [17/50], Train Loss: 0.4878, Train Acc: 17.86%, Val Loss: 0.0941, Val Acc: 19.73%
# Epoch [18/50], Train Loss: 0.4566, Train Acc: 4.17%, Val Loss: 0.0948, Val Acc: 32.38%
# Epoch [19/50], Train Loss: 0.4275, Train Acc: 25.00%, Val Loss: 0.0947, Val Acc: 26.30%
# Epoch [20/50], Train Loss: 0.4002, Train Acc: 10.71%, Val Loss: 0.0949, Val Acc: 20.63%
# Epoch [21/50], Train Loss: 0.3749, Train Acc: 5.00%, Val Loss: 0.0957, Val Acc: 11.42%
# Epoch [22/50], Train Loss: 0.3512, Train Acc: 32.14%, Val Loss: 0.0955, Val Acc: 19.27%
# Epoch [23/50], Train Loss: 0.3291, Train Acc: 15.62%, Val Loss: 0.0955, Val Acc: 16.67%
# Epoch [24/50], Train Loss: 0.3086, Train Acc: 11.46%, Val Loss: 0.0958, Val Acc: 12.50%
# Epoch [25/50], Train Loss: 0.2891, Train Acc: 22.22%, Val Loss: 0.0955, Val Acc: 17.86%
# Epoch [26/50], Train Loss: 0.2712, Train Acc: 7.50%, Val Loss: 0.0957, Val Acc: 11.11%
# Epoch [27/50], Train Loss: 0.2547, Train Acc: 8.57%, Val Loss: 0.0961, Val Acc: 12.50%
# Epoch [28/50], Train Loss: 0.2393, Train Acc: 18.75%, Val Loss: 0.0958, Val Acc: 18.75%
# Epoch [29/50], Train Loss: 0.2250, Train Acc: 14.29%, Val Loss: 0.0960, Val Acc: 12.50%
# Epoch [30/50], Train Loss: 0.2116, Train Acc: 14.29%, Val Loss: 0.0961, Val Acc: 12.50%
# Epoch [31/50], Train Loss: 0.1995, Train Acc: 12.50%, Val Loss: 0.0961, Val Acc: 14.29%
# Epoch [32/50], Train Loss: 0.1884, Train Acc: 14.29%, Val Loss: 0.0962, Val Acc: 12.50%
# Epoch [33/50], Train Loss: 0.1782, Train Acc: 16.67%, Val Loss: 0.0962, Val Acc: 12.50%
# Epoch [34/50], Train Loss: 0.1688, Train Acc: 16.67%, Val Loss: 0.0960, Val Acc: 11.11%
# Epoch [35/50], Train Loss: 0.1605, Train Acc: 16.67%, Val Loss: 0.0961, Val Acc: 12.50%
# Epoch [36/50], Train Loss: 0.1530, Train Acc: 12.50%, Val Loss: 0.0961, Val Acc: 14.29%
# Epoch [37/50], Train Loss: 0.1461, Train Acc: 20.00%, Val Loss: 0.0956, Val Acc: 11.11%
# Epoch [38/50], Train Loss: 0.1401, Train Acc: 14.29%, Val Loss: 0.0957, Val Acc: 11.11%
# Epoch [39/50], Train Loss: 0.1348, Train Acc: 16.67%, Val Loss: 0.0955, Val Acc: 14.29%
# Epoch [40/50], Train Loss: 0.1299, Train Acc: 16.67%, Val Loss: 0.0956, Val Acc: 11.11%
# Epoch [41/50], Train Loss: 0.1256, Train Acc: 16.67%, Val Loss: 0.0957, Val Acc: 11.11%
# Epoch [42/50], Train Loss: 0.1222, Train Acc: 11.11%, Val Loss: 0.0957, Val Acc: 12.50%
# Epoch [43/50], Train Loss: 0.1186, Train Acc: 25.00%, Val Loss: 0.0956, Val Acc: 14.29%
# Epoch [44/50], Train Loss: 0.1159, Train Acc: 16.67%, Val Loss: 0.0955, Val Acc: 11.11%
# Epoch [45/50], Train Loss: 0.1138, Train Acc: 0.00%, Val Loss: 0.0955, Val Acc: 14.29%
# Epoch [46/50], Train Loss: 0.1115, Train Acc: 14.29%, Val Loss: 0.0955, Val Acc: 11.11%
# Epoch [47/50], Train Loss: 0.1097, Train Acc: 20.00%, Val Loss: 0.0954, Val Acc: 14.29%
# Epoch [48/50], Train Loss: 0.1084, Train Acc: 16.67%, Val Loss: 0.0954, Val Acc: 11.11%
# Epoch [49/50], Train Loss: 0.1072, Train Acc: 16.67%, Val Loss: 0.0954, Val Acc: 12.50%
# Epoch [50/50], Train Loss: 0.1063, Train Acc: 14.29%, Val Loss: 0.0953, Val Acc: 14.29%
# F1 Score:  0.09426057813154588
# B_acc:  0.1111111111111111
# Best model has index  0
#
# Epoch [1/50], Train Loss: 1.7832, Train Acc: 26.67%, Val Loss: 0.1053, Val Acc: 12.50%
# Epoch [2/50], Train Loss: 1.4424, Train Acc: 21.43%, Val Loss: 0.1012, Val Acc: 15.87%
# Epoch [3/50], Train Loss: 1.2950, Train Acc: 18.75%, Val Loss: 0.0993, Val Acc: 20.37%
# Epoch [4/50], Train Loss: 1.1868, Train Acc: 12.50%, Val Loss: 0.0996, Val Acc: 22.22%
# Epoch [5/50], Train Loss: 1.0967, Train Acc: 19.05%, Val Loss: 0.0993, Val Acc: 17.22%
# Epoch [6/50], Train Loss: 1.0188, Train Acc: 21.43%, Val Loss: 0.0991, Val Acc: 16.67%
# Epoch [7/50], Train Loss: 0.9484, Train Acc: 18.75%, Val Loss: 0.1003, Val Acc: 18.52%
# Epoch [8/50], Train Loss: 0.8853, Train Acc: 17.86%, Val Loss: 0.0981, Val Acc: 13.33%
# Epoch [9/50], Train Loss: 0.8270, Train Acc: 17.50%, Val Loss: 0.0986, Val Acc: 14.81%
# Epoch [10/50], Train Loss: 0.7743, Train Acc: 16.67%, Val Loss: 0.0980, Val Acc: 14.81%
# Epoch [11/50], Train Loss: 0.7241, Train Acc: 18.75%, Val Loss: 0.0993, Val Acc: 15.62%
# Epoch [12/50], Train Loss: 0.6783, Train Acc: 25.00%, Val Loss: 0.0997, Val Acc: 16.67%
# Epoch [13/50], Train Loss: 0.6350, Train Acc: 29.17%, Val Loss: 0.0978, Val Acc: 17.92%
# Epoch [14/50], Train Loss: 0.5946, Train Acc: 28.57%, Val Loss: 0.0989, Val Acc: 20.00%
# Epoch [15/50], Train Loss: 0.5575, Train Acc: 16.67%, Val Loss: 0.0982, Val Acc: 18.75%
# Epoch [16/50], Train Loss: 0.5221, Train Acc: 10.71%, Val Loss: 0.0989, Val Acc: 16.67%
# Epoch [17/50], Train Loss: 0.4888, Train Acc: 30.00%, Val Loss: 0.0977, Val Acc: 12.96%
# Epoch [18/50], Train Loss: 0.4577, Train Acc: 25.00%, Val Loss: 0.0979, Val Acc: 16.25%
# Epoch [19/50], Train Loss: 0.4287, Train Acc: 21.43%, Val Loss: 0.0986, Val Acc: 13.89%
# Epoch [20/50], Train Loss: 0.4017, Train Acc: 28.57%, Val Loss: 0.0981, Val Acc: 20.00%
# Epoch [21/50], Train Loss: 0.3760, Train Acc: 29.17%, Val Loss: 0.0983, Val Acc: 19.64%
# Epoch [22/50], Train Loss: 0.3524, Train Acc: 16.67%, Val Loss: 0.0982, Val Acc: 22.22%
# Epoch [23/50], Train Loss: 0.3301, Train Acc: 19.05%, Val Loss: 0.0983, Val Acc: 21.88%
# Epoch [24/50], Train Loss: 0.3094, Train Acc: 14.29%, Val Loss: 0.0990, Val Acc: 10.37%
# Epoch [25/50], Train Loss: 0.2903, Train Acc: 23.81%, Val Loss: 0.0983, Val Acc: 15.56%
# Epoch [26/50], Train Loss: 0.2721, Train Acc: 25.00%, Val Loss: 0.0983, Val Acc: 18.52%
# Epoch [27/50], Train Loss: 0.2556, Train Acc: 33.33%, Val Loss: 0.0987, Val Acc: 18.52%
# Epoch [28/50], Train Loss: 0.2406, Train Acc: 14.29%, Val Loss: 0.0987, Val Acc: 13.33%
# Epoch [29/50], Train Loss: 0.2259, Train Acc: 11.11%, Val Loss: 0.0986, Val Acc: 12.50%
# Epoch [30/50], Train Loss: 0.2128, Train Acc: 28.57%, Val Loss: 0.0985, Val Acc: 15.56%
# Epoch [31/50], Train Loss: 0.2008, Train Acc: 12.50%, Val Loss: 0.0992, Val Acc: 11.11%
# Epoch [32/50], Train Loss: 0.1898, Train Acc: 12.50%, Val Loss: 0.0991, Val Acc: 12.50%
# Epoch [33/50], Train Loss: 0.1795, Train Acc: 16.67%, Val Loss: 0.0992, Val Acc: 15.00%
# Epoch [34/50], Train Loss: 0.1700, Train Acc: 16.67%, Val Loss: 0.0992, Val Acc: 11.11%
# Epoch [35/50], Train Loss: 0.1615, Train Acc: 20.00%, Val Loss: 0.0992, Val Acc: 12.50%
# Epoch [36/50], Train Loss: 0.1537, Train Acc: 25.00%, Val Loss: 0.0993, Val Acc: 11.11%
# Epoch [37/50], Train Loss: 0.1471, Train Acc: 11.11%, Val Loss: 0.0997, Val Acc: 12.50%
# Epoch [38/50], Train Loss: 0.1407, Train Acc: 12.50%, Val Loss: 0.0995, Val Acc: 12.50%
# Epoch [39/50], Train Loss: 0.1352, Train Acc: 14.29%, Val Loss: 0.0995, Val Acc: 11.11%
# Epoch [40/50], Train Loss: 0.1303, Train Acc: 16.67%, Val Loss: 0.0994, Val Acc: 11.11%
# Epoch [41/50], Train Loss: 0.1260, Train Acc: 14.29%, Val Loss: 0.0994, Val Acc: 14.29%
# Epoch [42/50], Train Loss: 0.1223, Train Acc: 12.50%, Val Loss: 0.0994, Val Acc: 12.50%
# Epoch [43/50], Train Loss: 0.1190, Train Acc: 14.29%, Val Loss: 0.0993, Val Acc: 11.11%
# Epoch [44/50], Train Loss: 0.1161, Train Acc: 16.67%, Val Loss: 0.0993, Val Acc: 11.11%
# Epoch [45/50], Train Loss: 0.1136, Train Acc: 14.29%, Val Loss: 0.0992, Val Acc: 14.29%
# Epoch [46/50], Train Loss: 0.1115, Train Acc: 12.50%, Val Loss: 0.0992, Val Acc: 12.50%
# Epoch [47/50], Train Loss: 0.1097, Train Acc: 14.29%, Val Loss: 0.0992, Val Acc: 11.11%
# Epoch [48/50], Train Loss: 0.1081, Train Acc: 14.29%, Val Loss: 0.0991, Val Acc: 12.50%
# Epoch [49/50], Train Loss: 0.1067, Train Acc: 16.67%, Val Loss: 0.0991, Val Acc: 11.11%
# Epoch [50/50], Train Loss: 0.1058, Train Acc: 14.29%, Val Loss: 0.0990, Val Acc: 12.50%
# F1 Score:  0.02949308755760369
# B_acc:  0.1111111111111111
# Best model has index  0
#
# Epoch [1/50], Train Loss: 1.7596, Train Acc: 9.52%, Val Loss: 0.1051, Val Acc: 9.72%
# Epoch [2/50], Train Loss: 1.4250, Train Acc: 14.29%, Val Loss: 0.1028, Val Acc: 16.93%
# Epoch [3/50], Train Loss: 1.2797, Train Acc: 28.57%, Val Loss: 0.1061, Val Acc: 10.32%
# Epoch [4/50], Train Loss: 1.1710, Train Acc: 22.50%, Val Loss: 0.1008, Val Acc: 13.10%
# Epoch [5/50], Train Loss: 1.0806, Train Acc: 7.41%, Val Loss: 0.0999, Val Acc: 11.67%
# Epoch [6/50], Train Loss: 1.0021, Train Acc: 9.38%, Val Loss: 0.1001, Val Acc: 7.54%
# Epoch [7/50], Train Loss: 0.9319, Train Acc: 11.11%, Val Loss: 0.1005, Val Acc: 7.50%
# Epoch [8/50], Train Loss: 0.8687, Train Acc: 23.33%, Val Loss: 0.0995, Val Acc: 16.67%
# Epoch [9/50], Train Loss: 0.8108, Train Acc: 10.42%, Val Loss: 0.0986, Val Acc: 13.39%
# Epoch [10/50], Train Loss: 0.7572, Train Acc: 20.83%, Val Loss: 0.0992, Val Acc: 14.55%
# Epoch [11/50], Train Loss: 0.7081, Train Acc: 0.00%, Val Loss: 0.0987, Val Acc: 14.13%
# Epoch [12/50], Train Loss: 0.6622, Train Acc: 23.33%, Val Loss: 0.0986, Val Acc: 12.04%
# Epoch [13/50], Train Loss: 0.6195, Train Acc: 7.14%, Val Loss: 0.0983, Val Acc: 15.00%
# Epoch [14/50], Train Loss: 0.5794, Train Acc: 26.67%, Val Loss: 0.0982, Val Acc: 15.48%
# Epoch [15/50], Train Loss: 0.5420, Train Acc: 6.25%, Val Loss: 0.0984, Val Acc: 16.67%
# Epoch [16/50], Train Loss: 0.5068, Train Acc: 16.67%, Val Loss: 0.0985, Val Acc: 12.50%
# Epoch [17/50], Train Loss: 0.4741, Train Acc: 8.93%, Val Loss: 0.0988, Val Acc: 11.11%
# Epoch [18/50], Train Loss: 0.4433, Train Acc: 25.00%, Val Loss: 0.0995, Val Acc: 7.22%
# Epoch [19/50], Train Loss: 0.4147, Train Acc: 22.22%, Val Loss: 0.0986, Val Acc: 5.56%
# Epoch [20/50], Train Loss: 0.3875, Train Acc: 21.67%, Val Loss: 0.0985, Val Acc: 13.33%
# Epoch [21/50], Train Loss: 0.3625, Train Acc: 14.29%, Val Loss: 0.0986, Val Acc: 11.11%
# Epoch [22/50], Train Loss: 0.3391, Train Acc: 6.67%, Val Loss: 0.0983, Val Acc: 7.44%
# Epoch [23/50], Train Loss: 0.3170, Train Acc: 33.33%, Val Loss: 0.0982, Val Acc: 11.90%
# Epoch [24/50], Train Loss: 0.2967, Train Acc: 0.00%, Val Loss: 0.0981, Val Acc: 14.29%
# Epoch [25/50], Train Loss: 0.2779, Train Acc: 21.43%, Val Loss: 0.0980, Val Acc: 8.33%
# Epoch [26/50], Train Loss: 0.2603, Train Acc: 12.50%, Val Loss: 0.0979, Val Acc: 12.22%
# Epoch [27/50], Train Loss: 0.2440, Train Acc: 4.17%, Val Loss: 0.0977, Val Acc: 10.49%
# Epoch [28/50], Train Loss: 0.2291, Train Acc: 17.71%, Val Loss: 0.0977, Val Acc: 6.48%
# Epoch [29/50], Train Loss: 0.2154, Train Acc: 9.52%, Val Loss: 0.0976, Val Acc: 9.38%
# Epoch [30/50], Train Loss: 0.2027, Train Acc: 10.42%, Val Loss: 0.0977, Val Acc: 11.11%
# Epoch [31/50], Train Loss: 0.1911, Train Acc: 25.00%, Val Loss: 0.0975, Val Acc: 7.41%
# Epoch [32/50], Train Loss: 0.1804, Train Acc: 14.29%, Val Loss: 0.0975, Val Acc: 11.11%
# Epoch [33/50], Train Loss: 0.1707, Train Acc: 9.52%, Val Loss: 0.0975, Val Acc: 11.11%
# Epoch [34/50], Train Loss: 0.1621, Train Acc: 16.67%, Val Loss: 0.0975, Val Acc: 16.25%
# Epoch [35/50], Train Loss: 0.1542, Train Acc: 18.75%, Val Loss: 0.0974, Val Acc: 11.11%
# Epoch [36/50], Train Loss: 0.1469, Train Acc: 14.29%, Val Loss: 0.0974, Val Acc: 11.11%
# Epoch [37/50], Train Loss: 0.1404, Train Acc: 16.67%, Val Loss: 0.0974, Val Acc: 11.11%
# Epoch [38/50], Train Loss: 0.1348, Train Acc: 11.11%, Val Loss: 0.0972, Val Acc: 11.11%
# Epoch [39/50], Train Loss: 0.1295, Train Acc: 25.00%, Val Loss: 0.0972, Val Acc: 12.50%
# Epoch [40/50], Train Loss: 0.1253, Train Acc: 14.29%, Val Loss: 0.0972, Val Acc: 11.11%
# Epoch [41/50], Train Loss: 0.1212, Train Acc: 20.00%, Val Loss: 0.0972, Val Acc: 12.50%
# Epoch [42/50], Train Loss: 0.1179, Train Acc: 16.67%, Val Loss: 0.0972, Val Acc: 11.11%
# Epoch [43/50], Train Loss: 0.1150, Train Acc: 14.29%, Val Loss: 0.0972, Val Acc: 11.11%
# Epoch [44/50], Train Loss: 0.1125, Train Acc: 12.50%, Val Loss: 0.0972, Val Acc: 11.11%
# Epoch [45/50], Train Loss: 0.1103, Train Acc: 16.67%, Val Loss: 0.0971, Val Acc: 11.11%
# Epoch [46/50], Train Loss: 0.1085, Train Acc: 14.29%, Val Loss: 0.0971, Val Acc: 11.11%
# Epoch [47/50], Train Loss: 0.1071, Train Acc: 14.29%, Val Loss: 0.0971, Val Acc: 11.11%
# Epoch [48/50], Train Loss: 0.1058, Train Acc: 14.29%, Val Loss: 0.0972, Val Acc: 12.50%
# Epoch [49/50], Train Loss: 0.1047, Train Acc: 11.11%, Val Loss: 0.0972, Val Acc: 11.11%
# Epoch [50/50], Train Loss: 0.1037, Train Acc: 16.67%, Val Loss: 0.0971, Val Acc: 12.50%
# F1 Score:  0.04480286738351254
# B_acc:  0.1111111111111111
# Best model has index  0

# %%
best_model_v4_sig, _ = Train_K_FOLDS(MLP_v4_sig, 50, 0.0001, 10, 32, 0.01, input_size, 128, output_size, 'adam', 'cross_entropy')
filename_v4_sig = best_model_v4_sig.get_architecture_name() + '.txt'
saveResults(best_model_v4_sig,save_dir,name,filename_v4_sig, 'adam', 'cross_entropy')

best_model_v4_sig, _ = Train_K_FOLDS(MLP_v4_sig, 50, 0.0001, 10, 32, 0.01, input_size, 128, output_size, 'adam', 'MSELoss')
filename_v4_sig = best_model_v4_sig.get_architecture_name() + '.txt'
saveResults(best_model_v4_sig,save_dir,name,filename_v4_sig, 'adam', 'MSELoss')

best_model_v4_sig, _ = Train_K_FOLDS(MLP_v4_sig, 50, 0.0001, 10, 32, 0.01, input_size, 128, output_size, 'adam', 'BCELoss')
filename_v4_sig = best_model_v4_sig.get_architecture_name() + '.txt'
saveResults(best_model_v4_sig,save_dir,name,filename_v4_sig, 'adam', 'BCELoss')


best_model_v4_sig, _ = Train_K_FOLDS(MLP_v4_sig, 50, 0.0001, 10, 32, 0.01, input_size, 128, output_size, 'SGD', 'cross_entropy')
filename_v4_sig = best_model_v4_sig.get_architecture_name() + '.txt'
saveResults(best_model_v4_sig,save_dir,name,filename_v4_sig, 'SGD', 'cross_entropy')

best_model_v4_sig, _ = Train_K_FOLDS(MLP_v4_sig, 50, 0.0001, 10, 32, 0.01, input_size, 128, output_size, 'SGD', 'MSELoss')
filename_v4_sig = best_model_v4_sig.get_architecture_name() + '.txt'
saveResults(best_model_v4_sig,save_dir,name,filename_v4_sig, 'SGD', 'MSELoss')

best_model_v4_sig, _ = Train_K_FOLDS(MLP_v4_sig, 50, 0.0001, 10, 32, 0.01, input_size, 128, output_size, 'SGD', 'BCELoss')
filename_v4_sig = best_model_v4_sig.get_architecture_name() + '.txt'
saveResults(best_model_v4_sig,save_dir,name,filename_v4_sig, 'SGD', 'BCELoss')


best_model_v4_sig, _ = Train_K_FOLDS(MLP_v4_sig, 50, 0.0001, 10, 32, 0.01, input_size, 128, output_size, 'RMSprop', 'cross_entropy')
filename_v4_sig = best_model_v4_sig.get_architecture_name() + '.txt'
saveResults(best_model_v4_sig,save_dir,name,filename_v4_sig, 'RMSprop', 'cross_entropy')

best_model_v4_sig, _ = Train_K_FOLDS(MLP_v4_sig, 50, 0.0001, 10, 32, 0.01, input_size, 128, output_size, 'RMSprop', 'MSELoss')
filename_v4_sig = best_model_v4_sig.get_architecture_name() + '.txt'
saveResults(best_model_v4_sig,save_dir,name,filename_v4_sig, 'RMSprop', 'MSELoss')

best_model_v4_sig, _ = Train_K_FOLDS(MLP_v4_sig, 50, 0.0001, 10, 32, 0.01, input_size, 128, output_size, 'RMSprop', 'BCELoss')
filename_v4_sig = best_model_v4_sig.get_architecture_name() + '.txt'
saveResults(best_model_v4_sig,save_dir,name,filename_v4_sig, 'RMSprop', 'BCELoss')




best_model_v4_tanh, _ = Train_K_FOLDS(MLP_v4_tanh, 50, 0.0001, 10, 32, 0.01, input_size, 128, output_size, 'adam', 'cross_entropy')
filename_v4_tanh = best_model_v4_tanh.get_architecture_name() + '.txt'
saveResults(best_model_v4_tanh,save_dir,name,filename_v4_tanh, 'adam', 'cross_entropy')

best_model_v4_tanh, _ = Train_K_FOLDS(MLP_v4_tanh, 50, 0.0001, 10, 32, 0.01, input_size, 128, output_size, 'adam', 'MSELoss')
filename_v4_tanh = best_model_v4_tanh.get_architecture_name() + '.txt'
saveResults(best_model_v4_tanh,save_dir,name,filename_v4_tanh, 'adam', 'MSELoss')

best_model_v4_tanh, _ = Train_K_FOLDS(MLP_v4_tanh, 50, 0.0001, 10, 32, 0.01, input_size, 128, output_size, 'adam', 'BCELoss')
filename_v4_tanh = best_model_v4_tanh.get_architecture_name() + '.txt'
saveResults(best_model_v4_tanh,save_dir,name,filename_v4_tanh, 'adam', 'BCELoss')


best_model_v4_tanh, _ = Train_K_FOLDS(MLP_v4_tanh, 50, 0.0001, 10, 32, 0.01, input_size, 128, output_size, 'SGD', 'cross_entropy')
filename_v4_tanh = best_model_v4_tanh.get_architecture_name() + '.txt'
saveResults(best_model_v4_tanh,save_dir,name,filename_v4_tanh, 'SGD', 'cross_entropy')

best_model_v4_tanh, _ = Train_K_FOLDS(MLP_v4_tanh, 50, 0.0001, 10, 32, 0.01, input_size, 128, output_size, 'SGD', 'MSELoss')
filename_v4_tanh = best_model_v4_tanh.get_architecture_name() + '.txt'
saveResults(best_model_v4_tanh,save_dir,name,filename_v4_tanh, 'SGD', 'MSELoss')

best_model_v4_tanh, _ = Train_K_FOLDS(MLP_v4_tanh, 50, 0.0001, 10, 32, 0.01, input_size, 128, output_size, 'SGD', 'BCELoss')
filename_v4_tanh = best_model_v4_tanh.get_architecture_name() + '.txt'
saveResults(best_model_v4_tanh,save_dir,name,filename_v4_tanh, 'SGD', 'BCELoss')


best_model_v4_tanh, _ = Train_K_FOLDS(MLP_v4_tanh, 50, 0.0001, 10, 32, 0.01, input_size, 128, output_size, 'RMSprop', 'cross_entropy')
filename_v4_tanh = best_model_v4_tanh.get_architecture_name() + '.txt'
saveResults(best_model_v4_tanh,save_dir,name,filename_v4_tanh, 'RMSprop', 'cross_entropy')

best_model_v4_tanh, _ = Train_K_FOLDS(MLP_v4_tanh, 50, 0.0001, 10, 32, 0.01, input_size, 128, output_size, 'RMSprop', 'MSELoss')
filename_v4_tanh = best_model_v4_tanh.get_architecture_name() + '.txt'
saveResults(best_model_v4_tanh,save_dir,name,filename_v4_tanh, 'RMSprop', 'MSELoss')

best_model_v4_tanh, _ = Train_K_FOLDS(MLP_v4_tanh, 50, 0.0001, 10, 32, 0.01, input_size, 128, output_size, 'RMSprop', 'BCELoss')
filename_v4_tanh = best_model_v4_tanh.get_architecture_name() + '.txt'
saveResults(best_model_v4_tanh,save_dir,name,filename_v4_tanh, 'RMSprop', 'BCELoss')
# Out:
# Epoch [1/50], Train Loss: 4.3325, Train Acc: 16.67%, Val Loss: 2.2999, Val Acc: 12.50%
# Epoch [2/50], Train Loss: 4.0017, Train Acc: 16.67%, Val Loss: 2.2332, Val Acc: 14.29%
# Epoch [3/50], Train Loss: 3.7864, Train Acc: 14.29%, Val Loss: 2.1869, Val Acc: 11.11%
# Epoch [4/50], Train Loss: 3.6361, Train Acc: 16.67%, Val Loss: 2.1496, Val Acc: 12.50%
# Epoch [5/50], Train Loss: 3.5252, Train Acc: 12.50%, Val Loss: 2.1227, Val Acc: 12.50%
# Epoch [6/50], Train Loss: 3.4285, Train Acc: 16.67%, Val Loss: 2.1049, Val Acc: 14.29%
# Epoch [7/50], Train Loss: 3.3502, Train Acc: 16.67%, Val Loss: 2.0930, Val Acc: 11.11%
# Epoch [8/50], Train Loss: 3.2759, Train Acc: 0.00%, Val Loss: 2.0857, Val Acc: 11.11%
# Epoch [9/50], Train Loss: 3.2055, Train Acc: 12.50%, Val Loss: 2.0799, Val Acc: 12.50%
# Epoch [10/50], Train Loss: 3.1433, Train Acc: 12.50%, Val Loss: 2.0784, Val Acc: 12.50%
# Epoch [11/50], Train Loss: 3.0866, Train Acc: 16.67%, Val Loss: 2.0761, Val Acc: 11.11%
# Epoch [12/50], Train Loss: 3.0320, Train Acc: 12.50%, Val Loss: 2.0716, Val Acc: 12.50%
# Epoch [13/50], Train Loss: 2.9746, Train Acc: 14.29%, Val Loss: 2.0727, Val Acc: 12.50%
# Epoch [14/50], Train Loss: 2.9190, Train Acc: 20.00%, Val Loss: 2.0746, Val Acc: 11.11%
# Epoch [15/50], Train Loss: 2.8781, Train Acc: 14.29%, Val Loss: 2.0719, Val Acc: 12.50%
# Epoch [16/50], Train Loss: 2.8260, Train Acc: 20.00%, Val Loss: 2.0714, Val Acc: 12.50%
# Epoch [17/50], Train Loss: 2.7880, Train Acc: 14.29%, Val Loss: 2.0709, Val Acc: 16.67%
# Epoch [18/50], Train Loss: 2.7493, Train Acc: 12.50%, Val Loss: 2.0747, Val Acc: 11.11%
# Epoch [19/50], Train Loss: 2.7109, Train Acc: 14.29%, Val Loss: 2.0709, Val Acc: 12.50%
# Epoch [20/50], Train Loss: 2.6754, Train Acc: 16.67%, Val Loss: 2.0725, Val Acc: 11.11%
# Epoch [21/50], Train Loss: 2.6507, Train Acc: 12.50%, Val Loss: 2.0765, Val Acc: 11.11%
# Epoch [22/50], Train Loss: 2.6092, Train Acc: 16.67%, Val Loss: 2.0746, Val Acc: 12.50%
# Epoch [23/50], Train Loss: 2.5891, Train Acc: 14.29%, Val Loss: 2.0736, Val Acc: 11.11%
# Epoch [24/50], Train Loss: 2.5555, Train Acc: 14.29%, Val Loss: 2.0751, Val Acc: 11.11%
# Epoch [25/50], Train Loss: 2.5256, Train Acc: 20.00%, Val Loss: 2.0747, Val Acc: 12.50%
# Epoch [26/50], Train Loss: 2.5063, Train Acc: 16.67%, Val Loss: 2.0716, Val Acc: 14.29%
# Epoch [27/50], Train Loss: 2.4791, Train Acc: 12.50%, Val Loss: 2.0732, Val Acc: 11.11%
# Epoch [28/50], Train Loss: 2.4602, Train Acc: 12.50%, Val Loss: 2.0733, Val Acc: 14.29%
# Epoch [29/50], Train Loss: 2.4381, Train Acc: 12.50%, Val Loss: 2.0729, Val Acc: 11.11%
# Epoch [30/50], Train Loss: 2.4180, Train Acc: 11.11%, Val Loss: 2.0711, Val Acc: 11.11%
# Epoch [31/50], Train Loss: 2.4034, Train Acc: 14.29%, Val Loss: 2.0715, Val Acc: 12.50%
# Epoch [32/50], Train Loss: 2.3781, Train Acc: 20.00%, Val Loss: 2.0728, Val Acc: 11.11%
# Epoch [33/50], Train Loss: 2.3587, Train Acc: 16.67%, Val Loss: 2.0731, Val Acc: 14.29%
# Epoch [34/50], Train Loss: 2.3458, Train Acc: 16.67%, Val Loss: 2.0773, Val Acc: 11.11%
# Epoch [35/50], Train Loss: 2.3397, Train Acc: 0.00%, Val Loss: 2.0717, Val Acc: 11.11%
# Epoch [36/50], Train Loss: 2.3223, Train Acc: 0.00%, Val Loss: 2.0734, Val Acc: 11.11%
# Epoch [37/50], Train Loss: 2.3049, Train Acc: 16.67%, Val Loss: 2.0766, Val Acc: 11.11%
# Epoch [38/50], Train Loss: 2.2896, Train Acc: 16.67%, Val Loss: 2.0766, Val Acc: 11.11%
# Epoch [39/50], Train Loss: 2.2819, Train Acc: 16.67%, Val Loss: 2.0718, Val Acc: 14.29%
# Epoch [40/50], Train Loss: 2.2720, Train Acc: 14.29%, Val Loss: 2.0699, Val Acc: 14.29%
# Epoch [41/50], Train Loss: 2.2585, Train Acc: 16.67%, Val Loss: 2.0736, Val Acc: 12.50%
# Epoch [42/50], Train Loss: 2.2526, Train Acc: 14.29%, Val Loss: 2.0741, Val Acc: 12.50%
# Epoch [43/50], Train Loss: 2.2420, Train Acc: 14.29%, Val Loss: 2.0715, Val Acc: 11.11%
# Epoch [44/50], Train Loss: 2.2342, Train Acc: 14.29%, Val Loss: 2.0712, Val Acc: 14.29%
# Epoch [45/50], Train Loss: 2.2252, Train Acc: 12.50%, Val Loss: 2.0752, Val Acc: 12.50%
# Epoch [46/50], Train Loss: 2.2233, Train Acc: 14.29%, Val Loss: 2.0743, Val Acc: 12.50%
# Epoch [47/50], Train Loss: 2.2066, Train Acc: 20.00%, Val Loss: 2.0733, Val Acc: 11.11%
# Epoch [48/50], Train Loss: 2.2015, Train Acc: 20.00%, Val Loss: 2.0715, Val Acc: 12.50%
# Epoch [49/50], Train Loss: 2.2038, Train Acc: 14.29%, Val Loss: 2.0688, Val Acc: 11.11%
# Epoch [50/50], Train Loss: 2.1878, Train Acc: 20.00%, Val Loss: 2.0739, Val Acc: 12.50%
# F1 Score:  0.1397599690282617
# B_acc:  0.1111111111111111
# Best model has index  0
#
# Epoch [1/50], Train Loss: 4.2743, Train Acc: 14.29%, Val Loss: 2.2003, Val Acc: 12.50%
# Epoch [2/50], Train Loss: 3.9525, Train Acc: 14.29%, Val Loss: 2.1503, Val Acc: 11.11%
# Epoch [3/50], Train Loss: 3.7433, Train Acc: 16.67%, Val Loss: 2.1119, Val Acc: 11.11%
# Epoch [4/50], Train Loss: 3.6090, Train Acc: 11.11%, Val Loss: 2.0857, Val Acc: 12.50%
# Epoch [5/50], Train Loss: 3.5020, Train Acc: 12.50%, Val Loss: 2.0681, Val Acc: 12.50%
# Epoch [6/50], Train Loss: 3.4106, Train Acc: 16.67%, Val Loss: 2.0591, Val Acc: 12.50%
# Epoch [7/50], Train Loss: 3.3287, Train Acc: 16.67%, Val Loss: 2.0504, Val Acc: 12.50%
# Epoch [8/50], Train Loss: 3.2583, Train Acc: 14.29%, Val Loss: 2.0444, Val Acc: 12.50%
# Epoch [9/50], Train Loss: 3.1977, Train Acc: 0.00%, Val Loss: 2.0413, Val Acc: 12.50%
# Epoch [10/50], Train Loss: 3.1300, Train Acc: 16.67%, Val Loss: 2.0377, Val Acc: 12.50%
# Epoch [11/50], Train Loss: 3.0778, Train Acc: 14.29%, Val Loss: 2.0341, Val Acc: 14.29%
# Epoch [12/50], Train Loss: 3.0200, Train Acc: 12.50%, Val Loss: 2.0369, Val Acc: 12.50%
# Epoch [13/50], Train Loss: 2.9674, Train Acc: 14.29%, Val Loss: 2.0390, Val Acc: 11.11%
# Epoch [14/50], Train Loss: 2.9146, Train Acc: 14.29%, Val Loss: 2.0354, Val Acc: 11.11%
# Epoch [15/50], Train Loss: 2.8712, Train Acc: 14.29%, Val Loss: 2.0335, Val Acc: 14.29%
# Epoch [16/50], Train Loss: 2.8283, Train Acc: 12.50%, Val Loss: 2.0347, Val Acc: 12.50%
# Epoch [17/50], Train Loss: 2.7840, Train Acc: 16.67%, Val Loss: 2.0331, Val Acc: 12.50%
# Epoch [18/50], Train Loss: 2.7437, Train Acc: 16.67%, Val Loss: 2.0319, Val Acc: 12.50%
# Epoch [19/50], Train Loss: 2.7040, Train Acc: 14.29%, Val Loss: 2.0329, Val Acc: 11.11%
# Epoch [20/50], Train Loss: 2.6783, Train Acc: 0.00%, Val Loss: 2.0309, Val Acc: 12.50%
# Epoch [21/50], Train Loss: 2.6356, Train Acc: 14.29%, Val Loss: 2.0306, Val Acc: 11.11%
# Epoch [22/50], Train Loss: 2.6070, Train Acc: 14.29%, Val Loss: 2.0329, Val Acc: 12.50%
# Epoch [23/50], Train Loss: 2.5790, Train Acc: 12.50%, Val Loss: 2.0320, Val Acc: 12.50%
# Epoch [24/50], Train Loss: 2.5504, Train Acc: 16.67%, Val Loss: 2.0322, Val Acc: 11.11%
# Epoch [25/50], Train Loss: 2.5217, Train Acc: 14.29%, Val Loss: 2.0315, Val Acc: 12.50%
# Epoch [26/50], Train Loss: 2.4963, Train Acc: 16.67%, Val Loss: 2.0318, Val Acc: 12.50%
# Epoch [27/50], Train Loss: 2.4712, Train Acc: 16.67%, Val Loss: 2.0326, Val Acc: 12.50%
# Epoch [28/50], Train Loss: 2.4520, Train Acc: 14.29%, Val Loss: 2.0309, Val Acc: 12.50%
# Epoch [29/50], Train Loss: 2.4315, Train Acc: 14.29%, Val Loss: 2.0316, Val Acc: 11.11%
# Epoch [30/50], Train Loss: 2.4123, Train Acc: 12.50%, Val Loss: 2.0277, Val Acc: 14.29%
# Epoch [31/50], Train Loss: 2.4016, Train Acc: 12.50%, Val Loss: 2.0335, Val Acc: 11.11%
# Epoch [32/50], Train Loss: 2.3781, Train Acc: 14.29%, Val Loss: 2.0311, Val Acc: 12.50%
# Epoch [33/50], Train Loss: 2.3612, Train Acc: 12.50%, Val Loss: 2.0296, Val Acc: 14.29%
# Epoch [34/50], Train Loss: 2.3483, Train Acc: 12.50%, Val Loss: 2.0299, Val Acc: 14.29%
# Epoch [35/50], Train Loss: 2.3277, Train Acc: 14.29%, Val Loss: 2.0326, Val Acc: 11.11%
# Epoch [36/50], Train Loss: 2.3209, Train Acc: 12.50%, Val Loss: 2.0315, Val Acc: 11.11%
# Epoch [37/50], Train Loss: 2.3104, Train Acc: 12.50%, Val Loss: 2.0320, Val Acc: 12.50%
# Epoch [38/50], Train Loss: 2.2904, Train Acc: 14.29%, Val Loss: 2.0332, Val Acc: 12.50%
# Epoch [39/50], Train Loss: 2.2875, Train Acc: 12.50%, Val Loss: 2.0334, Val Acc: 11.11%
# Epoch [40/50], Train Loss: 2.2653, Train Acc: 20.00%, Val Loss: 2.0322, Val Acc: 12.50%
# Epoch [41/50], Train Loss: 2.2610, Train Acc: 20.00%, Val Loss: 2.0316, Val Acc: 11.11%
# Epoch [42/50], Train Loss: 2.2514, Train Acc: 14.29%, Val Loss: 2.0304, Val Acc: 12.50%
# Epoch [43/50], Train Loss: 2.2472, Train Acc: 0.00%, Val Loss: 2.0267, Val Acc: 12.50%
# Epoch [44/50], Train Loss: 2.2294, Train Acc: 14.29%, Val Loss: 2.0326, Val Acc: 11.11%
# Epoch [45/50], Train Loss: 2.2281, Train Acc: 14.29%, Val Loss: 2.0302, Val Acc: 12.50%
# Epoch [46/50], Train Loss: 2.2172, Train Acc: 14.29%, Val Loss: 2.0348, Val Acc: 11.11%
# Epoch [47/50], Train Loss: 2.2135, Train Acc: 12.50%, Val Loss: 2.0289, Val Acc: 12.50%
# Epoch [48/50], Train Loss: 2.2071, Train Acc: 14.29%, Val Loss: 2.0308, Val Acc: 11.11%
# Epoch [49/50], Train Loss: 2.1956, Train Acc: 14.29%, Val Loss: 2.0316, Val Acc: 12.50%
# Epoch [50/50], Train Loss: 2.1983, Train Acc: 12.50%, Val Loss: 2.0308, Val Acc: 12.50%
# F1 Score:  0.11800734993875049
# B_acc:  0.1111111111111111
# Best model has index  0
#
# Epoch [1/50], Train Loss: 4.1970, Train Acc: 16.67%, Val Loss: 2.1803, Val Acc: 11.11%
# Epoch [2/50], Train Loss: 3.8990, Train Acc: 14.29%, Val Loss: 2.1619, Val Acc: 11.11%
# Epoch [3/50], Train Loss: 3.7005, Train Acc: 16.67%, Val Loss: 2.1477, Val Acc: 12.50%
# Epoch [4/50], Train Loss: 3.5727, Train Acc: 0.00%, Val Loss: 2.1323, Val Acc: 12.50%
# Epoch [5/50], Train Loss: 3.4686, Train Acc: 14.29%, Val Loss: 2.1320, Val Acc: 12.50%
# Epoch [6/50], Train Loss: 3.3803, Train Acc: 16.67%, Val Loss: 2.1229, Val Acc: 12.50%
# Epoch [7/50], Train Loss: 3.3082, Train Acc: 14.29%, Val Loss: 2.1259, Val Acc: 12.50%
# Epoch [8/50], Train Loss: 3.2453, Train Acc: 14.29%, Val Loss: 2.1292, Val Acc: 11.11%
# Epoch [9/50], Train Loss: 3.1755, Train Acc: 14.29%, Val Loss: 2.1239, Val Acc: 11.11%
# Epoch [10/50], Train Loss: 3.1148, Train Acc: 14.29%, Val Loss: 2.1234, Val Acc: 12.50%
# Epoch [11/50], Train Loss: 3.0584, Train Acc: 14.29%, Val Loss: 2.1231, Val Acc: 11.11%
# Epoch [12/50], Train Loss: 3.0041, Train Acc: 14.29%, Val Loss: 2.1239, Val Acc: 12.50%
# Epoch [13/50], Train Loss: 2.9503, Train Acc: 14.29%, Val Loss: 2.1270, Val Acc: 11.11%
# Epoch [14/50], Train Loss: 2.9024, Train Acc: 16.67%, Val Loss: 2.1241, Val Acc: 11.11%
# Epoch [15/50], Train Loss: 2.8540, Train Acc: 16.67%, Val Loss: 2.1263, Val Acc: 12.50%
# Epoch [16/50], Train Loss: 2.8123, Train Acc: 12.50%, Val Loss: 2.1240, Val Acc: 12.50%
# Epoch [17/50], Train Loss: 2.7716, Train Acc: 14.29%, Val Loss: 2.1237, Val Acc: 12.50%
# Epoch [18/50], Train Loss: 2.7308, Train Acc: 16.67%, Val Loss: 2.1216, Val Acc: 12.50%
# Epoch [19/50], Train Loss: 2.6935, Train Acc: 16.67%, Val Loss: 2.1205, Val Acc: 12.50%
# Epoch [20/50], Train Loss: 2.6562, Train Acc: 14.29%, Val Loss: 2.1252, Val Acc: 14.29%
# Epoch [21/50], Train Loss: 2.6282, Train Acc: 12.50%, Val Loss: 2.1230, Val Acc: 12.50%
# Epoch [22/50], Train Loss: 2.5941, Train Acc: 14.29%, Val Loss: 2.1258, Val Acc: 11.11%
# Epoch [23/50], Train Loss: 2.5640, Train Acc: 14.29%, Val Loss: 2.1249, Val Acc: 11.11%
# Epoch [24/50], Train Loss: 2.5338, Train Acc: 16.67%, Val Loss: 2.1281, Val Acc: 12.50%
# Epoch [25/50], Train Loss: 2.5125, Train Acc: 14.29%, Val Loss: 2.1215, Val Acc: 12.50%
# Epoch [26/50], Train Loss: 2.4881, Train Acc: 12.50%, Val Loss: 2.1318, Val Acc: 12.50%
# Epoch [27/50], Train Loss: 2.4636, Train Acc: 0.00%, Val Loss: 2.1251, Val Acc: 11.11%
# Epoch [28/50], Train Loss: 2.4477, Train Acc: 12.50%, Val Loss: 2.1220, Val Acc: 12.50%
# Epoch [29/50], Train Loss: 2.4223, Train Acc: 11.11%, Val Loss: 2.1218, Val Acc: 12.50%
# Epoch [30/50], Train Loss: 2.4014, Train Acc: 14.29%, Val Loss: 2.1226, Val Acc: 12.50%
# Epoch [31/50], Train Loss: 2.3860, Train Acc: 12.50%, Val Loss: 2.1216, Val Acc: 12.50%
# Epoch [32/50], Train Loss: 2.3623, Train Acc: 16.67%, Val Loss: 2.1204, Val Acc: 11.11%
# Epoch [33/50], Train Loss: 2.3526, Train Acc: 11.11%, Val Loss: 2.1263, Val Acc: 11.11%
# Epoch [34/50], Train Loss: 2.3349, Train Acc: 12.50%, Val Loss: 2.1218, Val Acc: 12.50%
# Epoch [35/50], Train Loss: 2.3211, Train Acc: 12.50%, Val Loss: 2.1248, Val Acc: 12.50%
# Epoch [36/50], Train Loss: 2.3048, Train Acc: 12.50%, Val Loss: 2.1250, Val Acc: 12.50%
# Epoch [37/50], Train Loss: 2.2960, Train Acc: 12.50%, Val Loss: 2.1218, Val Acc: 11.11%
# Epoch [38/50], Train Loss: 2.2842, Train Acc: 11.11%, Val Loss: 2.1245, Val Acc: 14.29%
# Epoch [39/50], Train Loss: 2.2622, Train Acc: 16.67%, Val Loss: 2.1214, Val Acc: 12.50%
# Epoch [40/50], Train Loss: 2.2580, Train Acc: 14.29%, Val Loss: 2.1284, Val Acc: 12.50%
# Epoch [41/50], Train Loss: 2.2483, Train Acc: 12.50%, Val Loss: 2.1215, Val Acc: 11.11%
# Epoch [42/50], Train Loss: 2.2368, Train Acc: 14.29%, Val Loss: 2.1304, Val Acc: 11.11%
# Epoch [43/50], Train Loss: 2.2213, Train Acc: 20.00%, Val Loss: 2.1292, Val Acc: 11.11%
# Epoch [44/50], Train Loss: 2.2223, Train Acc: 12.50%, Val Loss: 2.1215, Val Acc: 11.11%
# Epoch [45/50], Train Loss: 2.2150, Train Acc: 12.50%, Val Loss: 2.1276, Val Acc: 11.11%
# Epoch [46/50], Train Loss: 2.2075, Train Acc: 12.50%, Val Loss: 2.1256, Val Acc: 12.50%
# Epoch [47/50], Train Loss: 2.2053, Train Acc: 16.67%, Val Loss: 2.1268, Val Acc: 11.11%
# Epoch [48/50], Train Loss: 2.1969, Train Acc: 14.29%, Val Loss: 2.1243, Val Acc: 11.11%
# Epoch [49/50], Train Loss: 2.1924, Train Acc: 12.50%, Val Loss: 2.1221, Val Acc: 12.50%
# Epoch [50/50], Train Loss: 2.1813, Train Acc: 16.67%, Val Loss: 2.1254, Val Acc: 12.50%
# F1 Score:  0.10587262200165426
# B_acc:  0.1111111111111111
# Best model has index  0
#
# Epoch [1/50], Train Loss: 4.1928, Train Acc: 16.67%, Val Loss: 2.1445, Val Acc: 11.11%
# Epoch [2/50], Train Loss: 3.8952, Train Acc: 14.29%, Val Loss: 2.1300, Val Acc: 11.11%
# Epoch [3/50], Train Loss: 3.7065, Train Acc: 0.00%, Val Loss: 2.1214, Val Acc: 11.11%
# Epoch [4/50], Train Loss: 3.5731, Train Acc: 14.29%, Val Loss: 2.1114, Val Acc: 11.11%
# Epoch [5/50], Train Loss: 3.4746, Train Acc: 14.29%, Val Loss: 2.1097, Val Acc: 12.50%
# Epoch [6/50], Train Loss: 3.3837, Train Acc: 20.00%, Val Loss: 2.1144, Val Acc: 11.11%
# Epoch [7/50], Train Loss: 3.3116, Train Acc: 16.67%, Val Loss: 2.1140, Val Acc: 12.50%
# Epoch [8/50], Train Loss: 3.2463, Train Acc: 12.50%, Val Loss: 2.1132, Val Acc: 11.11%
# Epoch [9/50], Train Loss: 3.1781, Train Acc: 16.67%, Val Loss: 2.1146, Val Acc: 12.50%
# Epoch [10/50], Train Loss: 3.1168, Train Acc: 14.29%, Val Loss: 2.1090, Val Acc: 11.11%
# Epoch [11/50], Train Loss: 3.0610, Train Acc: 16.67%, Val Loss: 2.1166, Val Acc: 11.11%
# Epoch [12/50], Train Loss: 3.0077, Train Acc: 12.50%, Val Loss: 2.1096, Val Acc: 12.50%
# Epoch [13/50], Train Loss: 2.9560, Train Acc: 12.50%, Val Loss: 2.1101, Val Acc: 12.50%
# Epoch [14/50], Train Loss: 2.9009, Train Acc: 14.29%, Val Loss: 2.1178, Val Acc: 12.50%
# Epoch [15/50], Train Loss: 2.8616, Train Acc: 12.50%, Val Loss: 2.1133, Val Acc: 12.50%
# Epoch [16/50], Train Loss: 2.8155, Train Acc: 14.29%, Val Loss: 2.1111, Val Acc: 11.11%
# Epoch [17/50], Train Loss: 2.7777, Train Acc: 11.11%, Val Loss: 2.1144, Val Acc: 12.50%
# Epoch [18/50], Train Loss: 2.7339, Train Acc: 12.50%, Val Loss: 2.1100, Val Acc: 14.29%
# Epoch [19/50], Train Loss: 2.6969, Train Acc: 12.50%, Val Loss: 2.1130, Val Acc: 11.11%
# Epoch [20/50], Train Loss: 2.6585, Train Acc: 12.50%, Val Loss: 2.1122, Val Acc: 12.50%
# Epoch [21/50], Train Loss: 2.6255, Train Acc: 14.29%, Val Loss: 2.1113, Val Acc: 12.50%
# Epoch [22/50], Train Loss: 2.5966, Train Acc: 14.29%, Val Loss: 2.1059, Val Acc: 14.29%
# Epoch [23/50], Train Loss: 2.5624, Train Acc: 20.00%, Val Loss: 2.1155, Val Acc: 12.50%
# Epoch [24/50], Train Loss: 2.5351, Train Acc: 14.29%, Val Loss: 2.1138, Val Acc: 12.50%
# Epoch [25/50], Train Loss: 2.5068, Train Acc: 16.67%, Val Loss: 2.1102, Val Acc: 12.50%
# Epoch [26/50], Train Loss: 2.4972, Train Acc: 14.29%, Val Loss: 2.1189, Val Acc: 12.50%
# Epoch [27/50], Train Loss: 2.4638, Train Acc: 12.50%, Val Loss: 2.1174, Val Acc: 11.11%
# Epoch [28/50], Train Loss: 2.4426, Train Acc: 14.29%, Val Loss: 2.1133, Val Acc: 12.50%
# Epoch [29/50], Train Loss: 2.4177, Train Acc: 16.67%, Val Loss: 2.1105, Val Acc: 11.11%
# Epoch [30/50], Train Loss: 2.4098, Train Acc: 0.00%, Val Loss: 2.1107, Val Acc: 12.50%
# Epoch [31/50], Train Loss: 2.3847, Train Acc: 12.50%, Val Loss: 2.1137, Val Acc: 12.50%
# Epoch [32/50], Train Loss: 2.3687, Train Acc: 14.29%, Val Loss: 2.1148, Val Acc: 11.11%
# Epoch [33/50], Train Loss: 2.3518, Train Acc: 14.29%, Val Loss: 2.1146, Val Acc: 11.11%
# Epoch [34/50], Train Loss: 2.3317, Train Acc: 14.29%, Val Loss: 2.1181, Val Acc: 11.11%
# Epoch [35/50], Train Loss: 2.3164, Train Acc: 14.29%, Val Loss: 2.1145, Val Acc: 12.50%
# Epoch [36/50], Train Loss: 2.3043, Train Acc: 14.29%, Val Loss: 2.1141, Val Acc: 11.11%
# Epoch [37/50], Train Loss: 2.2941, Train Acc: 14.29%, Val Loss: 2.1098, Val Acc: 12.50%
# Epoch [38/50], Train Loss: 2.2856, Train Acc: 12.50%, Val Loss: 2.1101, Val Acc: 12.50%
# Epoch [39/50], Train Loss: 2.2741, Train Acc: 11.11%, Val Loss: 2.1142, Val Acc: 12.50%
# Epoch [40/50], Train Loss: 2.2561, Train Acc: 20.00%, Val Loss: 2.1100, Val Acc: 14.29%
# Epoch [41/50], Train Loss: 2.2521, Train Acc: 0.00%, Val Loss: 2.1076, Val Acc: 14.29%
# Epoch [42/50], Train Loss: 2.2390, Train Acc: 14.29%, Val Loss: 2.1089, Val Acc: 12.50%
# Epoch [43/50], Train Loss: 2.2324, Train Acc: 14.29%, Val Loss: 2.1152, Val Acc: 11.11%
# Epoch [44/50], Train Loss: 2.2261, Train Acc: 14.29%, Val Loss: 2.1159, Val Acc: 11.11%
# Epoch [45/50], Train Loss: 2.2106, Train Acc: 16.67%, Val Loss: 2.1144, Val Acc: 11.11%
# Epoch [46/50], Train Loss: 2.2059, Train Acc: 16.67%, Val Loss: 2.1139, Val Acc: 11.11%
# Epoch [47/50], Train Loss: 2.2006, Train Acc: 14.29%, Val Loss: 2.1163, Val Acc: 11.11%
# Epoch [48/50], Train Loss: 2.1923, Train Acc: 12.50%, Val Loss: 2.1149, Val Acc: 11.11%
# Epoch [49/50], Train Loss: 2.1865, Train Acc: 14.29%, Val Loss: 2.1148, Val Acc: 14.29%
# Epoch [50/50], Train Loss: 2.1829, Train Acc: 12.50%, Val Loss: 2.1094, Val Acc: 14.29%
# F1 Score:  0.06277244986922405
# B_acc:  0.1111111111111111
# Best model has index  0
#
# Epoch [1/50], Train Loss: 4.2306, Train Acc: 0.00%, Val Loss: 2.1869, Val Acc: 12.50%
# Epoch [2/50], Train Loss: 3.9273, Train Acc: 12.50%, Val Loss: 2.1383, Val Acc: 12.50%
# Epoch [3/50], Train Loss: 3.7263, Train Acc: 16.67%, Val Loss: 2.1093, Val Acc: 11.11%
# Epoch [4/50], Train Loss: 3.5995, Train Acc: 14.29%, Val Loss: 2.0866, Val Acc: 12.50%
# Epoch [5/50], Train Loss: 3.4908, Train Acc: 14.29%, Val Loss: 2.0719, Val Acc: 14.29%
# Epoch [6/50], Train Loss: 3.4058, Train Acc: 12.50%, Val Loss: 2.0591, Val Acc: 12.50%
# Epoch [7/50], Train Loss: 3.3305, Train Acc: 16.67%, Val Loss: 2.0529, Val Acc: 12.50%
# Epoch [8/50], Train Loss: 3.2641, Train Acc: 11.11%, Val Loss: 2.0455, Val Acc: 12.50%
# Epoch [9/50], Train Loss: 3.1976, Train Acc: 11.11%, Val Loss: 2.0450, Val Acc: 12.50%
# Epoch [10/50], Train Loss: 3.1315, Train Acc: 16.67%, Val Loss: 2.0420, Val Acc: 11.11%
# Epoch [11/50], Train Loss: 3.0713, Train Acc: 16.67%, Val Loss: 2.0403, Val Acc: 11.11%
# Epoch [12/50], Train Loss: 3.0170, Train Acc: 14.29%, Val Loss: 2.0416, Val Acc: 14.29%
# Epoch [13/50], Train Loss: 2.9706, Train Acc: 14.29%, Val Loss: 2.0405, Val Acc: 11.11%
# Epoch [14/50], Train Loss: 2.9150, Train Acc: 14.29%, Val Loss: 2.0377, Val Acc: 12.50%
# Epoch [15/50], Train Loss: 2.8659, Train Acc: 16.67%, Val Loss: 2.0385, Val Acc: 12.50%
# Epoch [16/50], Train Loss: 2.8278, Train Acc: 14.29%, Val Loss: 2.0303, Val Acc: 14.29%
# Epoch [17/50], Train Loss: 2.7835, Train Acc: 14.29%, Val Loss: 2.0339, Val Acc: 11.11%
# Epoch [18/50], Train Loss: 2.7398, Train Acc: 14.29%, Val Loss: 2.0296, Val Acc: 14.29%
# Epoch [19/50], Train Loss: 2.7147, Train Acc: 0.00%, Val Loss: 2.0285, Val Acc: 16.67%
# Epoch [20/50], Train Loss: 2.6671, Train Acc: 16.67%, Val Loss: 2.0319, Val Acc: 12.50%
# Epoch [21/50], Train Loss: 2.6357, Train Acc: 20.00%, Val Loss: 2.0325, Val Acc: 11.11%
# Epoch [22/50], Train Loss: 2.6038, Train Acc: 14.29%, Val Loss: 2.0313, Val Acc: 11.11%
# Epoch [23/50], Train Loss: 2.5805, Train Acc: 0.00%, Val Loss: 2.0254, Val Acc: 12.50%
# Epoch [24/50], Train Loss: 2.5527, Train Acc: 14.29%, Val Loss: 2.0288, Val Acc: 14.29%
# Epoch [25/50], Train Loss: 2.5251, Train Acc: 11.11%, Val Loss: 2.0301, Val Acc: 12.50%
# Epoch [26/50], Train Loss: 2.4990, Train Acc: 14.29%, Val Loss: 2.0318, Val Acc: 11.11%
# Epoch [27/50], Train Loss: 2.4759, Train Acc: 14.29%, Val Loss: 2.0351, Val Acc: 11.11%
# Epoch [28/50], Train Loss: 2.4554, Train Acc: 12.50%, Val Loss: 2.0330, Val Acc: 11.11%
# Epoch [29/50], Train Loss: 2.4262, Train Acc: 20.00%, Val Loss: 2.0275, Val Acc: 12.50%
# Epoch [30/50], Train Loss: 2.4116, Train Acc: 12.50%, Val Loss: 2.0280, Val Acc: 12.50%
# Epoch [31/50], Train Loss: 2.3927, Train Acc: 14.29%, Val Loss: 2.0247, Val Acc: 11.11%
# Epoch [32/50], Train Loss: 2.3745, Train Acc: 14.29%, Val Loss: 2.0277, Val Acc: 14.29%
# Epoch [33/50], Train Loss: 2.3594, Train Acc: 16.67%, Val Loss: 2.0283, Val Acc: 12.50%
# Epoch [34/50], Train Loss: 2.3468, Train Acc: 12.50%, Val Loss: 2.0315, Val Acc: 11.11%
# Epoch [35/50], Train Loss: 2.3281, Train Acc: 20.00%, Val Loss: 2.0287, Val Acc: 11.11%
# Epoch [36/50], Train Loss: 2.3165, Train Acc: 12.50%, Val Loss: 2.0260, Val Acc: 12.50%
# Epoch [37/50], Train Loss: 2.3127, Train Acc: 0.00%, Val Loss: 2.0259, Val Acc: 11.11%
# Epoch [38/50], Train Loss: 2.2892, Train Acc: 16.67%, Val Loss: 2.0284, Val Acc: 12.50%
# Epoch [39/50], Train Loss: 2.2760, Train Acc: 16.67%, Val Loss: 2.0240, Val Acc: 11.11%
# Epoch [40/50], Train Loss: 2.2658, Train Acc: 14.29%, Val Loss: 2.0301, Val Acc: 12.50%
# Epoch [41/50], Train Loss: 2.2578, Train Acc: 16.67%, Val Loss: 2.0276, Val Acc: 12.50%
# Epoch [42/50], Train Loss: 2.2548, Train Acc: 12.50%, Val Loss: 2.0307, Val Acc: 12.50%
# Epoch [43/50], Train Loss: 2.2418, Train Acc: 12.50%, Val Loss: 2.0301, Val Acc: 12.50%
# Epoch [44/50], Train Loss: 2.2358, Train Acc: 14.29%, Val Loss: 2.0257, Val Acc: 14.29%
# Epoch [45/50], Train Loss: 2.2241, Train Acc: 20.00%, Val Loss: 2.0269, Val Acc: 11.11%
# Epoch [46/50], Train Loss: 2.2169, Train Acc: 14.29%, Val Loss: 2.0249, Val Acc: 12.50%
# Epoch [47/50], Train Loss: 2.2099, Train Acc: 16.67%, Val Loss: 2.0271, Val Acc: 12.50%
# Epoch [48/50], Train Loss: 2.2080, Train Acc: 14.29%, Val Loss: 2.0256, Val Acc: 11.11%
# Epoch [49/50], Train Loss: 2.2031, Train Acc: 12.50%, Val Loss: 2.0266, Val Acc: 14.29%
# Epoch [50/50], Train Loss: 2.1969, Train Acc: 11.11%, Val Loss: 2.0293, Val Acc: 12.50%
# F1 Score:  0.09426057813154588
# B_acc:  0.1111111111111111
# Best model has index  0
#
# Epoch [1/50], Train Loss: 4.2438, Train Acc: 0.00%, Val Loss: 2.1432, Val Acc: 12.50%
# Epoch [2/50], Train Loss: 3.9333, Train Acc: 14.29%, Val Loss: 2.1115, Val Acc: 14.29%
# Epoch [3/50], Train Loss: 3.7330, Train Acc: 0.00%, Val Loss: 2.0908, Val Acc: 12.50%
# Epoch [4/50], Train Loss: 3.5945, Train Acc: 16.67%, Val Loss: 2.0771, Val Acc: 14.29%
# Epoch [5/50], Train Loss: 3.4919, Train Acc: 12.50%, Val Loss: 2.0722, Val Acc: 12.50%
# Epoch [6/50], Train Loss: 3.4007, Train Acc: 16.67%, Val Loss: 2.0651, Val Acc: 16.67%
# Epoch [7/50], Train Loss: 3.3239, Train Acc: 14.29%, Val Loss: 2.0656, Val Acc: 14.29%
# Epoch [8/50], Train Loss: 3.2551, Train Acc: 14.29%, Val Loss: 2.0639, Val Acc: 12.50%
# Epoch [9/50], Train Loss: 3.1906, Train Acc: 12.50%, Val Loss: 2.0671, Val Acc: 12.50%
# Epoch [10/50], Train Loss: 3.1322, Train Acc: 11.11%, Val Loss: 2.0666, Val Acc: 14.29%
# Epoch [11/50], Train Loss: 3.0617, Train Acc: 14.29%, Val Loss: 2.0697, Val Acc: 14.29%
# Epoch [12/50], Train Loss: 3.0143, Train Acc: 14.29%, Val Loss: 2.0668, Val Acc: 12.50%
# Epoch [13/50], Train Loss: 2.9647, Train Acc: 20.00%, Val Loss: 2.0697, Val Acc: 14.29%
# Epoch [14/50], Train Loss: 2.9107, Train Acc: 14.29%, Val Loss: 2.0693, Val Acc: 14.29%
# Epoch [15/50], Train Loss: 2.8638, Train Acc: 14.29%, Val Loss: 2.0717, Val Acc: 12.50%
# Epoch [16/50], Train Loss: 2.8240, Train Acc: 14.29%, Val Loss: 2.0725, Val Acc: 14.29%
# Epoch [17/50], Train Loss: 2.7781, Train Acc: 14.29%, Val Loss: 2.0755, Val Acc: 12.50%
# Epoch [18/50], Train Loss: 2.7485, Train Acc: 0.00%, Val Loss: 2.0719, Val Acc: 14.29%
# Epoch [19/50], Train Loss: 2.7051, Train Acc: 12.50%, Val Loss: 2.0711, Val Acc: 12.50%
# Epoch [20/50], Train Loss: 2.6643, Train Acc: 16.67%, Val Loss: 2.0724, Val Acc: 14.29%
# Epoch [21/50], Train Loss: 2.6413, Train Acc: 11.11%, Val Loss: 2.0714, Val Acc: 14.29%
# Epoch [22/50], Train Loss: 2.6005, Train Acc: 12.50%, Val Loss: 2.0756, Val Acc: 12.50%
# Epoch [23/50], Train Loss: 2.5734, Train Acc: 12.50%, Val Loss: 2.0719, Val Acc: 14.29%
# Epoch [24/50], Train Loss: 2.5504, Train Acc: 12.50%, Val Loss: 2.0778, Val Acc: 12.50%
# Epoch [25/50], Train Loss: 2.5212, Train Acc: 14.29%, Val Loss: 2.0724, Val Acc: 16.67%
# Epoch [26/50], Train Loss: 2.4964, Train Acc: 14.29%, Val Loss: 2.0775, Val Acc: 12.50%
# Epoch [27/50], Train Loss: 2.4685, Train Acc: 16.67%, Val Loss: 2.0772, Val Acc: 12.50%
# Epoch [28/50], Train Loss: 2.4466, Train Acc: 14.29%, Val Loss: 2.0718, Val Acc: 14.29%
# Epoch [29/50], Train Loss: 2.4265, Train Acc: 16.67%, Val Loss: 2.0743, Val Acc: 12.50%
# Epoch [30/50], Train Loss: 2.4097, Train Acc: 12.50%, Val Loss: 2.0729, Val Acc: 14.29%
# Epoch [31/50], Train Loss: 2.3961, Train Acc: 12.50%, Val Loss: 2.0695, Val Acc: 12.50%
# Epoch [32/50], Train Loss: 2.3751, Train Acc: 14.29%, Val Loss: 2.0742, Val Acc: 12.50%
# Epoch [33/50], Train Loss: 2.3555, Train Acc: 14.29%, Val Loss: 2.0727, Val Acc: 12.50%
# Epoch [34/50], Train Loss: 2.3396, Train Acc: 16.67%, Val Loss: 2.0733, Val Acc: 12.50%
# Epoch [35/50], Train Loss: 2.3219, Train Acc: 16.67%, Val Loss: 2.0766, Val Acc: 12.50%
# Epoch [36/50], Train Loss: 2.3068, Train Acc: 16.67%, Val Loss: 2.0748, Val Acc: 14.29%
# Epoch [37/50], Train Loss: 2.3019, Train Acc: 16.67%, Val Loss: 2.0748, Val Acc: 14.29%
# Epoch [38/50], Train Loss: 2.2923, Train Acc: 16.67%, Val Loss: 2.0710, Val Acc: 14.29%
# Epoch [39/50], Train Loss: 2.2851, Train Acc: 12.50%, Val Loss: 2.0781, Val Acc: 12.50%
# Epoch [40/50], Train Loss: 2.2651, Train Acc: 12.50%, Val Loss: 2.0719, Val Acc: 14.29%
# Epoch [41/50], Train Loss: 2.2612, Train Acc: 12.50%, Val Loss: 2.0765, Val Acc: 14.29%
# Epoch [42/50], Train Loss: 2.2470, Train Acc: 14.29%, Val Loss: 2.0707, Val Acc: 14.29%
# Epoch [43/50], Train Loss: 2.2331, Train Acc: 16.67%, Val Loss: 2.0718, Val Acc: 12.50%
# Epoch [44/50], Train Loss: 2.2348, Train Acc: 11.11%, Val Loss: 2.0723, Val Acc: 14.29%
# Epoch [45/50], Train Loss: 2.2199, Train Acc: 16.67%, Val Loss: 2.0727, Val Acc: 12.50%
# Epoch [46/50], Train Loss: 2.2173, Train Acc: 14.29%, Val Loss: 2.0759, Val Acc: 12.50%
# Epoch [47/50], Train Loss: 2.2099, Train Acc: 14.29%, Val Loss: 2.0770, Val Acc: 12.50%
# Epoch [48/50], Train Loss: 2.1979, Train Acc: 16.67%, Val Loss: 2.0755, Val Acc: 12.50%
# Epoch [49/50], Train Loss: 2.1881, Train Acc: 20.00%, Val Loss: 2.0714, Val Acc: 12.50%
# Epoch [50/50], Train Loss: 2.1903, Train Acc: 14.29%, Val Loss: 2.0721, Val Acc: 12.50%
# F1 Score:  0.053468846663720725
# B_acc:  0.125
# Best model has index  0
#
# Epoch [1/50], Train Loss: 4.2825, Train Acc: 16.67%, Val Loss: 2.2034, Val Acc: 11.11%
# Epoch [2/50], Train Loss: 3.9625, Train Acc: 0.00%, Val Loss: 2.1785, Val Acc: 11.11%
# Epoch [3/50], Train Loss: 3.7479, Train Acc: 20.00%, Val Loss: 2.1647, Val Acc: 12.50%
# Epoch [4/50], Train Loss: 3.6097, Train Acc: 11.11%, Val Loss: 2.1625, Val Acc: 11.11%
# Epoch [5/50], Train Loss: 3.4964, Train Acc: 14.29%, Val Loss: 2.1614, Val Acc: 11.11%
# Epoch [6/50], Train Loss: 3.4062, Train Acc: 16.67%, Val Loss: 2.1658, Val Acc: 12.50%
# Epoch [7/50], Train Loss: 3.3249, Train Acc: 12.50%, Val Loss: 2.1679, Val Acc: 11.11%
# Epoch [8/50], Train Loss: 3.2525, Train Acc: 12.50%, Val Loss: 2.1755, Val Acc: 11.11%
# Epoch [9/50], Train Loss: 3.1781, Train Acc: 25.00%, Val Loss: 2.1797, Val Acc: 11.11%
# Epoch [10/50], Train Loss: 3.1224, Train Acc: 14.29%, Val Loss: 2.1837, Val Acc: 11.11%
# Epoch [11/50], Train Loss: 3.0593, Train Acc: 14.29%, Val Loss: 2.1891, Val Acc: 11.11%
# Epoch [12/50], Train Loss: 3.0039, Train Acc: 16.67%, Val Loss: 2.1953, Val Acc: 11.11%
# Epoch [13/50], Train Loss: 2.9469, Train Acc: 20.00%, Val Loss: 2.1880, Val Acc: 11.11%
# Epoch [14/50], Train Loss: 2.9032, Train Acc: 16.67%, Val Loss: 2.1933, Val Acc: 12.50%
# Epoch [15/50], Train Loss: 2.8626, Train Acc: 0.00%, Val Loss: 2.1939, Val Acc: 11.11%
# Epoch [16/50], Train Loss: 2.8137, Train Acc: 14.29%, Val Loss: 2.1951, Val Acc: 11.11%
# Epoch [17/50], Train Loss: 2.7726, Train Acc: 14.29%, Val Loss: 2.1920, Val Acc: 11.11%
# Epoch [18/50], Train Loss: 2.7261, Train Acc: 14.29%, Val Loss: 2.1948, Val Acc: 11.11%
# Epoch [19/50], Train Loss: 2.6901, Train Acc: 14.29%, Val Loss: 2.1966, Val Acc: 11.11%
# Epoch [20/50], Train Loss: 2.6552, Train Acc: 14.29%, Val Loss: 2.1956, Val Acc: 11.11%
# Epoch [21/50], Train Loss: 2.6236, Train Acc: 16.67%, Val Loss: 2.2044, Val Acc: 11.11%
# Epoch [22/50], Train Loss: 2.5946, Train Acc: 12.50%, Val Loss: 2.1937, Val Acc: 12.50%
# Epoch [23/50], Train Loss: 2.5683, Train Acc: 16.67%, Val Loss: 2.1986, Val Acc: 11.11%
# Epoch [24/50], Train Loss: 2.5375, Train Acc: 12.50%, Val Loss: 2.2020, Val Acc: 12.50%
# Epoch [25/50], Train Loss: 2.5130, Train Acc: 16.67%, Val Loss: 2.2008, Val Acc: 11.11%
# Epoch [26/50], Train Loss: 2.4810, Train Acc: 12.50%, Val Loss: 2.1991, Val Acc: 12.50%
# Epoch [27/50], Train Loss: 2.4643, Train Acc: 12.50%, Val Loss: 2.1964, Val Acc: 11.11%
# Epoch [28/50], Train Loss: 2.4335, Train Acc: 16.67%, Val Loss: 2.1966, Val Acc: 12.50%
# Epoch [29/50], Train Loss: 2.4204, Train Acc: 12.50%, Val Loss: 2.1991, Val Acc: 11.11%
# Epoch [30/50], Train Loss: 2.3927, Train Acc: 20.00%, Val Loss: 2.1973, Val Acc: 11.11%
# Epoch [31/50], Train Loss: 2.3770, Train Acc: 14.29%, Val Loss: 2.2007, Val Acc: 11.11%
# Epoch [32/50], Train Loss: 2.3552, Train Acc: 20.00%, Val Loss: 2.2002, Val Acc: 11.11%
# Epoch [33/50], Train Loss: 2.3424, Train Acc: 16.67%, Val Loss: 2.1998, Val Acc: 12.50%
# Epoch [34/50], Train Loss: 2.3311, Train Acc: 14.29%, Val Loss: 2.2065, Val Acc: 11.11%
# Epoch [35/50], Train Loss: 2.3128, Train Acc: 16.67%, Val Loss: 2.2017, Val Acc: 11.11%
# Epoch [36/50], Train Loss: 2.3030, Train Acc: 14.29%, Val Loss: 2.2072, Val Acc: 0.00%
# Epoch [37/50], Train Loss: 2.2875, Train Acc: 16.67%, Val Loss: 2.2034, Val Acc: 11.11%
# Epoch [38/50], Train Loss: 2.2782, Train Acc: 14.29%, Val Loss: 2.1981, Val Acc: 12.50%
# Epoch [39/50], Train Loss: 2.2670, Train Acc: 12.50%, Val Loss: 2.2003, Val Acc: 11.11%
# Epoch [40/50], Train Loss: 2.2486, Train Acc: 20.00%, Val Loss: 2.1996, Val Acc: 11.11%
# Epoch [41/50], Train Loss: 2.2444, Train Acc: 12.50%, Val Loss: 2.2048, Val Acc: 11.11%
# Epoch [42/50], Train Loss: 2.2358, Train Acc: 14.29%, Val Loss: 2.2034, Val Acc: 12.50%
# Epoch [43/50], Train Loss: 2.2254, Train Acc: 14.29%, Val Loss: 2.2040, Val Acc: 11.11%
# Epoch [44/50], Train Loss: 2.2165, Train Acc: 16.67%, Val Loss: 2.2084, Val Acc: 12.50%
# Epoch [45/50], Train Loss: 2.2070, Train Acc: 16.67%, Val Loss: 2.2046, Val Acc: 14.29%
# Epoch [46/50], Train Loss: 2.2055, Train Acc: 11.11%, Val Loss: 2.1999, Val Acc: 11.11%
# Epoch [47/50], Train Loss: 2.1970, Train Acc: 16.67%, Val Loss: 2.2025, Val Acc: 12.50%
# Epoch [48/50], Train Loss: 2.1906, Train Acc: 14.29%, Val Loss: 2.2056, Val Acc: 11.11%
# Epoch [49/50], Train Loss: 2.1855, Train Acc: 11.11%, Val Loss: 2.2013, Val Acc: 11.11%
# Epoch [50/50], Train Loss: 2.1820, Train Acc: 16.67%, Val Loss: 2.2004, Val Acc: 12.50%
# F1 Score:  0.02949308755760369
# B_acc:  0.1111111111111111
# Best model has index  0
#
# Epoch [1/50], Train Loss: 4.2571, Train Acc: 0.00%, Val Loss: 2.2355, Val Acc: 12.50%
# Epoch [2/50], Train Loss: 3.9436, Train Acc: 12.50%, Val Loss: 2.1791, Val Acc: 12.50%
# Epoch [3/50], Train Loss: 3.7423, Train Acc: 16.67%, Val Loss: 2.1409, Val Acc: 12.50%
# Epoch [4/50], Train Loss: 3.6057, Train Acc: 16.67%, Val Loss: 2.1122, Val Acc: 12.50%
# Epoch [5/50], Train Loss: 3.4970, Train Acc: 25.00%, Val Loss: 2.0871, Val Acc: 12.50%
# Epoch [6/50], Train Loss: 3.4201, Train Acc: 14.29%, Val Loss: 2.0722, Val Acc: 12.50%
# Epoch [7/50], Train Loss: 3.3346, Train Acc: 12.50%, Val Loss: 2.0608, Val Acc: 14.29%
# Epoch [8/50], Train Loss: 3.2709, Train Acc: 16.67%, Val Loss: 2.0529, Val Acc: 11.11%
# Epoch [9/50], Train Loss: 3.2002, Train Acc: 14.29%, Val Loss: 2.0481, Val Acc: 12.50%
# Epoch [10/50], Train Loss: 3.1405, Train Acc: 12.50%, Val Loss: 2.0491, Val Acc: 12.50%
# Epoch [11/50], Train Loss: 3.0831, Train Acc: 12.50%, Val Loss: 2.0411, Val Acc: 12.50%
# Epoch [12/50], Train Loss: 3.0201, Train Acc: 16.67%, Val Loss: 2.0419, Val Acc: 11.11%
# Epoch [13/50], Train Loss: 2.9658, Train Acc: 16.67%, Val Loss: 2.0435, Val Acc: 11.11%
# Epoch [14/50], Train Loss: 2.9247, Train Acc: 0.00%, Val Loss: 2.0395, Val Acc: 11.11%
# Epoch [15/50], Train Loss: 2.8738, Train Acc: 14.29%, Val Loss: 2.0370, Val Acc: 11.11%
# Epoch [16/50], Train Loss: 2.8262, Train Acc: 16.67%, Val Loss: 2.0344, Val Acc: 11.11%
# Epoch [17/50], Train Loss: 2.7884, Train Acc: 12.50%, Val Loss: 2.0377, Val Acc: 14.29%
# Epoch [18/50], Train Loss: 2.7436, Train Acc: 14.29%, Val Loss: 2.0319, Val Acc: 12.50%
# Epoch [19/50], Train Loss: 2.7095, Train Acc: 12.50%, Val Loss: 2.0348, Val Acc: 12.50%
# Epoch [20/50], Train Loss: 2.6732, Train Acc: 14.29%, Val Loss: 2.0315, Val Acc: 14.29%
# Epoch [21/50], Train Loss: 2.6404, Train Acc: 14.29%, Val Loss: 2.0293, Val Acc: 11.11%
# Epoch [22/50], Train Loss: 2.6089, Train Acc: 12.50%, Val Loss: 2.0303, Val Acc: 14.29%
# Epoch [23/50], Train Loss: 2.5786, Train Acc: 16.67%, Val Loss: 2.0300, Val Acc: 12.50%
# Epoch [24/50], Train Loss: 2.5544, Train Acc: 12.50%, Val Loss: 2.0299, Val Acc: 12.50%
# Epoch [25/50], Train Loss: 2.5302, Train Acc: 12.50%, Val Loss: 2.0314, Val Acc: 12.50%
# Epoch [26/50], Train Loss: 2.4969, Train Acc: 16.67%, Val Loss: 2.0319, Val Acc: 12.50%
# Epoch [27/50], Train Loss: 2.4774, Train Acc: 14.29%, Val Loss: 2.0262, Val Acc: 14.29%
# Epoch [28/50], Train Loss: 2.4553, Train Acc: 16.67%, Val Loss: 2.0341, Val Acc: 12.50%
# Epoch [29/50], Train Loss: 2.4291, Train Acc: 16.67%, Val Loss: 2.0335, Val Acc: 12.50%
# Epoch [30/50], Train Loss: 2.4175, Train Acc: 11.11%, Val Loss: 2.0310, Val Acc: 12.50%
# Epoch [31/50], Train Loss: 2.3961, Train Acc: 14.29%, Val Loss: 2.0305, Val Acc: 11.11%
# Epoch [32/50], Train Loss: 2.3798, Train Acc: 14.29%, Val Loss: 2.0305, Val Acc: 12.50%
# Epoch [33/50], Train Loss: 2.3605, Train Acc: 16.67%, Val Loss: 2.0331, Val Acc: 12.50%
# Epoch [34/50], Train Loss: 2.3464, Train Acc: 14.29%, Val Loss: 2.0326, Val Acc: 11.11%
# Epoch [35/50], Train Loss: 2.3326, Train Acc: 16.67%, Val Loss: 2.0299, Val Acc: 11.11%
# Epoch [36/50], Train Loss: 2.3163, Train Acc: 16.67%, Val Loss: 2.0303, Val Acc: 12.50%
# Epoch [37/50], Train Loss: 2.3080, Train Acc: 14.29%, Val Loss: 2.0354, Val Acc: 12.50%
# Epoch [38/50], Train Loss: 2.2992, Train Acc: 12.50%, Val Loss: 2.0343, Val Acc: 12.50%
# Epoch [39/50], Train Loss: 2.2821, Train Acc: 14.29%, Val Loss: 2.0314, Val Acc: 12.50%
# Epoch [40/50], Train Loss: 2.2728, Train Acc: 12.50%, Val Loss: 2.0306, Val Acc: 11.11%
# Epoch [41/50], Train Loss: 2.2656, Train Acc: 14.29%, Val Loss: 2.0288, Val Acc: 12.50%
# Epoch [42/50], Train Loss: 2.2478, Train Acc: 14.29%, Val Loss: 2.0303, Val Acc: 12.50%
# Epoch [43/50], Train Loss: 2.2423, Train Acc: 14.29%, Val Loss: 2.0255, Val Acc: 12.50%
# Epoch [44/50], Train Loss: 2.2327, Train Acc: 14.29%, Val Loss: 2.0305, Val Acc: 11.11%
# Epoch [45/50], Train Loss: 2.2253, Train Acc: 16.67%, Val Loss: 2.0295, Val Acc: 12.50%
# Epoch [46/50], Train Loss: 2.2194, Train Acc: 12.50%, Val Loss: 2.0333, Val Acc: 11.11%
# Epoch [47/50], Train Loss: 2.2112, Train Acc: 16.67%, Val Loss: 2.0274, Val Acc: 12.50%
# Epoch [48/50], Train Loss: 2.2139, Train Acc: 12.50%, Val Loss: 2.0327, Val Acc: 12.50%
# Epoch [49/50], Train Loss: 2.2031, Train Acc: 12.50%, Val Loss: 2.0266, Val Acc: 14.29%
# Epoch [50/50], Train Loss: 2.1970, Train Acc: 12.50%, Val Loss: 2.0325, Val Acc: 12.50%
# F1 Score:  0.09426057813154588
# B_acc:  0.1111111111111111
# Best model has index  0
#
# Epoch [1/50], Train Loss: 4.2135, Train Acc: 20.00%, Val Loss: 2.1933, Val Acc: 11.11%
# Epoch [2/50], Train Loss: 3.9030, Train Acc: 20.00%, Val Loss: 2.1765, Val Acc: 11.11%
# Epoch [3/50], Train Loss: 3.7048, Train Acc: 16.67%, Val Loss: 2.1680, Val Acc: 11.11%
# Epoch [4/50], Train Loss: 3.5699, Train Acc: 12.50%, Val Loss: 2.1637, Val Acc: 11.11%
# Epoch [5/50], Train Loss: 3.4687, Train Acc: 14.29%, Val Loss: 2.1644, Val Acc: 12.50%
# Epoch [6/50], Train Loss: 3.3838, Train Acc: 14.29%, Val Loss: 2.1620, Val Acc: 12.50%
# Epoch [7/50], Train Loss: 3.3081, Train Acc: 14.29%, Val Loss: 2.1669, Val Acc: 12.50%
# Epoch [8/50], Train Loss: 3.2437, Train Acc: 12.50%, Val Loss: 2.1683, Val Acc: 12.50%
# Epoch [9/50], Train Loss: 3.1718, Train Acc: 14.29%, Val Loss: 2.1683, Val Acc: 12.50%
# Epoch [10/50], Train Loss: 3.1150, Train Acc: 14.29%, Val Loss: 2.1746, Val Acc: 12.50%
# Epoch [11/50], Train Loss: 3.0582, Train Acc: 11.11%, Val Loss: 2.1730, Val Acc: 11.11%
# Epoch [12/50], Train Loss: 3.0027, Train Acc: 11.11%, Val Loss: 2.1707, Val Acc: 14.29%
# Epoch [13/50], Train Loss: 2.9457, Train Acc: 12.50%, Val Loss: 2.1720, Val Acc: 12.50%
# Epoch [14/50], Train Loss: 2.8976, Train Acc: 12.50%, Val Loss: 2.1718, Val Acc: 14.29%
# Epoch [15/50], Train Loss: 2.8551, Train Acc: 14.29%, Val Loss: 2.1723, Val Acc: 16.67%
# Epoch [16/50], Train Loss: 2.8033, Train Acc: 16.67%, Val Loss: 2.1714, Val Acc: 12.50%
# Epoch [17/50], Train Loss: 2.7628, Train Acc: 14.29%, Val Loss: 2.1762, Val Acc: 11.11%
# Epoch [18/50], Train Loss: 2.7255, Train Acc: 16.67%, Val Loss: 2.1747, Val Acc: 12.50%
# Epoch [19/50], Train Loss: 2.6902, Train Acc: 16.67%, Val Loss: 2.1744, Val Acc: 11.11%
# Epoch [20/50], Train Loss: 2.6577, Train Acc: 14.29%, Val Loss: 2.1801, Val Acc: 11.11%
# Epoch [21/50], Train Loss: 2.6185, Train Acc: 16.67%, Val Loss: 2.1762, Val Acc: 11.11%
# Epoch [22/50], Train Loss: 2.5911, Train Acc: 14.29%, Val Loss: 2.1768, Val Acc: 12.50%
# Epoch [23/50], Train Loss: 2.5645, Train Acc: 14.29%, Val Loss: 2.1812, Val Acc: 11.11%
# Epoch [24/50], Train Loss: 2.5335, Train Acc: 14.29%, Val Loss: 2.1746, Val Acc: 12.50%
# Epoch [25/50], Train Loss: 2.5131, Train Acc: 14.29%, Val Loss: 2.1778, Val Acc: 14.29%
# Epoch [26/50], Train Loss: 2.4749, Train Acc: 20.00%, Val Loss: 2.1747, Val Acc: 11.11%
# Epoch [27/50], Train Loss: 2.4593, Train Acc: 16.67%, Val Loss: 2.1744, Val Acc: 12.50%
# Epoch [28/50], Train Loss: 2.4441, Train Acc: 14.29%, Val Loss: 2.1763, Val Acc: 12.50%
# Epoch [29/50], Train Loss: 2.4194, Train Acc: 14.29%, Val Loss: 2.1761, Val Acc: 12.50%
# Epoch [30/50], Train Loss: 2.3983, Train Acc: 16.67%, Val Loss: 2.1746, Val Acc: 12.50%
# Epoch [31/50], Train Loss: 2.3813, Train Acc: 12.50%, Val Loss: 2.1818, Val Acc: 11.11%
# Epoch [32/50], Train Loss: 2.3678, Train Acc: 12.50%, Val Loss: 2.1789, Val Acc: 12.50%
# Epoch [33/50], Train Loss: 2.3501, Train Acc: 0.00%, Val Loss: 2.1766, Val Acc: 14.29%
# Epoch [34/50], Train Loss: 2.3257, Train Acc: 16.67%, Val Loss: 2.1757, Val Acc: 12.50%
# Epoch [35/50], Train Loss: 2.3181, Train Acc: 12.50%, Val Loss: 2.1736, Val Acc: 12.50%
# Epoch [36/50], Train Loss: 2.3011, Train Acc: 14.29%, Val Loss: 2.1719, Val Acc: 11.11%
# Epoch [37/50], Train Loss: 2.2839, Train Acc: 16.67%, Val Loss: 2.1773, Val Acc: 12.50%
# Epoch [38/50], Train Loss: 2.2729, Train Acc: 20.00%, Val Loss: 2.1736, Val Acc: 11.11%
# Epoch [39/50], Train Loss: 2.2646, Train Acc: 16.67%, Val Loss: 2.1808, Val Acc: 11.11%
# Epoch [40/50], Train Loss: 2.2577, Train Acc: 14.29%, Val Loss: 2.1758, Val Acc: 12.50%
# Epoch [41/50], Train Loss: 2.2481, Train Acc: 11.11%, Val Loss: 2.1761, Val Acc: 11.11%
# Epoch [42/50], Train Loss: 2.2371, Train Acc: 14.29%, Val Loss: 2.1766, Val Acc: 12.50%
# Epoch [43/50], Train Loss: 2.2226, Train Acc: 20.00%, Val Loss: 2.1768, Val Acc: 12.50%
# Epoch [44/50], Train Loss: 2.2178, Train Acc: 12.50%, Val Loss: 2.1758, Val Acc: 11.11%
# Epoch [45/50], Train Loss: 2.2169, Train Acc: 11.11%, Val Loss: 2.1754, Val Acc: 11.11%
# Epoch [46/50], Train Loss: 2.2013, Train Acc: 16.67%, Val Loss: 2.1763, Val Acc: 11.11%
# Epoch [47/50], Train Loss: 2.2013, Train Acc: 12.50%, Val Loss: 2.1754, Val Acc: 12.50%
# Epoch [48/50], Train Loss: 2.1916, Train Acc: 12.50%, Val Loss: 2.1773, Val Acc: 11.11%
# Epoch [49/50], Train Loss: 2.1833, Train Acc: 14.29%, Val Loss: 2.1752, Val Acc: 12.50%
# Epoch [50/50], Train Loss: 2.1731, Train Acc: 20.00%, Val Loss: 2.1777, Val Acc: 11.11%
# F1 Score:  0.02949308755760369
# B_acc:  0.1111111111111111
# Best model has index  0
#
# Epoch [1/50], Train Loss: 4.2112, Train Acc: 20.00%, Val Loss: 2.2083, Val Acc: 12.50%
# Epoch [2/50], Train Loss: 3.9078, Train Acc: 12.50%, Val Loss: 2.1750, Val Acc: 12.50%
# Epoch [3/50], Train Loss: 3.7090, Train Acc: 12.50%, Val Loss: 2.1509, Val Acc: 11.11%
# Epoch [4/50], Train Loss: 3.5744, Train Acc: 14.29%, Val Loss: 2.1399, Val Acc: 14.29%
# Epoch [5/50], Train Loss: 3.4724, Train Acc: 12.50%, Val Loss: 2.1340, Val Acc: 14.29%
# Epoch [6/50], Train Loss: 3.3901, Train Acc: 14.29%, Val Loss: 2.1324, Val Acc: 11.11%
# Epoch [7/50], Train Loss: 3.3135, Train Acc: 12.50%, Val Loss: 2.1327, Val Acc: 11.11%
# Epoch [8/50], Train Loss: 3.2440, Train Acc: 14.29%, Val Loss: 2.1330, Val Acc: 12.50%
# Epoch [9/50], Train Loss: 3.1769, Train Acc: 14.29%, Val Loss: 2.1360, Val Acc: 11.11%
# Epoch [10/50], Train Loss: 3.1145, Train Acc: 16.67%, Val Loss: 2.1311, Val Acc: 11.11%
# Epoch [11/50], Train Loss: 3.0522, Train Acc: 20.00%, Val Loss: 2.1350, Val Acc: 11.11%
# Epoch [12/50], Train Loss: 3.0037, Train Acc: 14.29%, Val Loss: 2.1349, Val Acc: 14.29%
# Epoch [13/50], Train Loss: 2.9519, Train Acc: 12.50%, Val Loss: 2.1336, Val Acc: 12.50%
# Epoch [14/50], Train Loss: 2.8992, Train Acc: 14.29%, Val Loss: 2.1358, Val Acc: 11.11%
# Epoch [15/50], Train Loss: 2.8513, Train Acc: 16.67%, Val Loss: 2.1334, Val Acc: 11.11%
# Epoch [16/50], Train Loss: 2.8140, Train Acc: 14.29%, Val Loss: 2.1351, Val Acc: 11.11%
# Epoch [17/50], Train Loss: 2.7670, Train Acc: 16.67%, Val Loss: 2.1342, Val Acc: 12.50%
# Epoch [18/50], Train Loss: 2.7321, Train Acc: 12.50%, Val Loss: 2.1324, Val Acc: 12.50%
# Epoch [19/50], Train Loss: 2.6972, Train Acc: 14.29%, Val Loss: 2.1436, Val Acc: 12.50%
# Epoch [20/50], Train Loss: 2.6644, Train Acc: 0.00%, Val Loss: 2.1391, Val Acc: 11.11%
# Epoch [21/50], Train Loss: 2.6238, Train Acc: 14.29%, Val Loss: 2.1356, Val Acc: 11.11%
# Epoch [22/50], Train Loss: 2.5916, Train Acc: 12.50%, Val Loss: 2.1355, Val Acc: 11.11%
# Epoch [23/50], Train Loss: 2.5709, Train Acc: 12.50%, Val Loss: 2.1334, Val Acc: 12.50%
# Epoch [24/50], Train Loss: 2.5375, Train Acc: 12.50%, Val Loss: 2.1380, Val Acc: 11.11%
# Epoch [25/50], Train Loss: 2.5053, Train Acc: 16.67%, Val Loss: 2.1358, Val Acc: 11.11%
# Epoch [26/50], Train Loss: 2.4863, Train Acc: 14.29%, Val Loss: 2.1354, Val Acc: 11.11%
# Epoch [27/50], Train Loss: 2.4625, Train Acc: 14.29%, Val Loss: 2.1347, Val Acc: 11.11%
# Epoch [28/50], Train Loss: 2.4411, Train Acc: 12.50%, Val Loss: 2.1361, Val Acc: 11.11%
# Epoch [29/50], Train Loss: 2.4232, Train Acc: 12.50%, Val Loss: 2.1336, Val Acc: 14.29%
# Epoch [30/50], Train Loss: 2.3982, Train Acc: 20.00%, Val Loss: 2.1328, Val Acc: 12.50%
# Epoch [31/50], Train Loss: 2.3807, Train Acc: 12.50%, Val Loss: 2.1353, Val Acc: 12.50%
# Epoch [32/50], Train Loss: 2.3628, Train Acc: 14.29%, Val Loss: 2.1369, Val Acc: 12.50%
# Epoch [33/50], Train Loss: 2.3493, Train Acc: 14.29%, Val Loss: 2.1347, Val Acc: 11.11%
# Epoch [34/50], Train Loss: 2.3376, Train Acc: 14.29%, Val Loss: 2.1395, Val Acc: 11.11%
# Epoch [35/50], Train Loss: 2.3232, Train Acc: 14.29%, Val Loss: 2.1402, Val Acc: 11.11%
# Epoch [36/50], Train Loss: 2.3063, Train Acc: 14.29%, Val Loss: 2.1356, Val Acc: 11.11%
# Epoch [37/50], Train Loss: 2.3004, Train Acc: 14.29%, Val Loss: 2.1395, Val Acc: 12.50%
# Epoch [38/50], Train Loss: 2.2809, Train Acc: 14.29%, Val Loss: 2.1383, Val Acc: 12.50%
# Epoch [39/50], Train Loss: 2.2606, Train Acc: 20.00%, Val Loss: 2.1394, Val Acc: 12.50%
# Epoch [40/50], Train Loss: 2.2567, Train Acc: 16.67%, Val Loss: 2.1382, Val Acc: 11.11%
# Epoch [41/50], Train Loss: 2.2456, Train Acc: 14.29%, Val Loss: 2.1358, Val Acc: 12.50%
# Epoch [42/50], Train Loss: 2.2404, Train Acc: 12.50%, Val Loss: 2.1395, Val Acc: 11.11%
# Epoch [43/50], Train Loss: 2.2263, Train Acc: 14.29%, Val Loss: 2.1344, Val Acc: 12.50%
# Epoch [44/50], Train Loss: 2.2308, Train Acc: 0.00%, Val Loss: 2.1373, Val Acc: 11.11%
# Epoch [45/50], Train Loss: 2.2175, Train Acc: 14.29%, Val Loss: 2.1341, Val Acc: 11.11%
# Epoch [46/50], Train Loss: 2.2121, Train Acc: 11.11%, Val Loss: 2.1354, Val Acc: 11.11%
# Epoch [47/50], Train Loss: 2.2002, Train Acc: 14.29%, Val Loss: 2.1345, Val Acc: 12.50%
# Epoch [48/50], Train Loss: 2.1892, Train Acc: 16.67%, Val Loss: 2.1360, Val Acc: 11.11%
# Epoch [49/50], Train Loss: 2.1853, Train Acc: 16.67%, Val Loss: 2.1372, Val Acc: 11.11%
# Epoch [50/50], Train Loss: 2.1829, Train Acc: 14.29%, Val Loss: 2.1375, Val Acc: 11.11%
# F1 Score:  0.04480286738351254
# B_acc:  0.1111111111111111
# Best model has index  0
#
# Epoch [1/50], Train Loss: 2.2265, Train Acc: 0.00%, Val Loss: 0.1739, Val Acc: 0.00%
# Epoch [2/50], Train Loss: 1.9026, Train Acc: 11.11%, Val Loss: 0.1295, Val Acc: 11.11%
# Epoch [3/50], Train Loss: 1.7027, Train Acc: 12.50%, Val Loss: 0.1097, Val Acc: 11.11%
# Epoch [4/50], Train Loss: 1.5705, Train Acc: 12.50%, Val Loss: 0.1018, Val Acc: 11.11%
# Epoch [5/50], Train Loss: 1.4701, Train Acc: 20.00%, Val Loss: 0.0988, Val Acc: 12.50%
# Epoch [6/50], Train Loss: 1.3847, Train Acc: 16.67%, Val Loss: 0.0975, Val Acc: 11.11%
# Epoch [7/50], Train Loss: 1.3073, Train Acc: 14.29%, Val Loss: 0.0968, Val Acc: 12.50%
# Epoch [8/50], Train Loss: 1.2350, Train Acc: 14.29%, Val Loss: 0.0966, Val Acc: 11.11%
# Epoch [9/50], Train Loss: 1.1670, Train Acc: 12.50%, Val Loss: 0.0962, Val Acc: 11.11%
# Epoch [10/50], Train Loss: 1.1028, Train Acc: 14.29%, Val Loss: 0.0960, Val Acc: 11.11%
# Epoch [11/50], Train Loss: 1.0423, Train Acc: 14.29%, Val Loss: 0.0960, Val Acc: 11.11%
# Epoch [12/50], Train Loss: 0.9850, Train Acc: 16.67%, Val Loss: 0.0957, Val Acc: 11.11%
# Epoch [13/50], Train Loss: 0.9310, Train Acc: 14.29%, Val Loss: 0.0957, Val Acc: 11.11%
# Epoch [14/50], Train Loss: 0.8802, Train Acc: 14.29%, Val Loss: 0.0955, Val Acc: 12.50%
# Epoch [15/50], Train Loss: 0.8322, Train Acc: 16.67%, Val Loss: 0.0957, Val Acc: 11.11%
# Epoch [16/50], Train Loss: 0.7869, Train Acc: 14.29%, Val Loss: 0.0952, Val Acc: 12.50%
# Epoch [17/50], Train Loss: 0.7442, Train Acc: 12.50%, Val Loss: 0.0955, Val Acc: 11.11%
# Epoch [18/50], Train Loss: 0.7038, Train Acc: 0.00%, Val Loss: 0.0953, Val Acc: 11.11%
# Epoch [19/50], Train Loss: 0.6660, Train Acc: 12.50%, Val Loss: 0.0956, Val Acc: 11.11%
# Epoch [20/50], Train Loss: 0.6302, Train Acc: 14.29%, Val Loss: 0.0952, Val Acc: 11.11%
# Epoch [21/50], Train Loss: 0.5966, Train Acc: 14.29%, Val Loss: 0.0953, Val Acc: 11.11%
# Epoch [22/50], Train Loss: 0.5647, Train Acc: 20.00%, Val Loss: 0.0953, Val Acc: 11.11%
# Epoch [23/50], Train Loss: 0.5348, Train Acc: 20.00%, Val Loss: 0.0953, Val Acc: 14.29%
# Epoch [24/50], Train Loss: 0.5070, Train Acc: 12.50%, Val Loss: 0.0949, Val Acc: 11.11%
# Epoch [25/50], Train Loss: 0.4806, Train Acc: 12.50%, Val Loss: 0.0953, Val Acc: 11.11%
# Epoch [26/50], Train Loss: 0.4558, Train Acc: 16.67%, Val Loss: 0.0950, Val Acc: 11.11%
# Epoch [27/50], Train Loss: 0.4327, Train Acc: 16.67%, Val Loss: 0.0951, Val Acc: 11.11%
# Epoch [28/50], Train Loss: 0.4108, Train Acc: 14.29%, Val Loss: 0.0952, Val Acc: 12.50%
# Epoch [29/50], Train Loss: 0.3905, Train Acc: 12.50%, Val Loss: 0.0949, Val Acc: 11.11%
# Epoch [30/50], Train Loss: 0.3711, Train Acc: 12.50%, Val Loss: 0.0952, Val Acc: 11.11%
# Epoch [31/50], Train Loss: 0.3531, Train Acc: 12.50%, Val Loss: 0.0951, Val Acc: 14.29%
# Epoch [32/50], Train Loss: 0.3362, Train Acc: 12.50%, Val Loss: 0.0951, Val Acc: 11.11%
# Epoch [33/50], Train Loss: 0.3205, Train Acc: 14.29%, Val Loss: 0.0951, Val Acc: 11.11%
# Epoch [34/50], Train Loss: 0.3058, Train Acc: 11.11%, Val Loss: 0.0948, Val Acc: 12.50%
# Epoch [35/50], Train Loss: 0.2918, Train Acc: 16.67%, Val Loss: 0.0950, Val Acc: 11.11%
# Epoch [36/50], Train Loss: 0.2790, Train Acc: 14.29%, Val Loss: 0.0950, Val Acc: 11.11%
# Epoch [37/50], Train Loss: 0.2665, Train Acc: 20.00%, Val Loss: 0.0950, Val Acc: 11.11%
# ...
# Epoch [23/50], Train Loss: 0.3078, Train Acc: 20.00%, Val Loss: 0.0993, Val Acc: 11.11%
# Epoch [24/50], Train Loss: 0.2880, Train Acc: 11.11%, Val Loss: 0.0992, Val Acc: 12.50%
# Epoch [25/50], Train Loss: 0.2698, Train Acc: 12.50%, Val Loss: 0.0993, Val Acc: 12.50%
# Epoch [26/50], Train Loss: 0.2527, Train Acc: 14.29%, Val Loss: 0.0995, Val Acc: 11.11%
# Epoch [27/50], Train Loss: 0.2369, Train Acc: 16.67%, Val Loss: 0.0994, Val Acc: 11.11%
# Epoch [28/50], Train Loss: 0.2225, Train Acc: 14.29%, Val Loss: 0.0995, Val Acc: 11.11%
# Epoch [29/50], Train Loss: 0.2092, Train Acc: 14.29%, Val Loss: 0.0994, Val Acc: 11.11%
# Epoch [30/50], Train Loss: 0.1972, Train Acc: 0.00%, Val Loss: 0.0995, Val Acc: 11.11%
# Epoch [31/50], Train Loss: 0.1859, Train Acc: 14.29%, Val Loss: 0.0995, Val Acc: 12.50%
# Epoch [32/50], Train Loss: 0.1758, Train Acc: 14.29%, Val Loss: 0.0994, Val Acc: 11.11%
# Epoch [33/50], Train Loss: 0.1669, Train Acc: 11.11%, Val Loss: 0.0993, Val Acc: 12.50%
# Epoch [34/50], Train Loss: 0.1584, Train Acc: 16.67%, Val Loss: 0.0992, Val Acc: 12.50%
# Epoch [35/50], Train Loss: 0.1508, Train Acc: 20.00%, Val Loss: 0.0993, Val Acc: 11.11%
# Epoch [36/50], Train Loss: 0.1443, Train Acc: 16.67%, Val Loss: 0.0993, Val Acc: 12.50%
# Epoch [37/50], Train Loss: 0.1383, Train Acc: 14.29%, Val Loss: 0.0992, Val Acc: 14.29%
# Epoch [38/50], Train Loss: 0.1329, Train Acc: 16.67%, Val Loss: 0.0994, Val Acc: 11.11%
# Epoch [39/50], Train Loss: 0.1285, Train Acc: 12.50%, Val Loss: 0.0993, Val Acc: 11.11%
# Epoch [40/50], Train Loss: 0.1242, Train Acc: 12.50%, Val Loss: 0.0993, Val Acc: 11.11%
# Epoch [41/50], Train Loss: 0.1207, Train Acc: 11.11%, Val Loss: 0.0993, Val Acc: 11.11%
# Epoch [42/50], Train Loss: 0.1174, Train Acc: 14.29%, Val Loss: 0.0992, Val Acc: 11.11%
# Epoch [43/50], Train Loss: 0.1147, Train Acc: 14.29%, Val Loss: 0.0993, Val Acc: 11.11%
# Epoch [44/50], Train Loss: 0.1125, Train Acc: 14.29%, Val Loss: 0.0993, Val Acc: 11.11%
# Epoch [45/50], Train Loss: 0.1105, Train Acc: 12.50%, Val Loss: 0.0993, Val Acc: 12.50%
# Epoch [46/50], Train Loss: 0.1089, Train Acc: 14.29%, Val Loss: 0.0993, Val Acc: 12.50%
# Epoch [47/50], Train Loss: 0.1073, Train Acc: 16.67%, Val Loss: 0.0993, Val Acc: 11.11%
# Epoch [48/50], Train Loss: 0.1063, Train Acc: 14.29%, Val Loss: 0.0991, Val Acc: 12.50%
# Epoch [49/50], Train Loss: 0.1052, Train Acc: 16.67%, Val Loss: 0.0992, Val Acc: 11.11%
# Epoch [50/50], Train Loss: 0.1045, Train Acc: 12.50%, Val Loss: 0.0993, Val Acc: 11.11%
# F1 Score:  0.02949308755760369
# B_acc:  0.1111111111111111
# Best model has index  0
#
# Epoch [1/50], Train Loss: 1.7862, Train Acc: 32.50%, Val Loss: 0.0920, Val Acc: 33.33%
# Epoch [2/50], Train Loss: 1.4183, Train Acc: 33.33%, Val Loss: 0.0902, Val Acc: 21.73%
# Epoch [3/50], Train Loss: 1.2610, Train Acc: 58.33%, Val Loss: 0.0904, Val Acc: 39.29%
# Epoch [4/50], Train Loss: 1.1491, Train Acc: 22.22%, Val Loss: 0.0903, Val Acc: 27.50%
# Epoch [5/50], Train Loss: 1.0572, Train Acc: 28.57%, Val Loss: 0.0899, Val Acc: 21.88%
# Epoch [6/50], Train Loss: 0.9782, Train Acc: 23.81%, Val Loss: 0.0899, Val Acc: 20.00%
# Epoch [7/50], Train Loss: 0.9089, Train Acc: 12.50%, Val Loss: 0.0914, Val Acc: 17.14%
# Epoch [8/50], Train Loss: 0.8454, Train Acc: 28.57%, Val Loss: 0.0921, Val Acc: 19.44%
# Epoch [9/50], Train Loss: 0.7879, Train Acc: 22.22%, Val Loss: 0.0912, Val Acc: 22.50%
# Epoch [10/50], Train Loss: 0.7348, Train Acc: 16.67%, Val Loss: 0.0916, Val Acc: 16.67%
# Epoch [11/50], Train Loss: 0.6862, Train Acc: 37.50%, Val Loss: 0.0923, Val Acc: 20.00%
# Epoch [12/50], Train Loss: 0.6406, Train Acc: 14.29%, Val Loss: 0.0945, Val Acc: 13.76%
# Epoch [13/50], Train Loss: 0.5983, Train Acc: 19.05%, Val Loss: 0.0937, Val Acc: 16.67%
# Epoch [14/50], Train Loss: 0.5588, Train Acc: 28.57%, Val Loss: 0.0929, Val Acc: 18.75%
# Epoch [15/50], Train Loss: 0.5221, Train Acc: 16.67%, Val Loss: 0.0929, Val Acc: 20.83%
# Epoch [16/50], Train Loss: 0.4880, Train Acc: 14.29%, Val Loss: 0.0937, Val Acc: 12.50%
# Epoch [17/50], Train Loss: 0.4554, Train Acc: 19.05%, Val Loss: 0.0934, Val Acc: 19.05%
# Epoch [18/50], Train Loss: 0.4255, Train Acc: 12.50%, Val Loss: 0.0939, Val Acc: 12.50%
# Epoch [19/50], Train Loss: 0.3974, Train Acc: 20.00%, Val Loss: 0.0949, Val Acc: 12.50%
# Epoch [20/50], Train Loss: 0.3710, Train Acc: 14.29%, Val Loss: 0.0944, Val Acc: 11.11%
# Epoch [21/50], Train Loss: 0.3467, Train Acc: 14.29%, Val Loss: 0.0947, Val Acc: 12.50%
# Epoch [22/50], Train Loss: 0.3238, Train Acc: 14.29%, Val Loss: 0.0951, Val Acc: 12.50%
# Epoch [23/50], Train Loss: 0.3026, Train Acc: 16.67%, Val Loss: 0.0950, Val Acc: 11.11%
# Epoch [24/50], Train Loss: 0.2830, Train Acc: 16.67%, Val Loss: 0.0949, Val Acc: 12.50%
# Epoch [25/50], Train Loss: 0.2647, Train Acc: 20.00%, Val Loss: 0.0950, Val Acc: 12.50%
# Epoch [26/50], Train Loss: 0.2480, Train Acc: 16.67%, Val Loss: 0.0951, Val Acc: 12.50%
# Epoch [27/50], Train Loss: 0.2327, Train Acc: 14.29%, Val Loss: 0.0951, Val Acc: 12.50%
# Epoch [28/50], Train Loss: 0.2183, Train Acc: 12.50%, Val Loss: 0.0951, Val Acc: 12.50%
# Epoch [29/50], Train Loss: 0.2053, Train Acc: 14.29%, Val Loss: 0.0951, Val Acc: 14.29%
# Epoch [30/50], Train Loss: 0.1933, Train Acc: 14.29%, Val Loss: 0.0951, Val Acc: 12.50%
# Epoch [31/50], Train Loss: 0.1824, Train Acc: 12.50%, Val Loss: 0.0952, Val Acc: 11.11%
# Epoch [32/50], Train Loss: 0.1724, Train Acc: 14.29%, Val Loss: 0.0952, Val Acc: 14.29%
# Epoch [33/50], Train Loss: 0.1633, Train Acc: 16.67%, Val Loss: 0.0952, Val Acc: 11.11%
# Epoch [34/50], Train Loss: 0.1551, Train Acc: 16.67%, Val Loss: 0.0952, Val Acc: 14.29%
# Epoch [35/50], Train Loss: 0.1478, Train Acc: 14.29%, Val Loss: 0.0952, Val Acc: 12.50%
# Epoch [36/50], Train Loss: 0.1412, Train Acc: 14.29%, Val Loss: 0.0952, Val Acc: 12.50%
# Epoch [37/50], Train Loss: 0.1354, Train Acc: 12.50%, Val Loss: 0.0952, Val Acc: 16.67%
# Epoch [38/50], Train Loss: 0.1302, Train Acc: 16.67%, Val Loss: 0.0952, Val Acc: 11.11%
# Epoch [39/50], Train Loss: 0.1256, Train Acc: 12.50%, Val Loss: 0.0952, Val Acc: 12.50%
# Epoch [40/50], Train Loss: 0.1215, Train Acc: 14.29%, Val Loss: 0.0952, Val Acc: 11.11%
# Epoch [41/50], Train Loss: 0.1179, Train Acc: 14.29%, Val Loss: 0.0952, Val Acc: 14.29%
# Epoch [42/50], Train Loss: 0.1148, Train Acc: 16.67%, Val Loss: 0.0953, Val Acc: 12.50%
# Epoch [43/50], Train Loss: 0.1122, Train Acc: 16.67%, Val Loss: 0.0952, Val Acc: 12.50%
# Epoch [44/50], Train Loss: 0.1099, Train Acc: 14.29%, Val Loss: 0.0953, Val Acc: 12.50%
# Epoch [45/50], Train Loss: 0.1080, Train Acc: 14.29%, Val Loss: 0.0952, Val Acc: 11.11%
# Epoch [46/50], Train Loss: 0.1065, Train Acc: 14.29%, Val Loss: 0.0952, Val Acc: 12.50%
# Epoch [47/50], Train Loss: 0.1051, Train Acc: 12.50%, Val Loss: 0.0953, Val Acc: 12.50%
# Epoch [48/50], Train Loss: 0.1040, Train Acc: 11.11%, Val Loss: 0.0953, Val Acc: 12.50%
# Epoch [49/50], Train Loss: 0.1032, Train Acc: 12.50%, Val Loss: 0.0953, Val Acc: 12.50%
# Epoch [50/50], Train Loss: 0.1024, Train Acc: 14.29%, Val Loss: 0.0953, Val Acc: 12.50%
# F1 Score:  0.09426057813154588
# B_acc:  0.1111111111111111
# Best model has index  0
#
# Epoch [1/50], Train Loss: 1.7840, Train Acc: 0.00%, Val Loss: 0.0956, Val Acc: 23.89%
# Epoch [2/50], Train Loss: 1.4214, Train Acc: 25.00%, Val Loss: 0.0954, Val Acc: 30.56%
# Epoch [3/50], Train Loss: 1.2657, Train Acc: 16.67%, Val Loss: 0.0930, Val Acc: 32.59%
# Epoch [4/50], Train Loss: 1.1543, Train Acc: 34.52%, Val Loss: 0.0931, Val Acc: 26.67%
# Epoch [5/50], Train Loss: 1.0623, Train Acc: 26.67%, Val Loss: 0.0944, Val Acc: 35.42%
# Epoch [6/50], Train Loss: 0.9833, Train Acc: 41.67%, Val Loss: 0.0939, Val Acc: 29.63%
# Epoch [7/50], Train Loss: 0.9133, Train Acc: 40.62%, Val Loss: 0.0939, Val Acc: 18.52%
# Epoch [8/50], Train Loss: 0.8500, Train Acc: 36.67%, Val Loss: 0.0953, Val Acc: 19.26%
# Epoch [9/50], Train Loss: 0.7928, Train Acc: 25.00%, Val Loss: 0.0948, Val Acc: 22.29%
# Epoch [10/50], Train Loss: 0.7395, Train Acc: 32.00%, Val Loss: 0.0958, Val Acc: 22.50%
# Epoch [11/50], Train Loss: 0.6908, Train Acc: 25.00%, Val Loss: 0.0955, Val Acc: 19.52%
# Epoch [12/50], Train Loss: 0.6455, Train Acc: 18.75%, Val Loss: 0.0959, Val Acc: 21.48%
# Epoch [13/50], Train Loss: 0.6027, Train Acc: 19.44%, Val Loss: 0.0959, Val Acc: 25.45%
# Epoch [14/50], Train Loss: 0.5636, Train Acc: 34.29%, Val Loss: 0.0963, Val Acc: 14.58%
# Epoch [15/50], Train Loss: 0.5266, Train Acc: 12.50%, Val Loss: 0.0969, Val Acc: 13.89%
# Epoch [16/50], Train Loss: 0.4927, Train Acc: 12.50%, Val Loss: 0.0969, Val Acc: 15.56%
# Epoch [17/50], Train Loss: 0.4602, Train Acc: 12.50%, Val Loss: 0.0973, Val Acc: 11.11%
# Epoch [18/50], Train Loss: 0.4298, Train Acc: 14.29%, Val Loss: 0.0973, Val Acc: 12.50%
# Epoch [19/50], Train Loss: 0.4018, Train Acc: 16.67%, Val Loss: 0.0981, Val Acc: 11.11%
# Epoch [20/50], Train Loss: 0.3753, Train Acc: 16.67%, Val Loss: 0.0978, Val Acc: 11.11%
# Epoch [21/50], Train Loss: 0.3508, Train Acc: 12.50%, Val Loss: 0.0988, Val Acc: 17.08%
# Epoch [22/50], Train Loss: 0.3281, Train Acc: 14.29%, Val Loss: 0.0979, Val Acc: 11.11%
# Epoch [23/50], Train Loss: 0.3066, Train Acc: 20.00%, Val Loss: 0.0979, Val Acc: 11.11%
# Epoch [24/50], Train Loss: 0.2869, Train Acc: 12.50%, Val Loss: 0.0981, Val Acc: 12.50%
# Epoch [25/50], Train Loss: 0.2686, Train Acc: 11.11%, Val Loss: 0.0982, Val Acc: 11.11%
# Epoch [26/50], Train Loss: 0.2516, Train Acc: 12.50%, Val Loss: 0.0982, Val Acc: 12.50%
# Epoch [27/50], Train Loss: 0.2358, Train Acc: 14.29%, Val Loss: 0.0982, Val Acc: 11.11%
# Epoch [28/50], Train Loss: 0.2213, Train Acc: 20.00%, Val Loss: 0.0983, Val Acc: 11.11%
# Epoch [29/50], Train Loss: 0.2082, Train Acc: 14.29%, Val Loss: 0.0982, Val Acc: 12.50%
# Epoch [30/50], Train Loss: 0.1961, Train Acc: 16.67%, Val Loss: 0.0983, Val Acc: 12.50%
# Epoch [31/50], Train Loss: 0.1851, Train Acc: 14.29%, Val Loss: 0.0982, Val Acc: 12.50%
# Epoch [32/50], Train Loss: 0.1750, Train Acc: 16.67%, Val Loss: 0.0982, Val Acc: 12.50%
# Epoch [33/50], Train Loss: 0.1659, Train Acc: 12.50%, Val Loss: 0.0982, Val Acc: 12.50%
# Epoch [34/50], Train Loss: 0.1575, Train Acc: 16.67%, Val Loss: 0.0983, Val Acc: 12.50%
# Epoch [35/50], Train Loss: 0.1501, Train Acc: 12.50%, Val Loss: 0.0982, Val Acc: 12.50%
# Epoch [36/50], Train Loss: 0.1433, Train Acc: 16.67%, Val Loss: 0.0983, Val Acc: 11.11%
# Epoch [37/50], Train Loss: 0.1374, Train Acc: 16.67%, Val Loss: 0.0982, Val Acc: 12.50%
# Epoch [38/50], Train Loss: 0.1322, Train Acc: 14.29%, Val Loss: 0.0982, Val Acc: 14.29%
# Epoch [39/50], Train Loss: 0.1275, Train Acc: 16.67%, Val Loss: 0.0982, Val Acc: 11.11%
# Epoch [40/50], Train Loss: 0.1234, Train Acc: 14.29%, Val Loss: 0.0982, Val Acc: 11.11%
# Epoch [41/50], Train Loss: 0.1198, Train Acc: 16.67%, Val Loss: 0.0982, Val Acc: 11.11%
# Epoch [42/50], Train Loss: 0.1167, Train Acc: 12.50%, Val Loss: 0.0982, Val Acc: 12.50%
# Epoch [43/50], Train Loss: 0.1138, Train Acc: 14.29%, Val Loss: 0.0983, Val Acc: 12.50%
# Epoch [44/50], Train Loss: 0.1116, Train Acc: 16.67%, Val Loss: 0.0982, Val Acc: 12.50%
# Epoch [45/50], Train Loss: 0.1096, Train Acc: 14.29%, Val Loss: 0.0983, Val Acc: 11.11%
# Epoch [46/50], Train Loss: 0.1080, Train Acc: 14.29%, Val Loss: 0.0983, Val Acc: 12.50%
# Epoch [47/50], Train Loss: 0.1067, Train Acc: 16.67%, Val Loss: 0.0982, Val Acc: 12.50%
# Epoch [48/50], Train Loss: 0.1056, Train Acc: 12.50%, Val Loss: 0.0983, Val Acc: 12.50%
# Epoch [49/50], Train Loss: 0.1044, Train Acc: 16.67%, Val Loss: 0.0983, Val Acc: 11.11%
# Epoch [50/50], Train Loss: 0.1038, Train Acc: 14.29%, Val Loss: 0.0982, Val Acc: 11.11%
# F1 Score:  0.02949308755760369
# B_acc:  0.1111111111111111
# Best model has index  0
#
# Epoch [1/50], Train Loss: 1.7740, Train Acc: 40.00%, Val Loss: 0.0937, Val Acc: 19.58%
# Epoch [2/50], Train Loss: 1.4116, Train Acc: 33.33%, Val Loss: 0.0921, Val Acc: 35.52%
# Epoch [3/50], Train Loss: 1.2571, Train Acc: 37.50%, Val Loss: 0.0933, Val Acc: 22.06%
# Epoch [4/50], Train Loss: 1.1460, Train Acc: 53.57%, Val Loss: 0.0926, Val Acc: 27.08%
# Epoch [5/50], Train Loss: 1.0546, Train Acc: 47.92%, Val Loss: 0.0941, Val Acc: 23.33%
# Epoch [6/50], Train Loss: 0.9760, Train Acc: 16.67%, Val Loss: 0.0953, Val Acc: 17.50%
# Epoch [7/50], Train Loss: 0.9065, Train Acc: 20.00%, Val Loss: 0.0929, Val Acc: 25.00%
# Epoch [8/50], Train Loss: 0.8437, Train Acc: 25.00%, Val Loss: 0.0943, Val Acc: 18.33%
# Epoch [9/50], Train Loss: 0.7859, Train Acc: 28.57%, Val Loss: 0.0940, Val Acc: 16.67%
# Epoch [10/50], Train Loss: 0.7332, Train Acc: 6.12%, Val Loss: 0.0946, Val Acc: 23.21%
# Epoch [11/50], Train Loss: 0.6846, Train Acc: 14.29%, Val Loss: 0.0958, Val Acc: 16.07%
# Epoch [12/50], Train Loss: 0.6390, Train Acc: 28.33%, Val Loss: 0.0951, Val Acc: 20.37%
# Epoch [13/50], Train Loss: 0.5975, Train Acc: 12.50%, Val Loss: 0.0962, Val Acc: 18.52%
# Epoch [14/50], Train Loss: 0.5582, Train Acc: 24.00%, Val Loss: 0.0958, Val Acc: 11.11%
# Epoch [15/50], Train Loss: 0.5212, Train Acc: 16.67%, Val Loss: 0.0958, Val Acc: 16.67%
# Epoch [16/50], Train Loss: 0.4871, Train Acc: 12.50%, Val Loss: 0.0966, Val Acc: 11.11%
# Epoch [17/50], Train Loss: 0.4549, Train Acc: 12.50%, Val Loss: 0.0965, Val Acc: 11.11%
# Epoch [18/50], Train Loss: 0.4250, Train Acc: 14.29%, Val Loss: 0.0969, Val Acc: 11.11%
# Epoch [19/50], Train Loss: 0.3969, Train Acc: 16.67%, Val Loss: 0.0972, Val Acc: 11.11%
# Epoch [20/50], Train Loss: 0.3708, Train Acc: 12.50%, Val Loss: 0.0974, Val Acc: 12.50%
# Epoch [21/50], Train Loss: 0.3464, Train Acc: 14.29%, Val Loss: 0.0972, Val Acc: 11.11%
# Epoch [22/50], Train Loss: 0.3237, Train Acc: 14.29%, Val Loss: 0.0973, Val Acc: 12.50%
# Epoch [23/50], Train Loss: 0.3026, Train Acc: 12.50%, Val Loss: 0.0975, Val Acc: 11.11%
# Epoch [24/50], Train Loss: 0.2830, Train Acc: 12.50%, Val Loss: 0.0975, Val Acc: 11.11%
# Epoch [25/50], Train Loss: 0.2648, Train Acc: 20.00%, Val Loss: 0.0974, Val Acc: 12.50%
# Epoch [26/50], Train Loss: 0.2481, Train Acc: 16.67%, Val Loss: 0.0975, Val Acc: 11.11%
# Epoch [27/50], Train Loss: 0.2326, Train Acc: 14.29%, Val Loss: 0.0975, Val Acc: 11.11%
# Epoch [28/50], Train Loss: 0.2184, Train Acc: 14.29%, Val Loss: 0.0975, Val Acc: 11.11%
# Epoch [29/50], Train Loss: 0.2053, Train Acc: 14.29%, Val Loss: 0.0975, Val Acc: 11.11%
# Epoch [30/50], Train Loss: 0.1934, Train Acc: 12.50%, Val Loss: 0.0975, Val Acc: 11.11%
# Epoch [31/50], Train Loss: 0.1824, Train Acc: 16.67%, Val Loss: 0.0974, Val Acc: 14.29%
# Epoch [32/50], Train Loss: 0.1723, Train Acc: 16.67%, Val Loss: 0.0974, Val Acc: 11.11%
# Epoch [33/50], Train Loss: 0.1634, Train Acc: 16.67%, Val Loss: 0.0975, Val Acc: 11.11%
# Epoch [34/50], Train Loss: 0.1551, Train Acc: 14.29%, Val Loss: 0.0975, Val Acc: 11.11%
# Epoch [35/50], Train Loss: 0.1479, Train Acc: 14.29%, Val Loss: 0.0975, Val Acc: 12.50%
# Epoch [36/50], Train Loss: 0.1412, Train Acc: 16.67%, Val Loss: 0.0975, Val Acc: 11.11%
# Epoch [37/50], Train Loss: 0.1354, Train Acc: 14.29%, Val Loss: 0.0975, Val Acc: 11.11%
# Epoch [38/50], Train Loss: 0.1301, Train Acc: 14.29%, Val Loss: 0.0975, Val Acc: 11.11%
# Epoch [39/50], Train Loss: 0.1257, Train Acc: 12.50%, Val Loss: 0.0975, Val Acc: 11.11%
# Epoch [40/50], Train Loss: 0.1215, Train Acc: 14.29%, Val Loss: 0.0975, Val Acc: 11.11%
# Epoch [41/50], Train Loss: 0.1181, Train Acc: 12.50%, Val Loss: 0.0974, Val Acc: 12.50%
# Epoch [42/50], Train Loss: 0.1148, Train Acc: 16.67%, Val Loss: 0.0975, Val Acc: 11.11%
# Epoch [43/50], Train Loss: 0.1122, Train Acc: 16.67%, Val Loss: 0.0975, Val Acc: 11.11%
# Epoch [44/50], Train Loss: 0.1100, Train Acc: 14.29%, Val Loss: 0.0975, Val Acc: 11.11%
# Epoch [45/50], Train Loss: 0.1081, Train Acc: 20.00%, Val Loss: 0.0975, Val Acc: 11.11%
# Epoch [46/50], Train Loss: 0.1064, Train Acc: 16.67%, Val Loss: 0.0975, Val Acc: 11.11%
# Epoch [47/50], Train Loss: 0.1052, Train Acc: 12.50%, Val Loss: 0.0976, Val Acc: 11.11%
# Epoch [48/50], Train Loss: 0.1041, Train Acc: 11.11%, Val Loss: 0.0975, Val Acc: 11.11%
# Epoch [49/50], Train Loss: 0.1032, Train Acc: 16.67%, Val Loss: 0.0975, Val Acc: 12.50%
# Epoch [50/50], Train Loss: 0.1023, Train Acc: 14.29%, Val Loss: 0.0975, Val Acc: 12.50%
# F1 Score:  0.04480286738351254
# B_acc:  0.1111111111111111
# Best model has index  0

# %% [markdown]
# #Training

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)

#Initialize model, loss function, and optimizer
input_size = IMG_WIDTH * IMG_HEIGHT * 3 #RGB
#n of classes
output_size = 9

batchSizes = [32, 64]
hiddens = [64, 128]
folds = [10]
lrs = [0.001, 0.0001]
l2s = [0.01, 0.001] #l2 regulrization
time = [50, 100]
#save_dir = '/content/drive/MyDrive/Nicoli'
save_dir = '/home/stefanotrenti/AML/project/MLP/'
#save_dir = 'MLP/'

for b in range(len(batchSizes)):
  batch_size = batchSizes[b]
  for f in range(len(folds)):
    fold = folds[f]
    for h in range(len(hiddens)):
      hidden_size = hiddens[h]
      for l in range(len(lrs)):
        lr = lrs[l]
        for li in range(len(l2s)):
          l2 = l2s[li]
          for e in range(len(time)):
            epochs = time[e]
            best_model_v1, _ = Train_K_FOLDS(MLP_v1, epochs, lr, fold, batch_size, l2, input_size, hidden_size, output_size)
            filename_v1 = best_model_v1.get_architecture_name() + '.txt'
            saveResults(best_model_v1, save_dir, filename_v1, modelName)
            best_model_v2, _ = Train_K_FOLDS(MLP_v2, epochs, lr, fold, batch_size, l2, input_size, hidden_size, output_size)
            filename_v2 = best_model_v2.get_architecture_name() + '.txt'
            saveResults(best_model_v2, save_dir, filename_v2, modelName)
            best_model_v3, _ = Train_K_FOLDS(MLP_v3, epochs, lr, fold, batch_size, l2, input_size, hidden_size, output_size)
            filename_v3 = best_model_v3.get_architecture_name() + '.txt'
            saveResults(best_model_v3, save_dir, filename_v3, modelName)
            best_model_v4, _ = Train_K_FOLDS(MLP_v4, epochs, lr, fold, batch_size, l2, input_size, hidden_size, output_size)
            modelName = "_"+str(batch_size)+"_"+str(fold)+"_"+str(lr)+"_"+str(epochs)+"_"+str(hidden_size)+"_"+str(l2)
            filename_v4 = best_model_v4.get_architecture_name() + '.txt'
            saveResults(best_model_v4, save_dir, filename_v4, modelName)
"""
best_model, _ = Train_K_FOLDS(MLP_v1, epochs, lr, fold, batch_size, l2, input_size, hidden_size, output_size)
best_model, _ = Train_K_FOLDS(MLP_v2, epochs, lr, fold, batch_size, l2, input_size, hidden_size, output_size)
best_model, _ = Train_K_FOLDS(MLP_v3, epochs, lr, fold, batch_size, l2, input_size, hidden_size, output_size)
best_model, _ = Train_K_FOLDS(MLP_v4, epochs, lr, fold, batch_size, l2, input_size, hidden_size, output_size)
"""
