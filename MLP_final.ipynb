# %% [markdown]
# # INITIALIZATION

# %%
import matplotlib.pyplot as plt
#%matplotlib inline
from PIL import Image 
import os
from skimage.io import  imread, imshow 
import torch
from torchvision import datasets, transforms
from torch.utils.data import Dataset, DataLoader, Subset
from sklearn.metrics import confusion_matrix, balanced_accuracy_score,  mean_squared_error, r2_score, f1_score
from sklearn.model_selection import KFold, train_test_split
import numpy as np

#import torch
import torch.nn as nn
import torch.optim as optim
from torch.functional import F
from torch.nn import Dropout

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # DATA LOADING PIPELINE

# %%
# Check if the code is running on Google Colab
try:
    import google.colab
    IN_COLAB = True
except ImportError:
    IN_COLAB = False

if IN_COLAB:
    # Mount Google Drive
    from google.colab import drive
    drive.mount('/content/drive')

    train_dataset_path = '/content/drive/MyDrive/Nicoli/data-students/TRAIN'
    test_dataset_path = '/content/drive/MyDrive/Nicoli/data-students/TEST'
else:
    # Load data from local file
    train_dataset_path = 'data-students/TRAIN'
    test_dataset_path = 'data-students/TEST'

# Now you can use file_path to load your data
#print("File path:", file_path)

#FIXED VARIABLES
IMG_WIDTH = 75
IMG_HEIGHT = 75
BATCH_SIZE = 32

#testing variables
seed = 42

# %%
#!pip install rembg #needed for colab notebook
from rembg import remove
import io

def remove_background_pil(image):
    # Convert PIL image to bytes
    with io.BytesIO() as output_buffer:
        image.save(output_buffer, format='PNG')
        image_bytes = output_buffer.getvalue()

    # Use rembg to remove the background
    result = remove(image_bytes)

    # Convert the result binary data back to a PIL image
    result_image = Image.open(io.BytesIO(result))

    # Fill transparent pixels with black
    result_image = fill_transparent_pixels_with_black(result_image)

    # Convert the image to RGB mode if it's not already
    if result_image.mode != 'RGB':
        result_image = result_image.convert('RGB')

    return result_image

def fill_transparent_pixels_with_black(image):
    # Convert image to RGBA mode if it's not already
    if image.mode != 'RGBA':
        image = image.convert('RGBA')

    # Get the image data as a pixel access object
    pixel_data = image.load()

    # Iterate over each pixel
    width, height = image.size
    for x in range(width):
        for y in range(height):
            # Check if the pixel is transparent
            if pixel_data[x, y][3] == 0:
                # Set the pixel color to black (RGB: 0, 0, 0, Alpha: 255)
                pixel_data[x, y] = (0, 0, 0, 255)

    return image

# %%
from torchvision.transforms import v2

# Define your custom transformation function
augmentation = transforms.Compose([v2.RandomAffine(degrees=(-20, 20), translate=(0.1, 0.2), scale=(0.5, 0.9))])

def removeBackground(image):
    # Apply your custom background removal function
    processed_image = remove_background_pil(image) # remove_background(removal_model, image)

    # Apply other transformations if needed
    transform = transforms.Compose([
        transforms.Resize((IMG_WIDTH, IMG_HEIGHT)),
        #transforms.ToTensor(),
        #transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
    ])

    return transform(processed_image)

def Augment(image):
    # Apply your custom background removal function
    transform = transforms.Compose([
        augmentation,
        transforms.Resize((IMG_WIDTH, IMG_HEIGHT)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
    ])

    return transform(image)

def input_transform(image):
    # Apply your custom background removal function
    transform = transforms.Compose([
        transforms.Resize((IMG_WIDTH, IMG_HEIGHT)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
    ])

    return transform(image)

def input_transform_noBG(image):
    # Apply your custom background removal function
    transform = transforms.Compose([
        transforms.Resize((IMG_WIDTH, IMG_HEIGHT)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
    ])

    return transform(image)

normal_transform = transforms.Compose([
        transforms.Resize((IMG_WIDTH, IMG_HEIGHT)),
        transforms.ToTensor(),
        #transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ])

# %%
#SAVE THE PREPROCESSED IMAGES IN A FOLDER
torch.cuda.is_available()
True
from torchvision.transforms import v2
import shutil
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

#background_removed_path = '/content/drive/MyDrive/Nicoli/data-students/TRAIN-NOBG'

background_removed_path = 'data-students/TRAIN-NOBG'


'''
#only run to generate the folder with images with no background

#------------------------------ONLY RUN ONCE--------------------------------------
 
# Assuming you already have your original dataset and transformed dataset
original_dataset = datasets.ImageFolder(root=train_dataset_path, transform=normal_transform)

# Create a DataLoader
dataloader = DataLoader(original_dataset, batch_size=None, shuffle=False)

transform_to_tensor = transforms.ToTensor()

# Iterate through the DataLoader
for image_path, target in original_dataset.imgs:
    class_name = original_dataset.classes[target]
    class_path = os.path.join(background_removed_path, class_name)
    os.makedirs(class_path, exist_ok=True)

    # Load the image
    image = Image.open(image_path)

    # Apply the transformation
    
    transformed_image = transform_to_tensor(removeBackground(image))

    # Save the transformed image in the corresponding class folder
    image_filename = os.path.basename(image_path)
    image_save_path = os.path.join(class_path, image_filename)
    transformed_image_pil = transforms.ToPILImage()(transformed_image)
    transformed_image_pil.save(image_save_path)  # Save the transformed image

'''
# Out:
# '\n#only run to generate the folder with images with no background\n#------------------------------ONLY RUN ONCE--------------------------------------\n \n# Assuming you already have your original dataset and transformed dataset\noriginal_dataset = datasets.ImageFolder(root=train_dataset_path, transform=normal_transform)\n\n# Create a DataLoader\ndataloader = DataLoader(original_dataset, batch_size=None, shuffle=False)\n\ntransform_to_tensor = transforms.ToTensor()\n\n# Iterate through the DataLoader\nfor image_path, target in original_dataset.imgs:\n    class_name = original_dataset.classes[target]\n    class_path = os.path.join(background_removed_path, class_name)\n    os.makedirs(class_path, exist_ok=True)\n\n    # Load the image\n    image = Image.open(image_path)\n\n    # Apply the transformation\n    \n    transformed_image = transform_to_tensor(removeBackground(image))\n\n    # Save the transformed image in the corresponding class folder\n    image_filename = os.path.basename(image_path)\n    image_save_path = os.path.join(class_path, image_filename)\n    transformed_image_pil = transforms.ToPILImage()(transformed_image)\n    transformed_image_pil.save(image_save_path)  # Save the transformed image\n\n'

# %%
from torch.utils.data import ConcatDataset
nobg_dataset = datasets.ImageFolder(root=background_removed_path, transform=normal_transform)


# Define how many times you want to enlarge the dataset
enlarge_factor = 1

# Create a list to hold the datasets
combined_datasets = [nobg_dataset]

# Add the transformed dataset to the list multiple times
for _ in range(enlarge_factor):
    transformed_dataset = datasets.ImageFolder(root=background_removed_path, transform=Augment)
    combined_datasets.append(transformed_dataset)

# Concatenate the datasets into a single dataset
enlarged_dataset = ConcatDataset(combined_datasets)


test_set_size = 0.4
#get train & test for K-MEANS
train_val_dataset, test_dataset = train_test_split(enlarged_dataset, test_size = test_set_size, random_state=seed) #random_state = randomizer seed
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False)

# %%
#to print the label (AUXILIAR)
label_str = [
    "12 - Don't Go Left or Right",
    "13 - Don't Go Right",
    "24 - Go Right",
    "37 - Children crossing",
    "38 - Dangerous curve to the right",
    "39 - Dangerous curve to the left",
    "44 - Go left or straight",
    "50 - Fences",
    "6 - Speed limit (70km/h)"
]
label_str_id = [
    "12",
    "13",
    "24",
    "37",
    "38",
    "39",
    "44",
    "50",
    "6"
]

# %% [markdown]
# # AUXILIAY FUNCTIONS

# %%
def createCSV(model, test_dataset_loader,type, name, directory):
    import csv

    data = []

    #directory where you want to save the CSV file
    try:
        import google.colab
        IN_COLAB = True
    except ImportError:
        IN_COLAB = False

    if IN_COLAB:
        save_dir = '/content/drive/MyDrive/'
    else:
        save_dir = directory


    #file name
    csv_file = os.path.join(save_dir, name)

    if type == "voting":
      most_voted_classes = voting(model, test_dataset_loader,1)
      for i in range(len(most_voted_classes)):
        predicted_class = int(most_voted_classes[i])  # Extract the integer value
        data.append({"ID": i+1, "Class": label_str_id[predicted_class]}) #, "Name": label_str[test_predictions]})

    else:
      for i, images in enumerate(test_dataset_loader):

          images = images.to(device)
          # Forward pass
          outputs = model(images)
          test_predictions = torch.argmax(outputs, dim=1)

          images = images.cpu().numpy()
          predicted_classes = test_predictions.cpu().numpy()

          # Iterate over the batch
          predicted_class = int(predicted_classes[0])  # Extract the integer value
          data.append({"ID": i+1, "Class": label_str_id[predicted_class]}) #, "Name": label_str[test_predictions]})


    # Define the field names
    fields = ["ID", "Class"]#, "Name"]

    # Write data to CSV file
    with open(csv_file, mode='w', newline='') as file:
        writer = csv.DictWriter(file, fieldnames=fields)

        # Write the header
        writer.writeheader()

        # Write the data rows
        for row in data:
            writer.writerow(row)

    print("CSV file created successfully.")
    return

# %%
def evaluate_network(model,dataset_loader, to_device=True):
    # X given input data
    # y corresponding target labels
    full_dataset = []
    for batch in dataset_loader:
        # Assuming each batch is a tuple (inputs, labels)
        inputs, labels = batch
        full_dataset.append((inputs, labels))

        # Concatenate all data points into a single tensor
        X = torch.cat([inputs for inputs, _ in full_dataset], dim=0)
        y = torch.cat([labels for _, labels in full_dataset], dim=0)


    # Set the model to evaluation mode
    model.eval()
    if to_device:
      # Assuming you're using GPU (if available)
        #device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        X = X.to(device)
        y = y.to(device)
        #model = model.to(device)

    # Run the model on the test data
    with torch.no_grad():
        outputs = model(X)
        _, predicted = torch.max(outputs.data, 1)

    # Convert tensors to numpy arrays
    if to_device:
        predicted = predicted.to("cpu")

    predicted_np = predicted.cpu().numpy()
    test_target_np = y.cpu().numpy()


    # Compute confusion matrix and F1 score
    conf_mat = confusion_matrix(test_target_np, predicted_np)
    f1 = f1_score(test_target_np, predicted_np, average='weighted')
    bal_acc = balanced_accuracy_score(y.cpu(), predicted_np)

    #print('Confusion Matrix:\n', conf_mat)
    print('F1 Score: ', f1)
    print('B_acc: ', bal_acc)

    return conf_mat, f1, bal_acc

# %%
import os,sys

def saveResults(model, directory, name, modelName, optim, loss):
    # Create the directory if it doesn't exist
    os.makedirs(directory, exist_ok=True)
    
    # Join the directory path with the file name
    results_path = os.path.join(directory, name)
    
    # Check if the file exists
    file_exists = os.path.isfile(results_path)
    
    # Open the file in append mode or write mode depending on whether the file exists
    with open(results_path, 'a' if file_exists else 'w') as f:
        # Redirect stdout to the file
        sys.stdout = f
        print(" ---------------------------------------------------------------------------------------------------------------------- ")
        print(" ----------------------------- Model parameters ------------------------------")
        print("model name:" + modelName)
        print('learning rate  = 0.001')
        print('epochs = 50')
        print('folds = 5')
        print('batch size = 64')
        print('Test set size  = ',test_set_size)
        print("enlarge_factor =", enlarge_factor)
        print('loss = '+ loss)
        print('optimizer = '+ optim)
        print(" ------------------------------- Evaluation  ---------------------------------")
        evaluate_network(model, test_loader)
        print(" ---------------------------------------------------------------------------------------------------------------------- ")
 
    # Reset stdout to its default value (console)
    sys.stdout = sys.__stdout__

# %%
def fit(train_loader, val_loader, model, criterion, optimizer, n_epochs, l2 ,to_device=True):
    #Train the network
    loss_values = []
    balanced_accuracy_values = []
    l2_lambda=l2
    for epoch in range(n_epochs):

        model.train()
        running_loss = 0.0

        for X, y in train_loader:
            # Move data to GPU
            X, y = X.to(device), y.to(device)

            #Forward pass
            y_pred = model(X)

            #if criterion -> MSELoss
            #y_one_hot = F.one_hot(y, num_classes=9).float()
            if isinstance(criterion, nn.MSELoss):
                y_one_hot = F.one_hot(y, num_classes=9).float()
                loss = criterion(y_pred, y_one_hot)
            else:
                loss = criterion(y_pred, y)


            # L2 regularization
            l2_reg = 0
            for param in model.parameters():
                l2_reg += torch.norm(param)**2

            loss += l2_lambda * l2_reg

            running_loss += loss.item()

            #Backward pass and optimization
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

        train_loss = running_loss / len(train_loader)
        train_acc = balanced_accuracy_score(y.tolist(),y_pred.argmax(dim=1).tolist())

        #Validation
        model.eval()
        val_loss = 0.0

        with torch.no_grad():
          for X, y in val_loader:
            X, y = X.to(device), y.to(device)

            y_pred = model(X)
            if isinstance(criterion, nn.MSELoss):
                y_one_hot = F.one_hot(y, num_classes=9).float()
                loss = criterion(y_pred, y_one_hot)
            else:
                loss = criterion(y_pred, y)
            val_loss += loss.item()

        val_loss = val_loss/len(val_loader)
        val_acc = balanced_accuracy_score(y.tolist(),y_pred.argmax(dim=1).tolist())

        print(f'Epoch [{epoch + 1}/{n_epochs}], '
              f'Train Loss: {train_loss:.4f}, Train Acc: {train_acc*100:.2f}%, '
              f'Val Loss: {val_loss:.4f}, Val Acc: {val_acc*100:.2f}%')

    return train_loss, balanced_accuracy_values, model

# %%
def Train_K_FOLDS(k_model, epochs, lr, folds, batch_size, l2, input_size, hidden_size, output_size, optim_type, loss_type):

    kf = KFold(n_splits=folds, shuffle=True, random_state=seed)

    models = []
    index=0
    i = 0
    best_accuracy = 0
    best_model = k_model(input_size, hidden_size, output_size)
    second_best_model = k_model(input_size, hidden_size, output_size)
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    for fold, (train_index, val_index) in enumerate(kf.split(train_val_dataset)):

        model = k_model(input_size, hidden_size, output_size)
        model.to(device)
        second_best_model.to(device)

        #Creating DataLoaders for training and validation
        train_sampler = torch.utils.data.SubsetRandomSampler(train_index)
        val_sampler = torch.utils.data.SubsetRandomSampler(val_index)
        #
        train_loader = DataLoader(train_val_dataset, batch_size=batch_size, sampler=train_sampler)
        val_loader = DataLoader(train_val_dataset, batch_size=batch_size, sampler=val_sampler)

        #CHOOSE LOSS
        if loss_type == 'MSELoss' or loss_type == 'BCELoss':
            criterion = nn.MSELoss()
            
        elif loss_type == 'cross_entropy':
            criterion = nn.CrossEntropyLoss()
        elif loss_type == 'BCELoss':
            criterion = nn.BCELoss()
        else:
            raise ValueError(f"Unsupported loss type: {loss_type}")
            
        #CHOOSE OPTIMIZER
        if optim_type == 'adam':
            optimizer = optim.Adam(model.parameters(), lr=lr)
        elif optim_type == 'SGD':
            optimizer = optim.SGD(model.parameters(), lr=lr)
        elif optim_type == 'RMSprop':
            optimizer = optim.RMSprop(model.parameters(), lr=lr)
        else:
            raise ValueError(f"Unsupported optimizer type: {optim_type}")

        # Train the model
        train_loss, train_acc,  trained_model = fit(train_loader, val_loader, model, criterion, optimizer, epochs, l2, to_device=False)
        #models.append(trained_model)
        conf_matrix, F_score, bal_acc = evaluate_network(trained_model, val_loader)
        if(bal_acc > best_accuracy):
            best_accuracy = bal_acc
            index = i
            if(fold >1):second_best_model = best_model
            best_model = model

        print("Best model has index ", index , "\n")


    models.append(best_model)
    models.append(second_best_model)

    return best_model, models

# %% [markdown]
# # MLP

# %%
class MLP_v4(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super(MLP_v4, self).__init__()
        self.lin1 = nn.Linear(input_size, hidden_size)
        self.relu = nn.ReLU()

        #hidden
        self.lin2 = nn.Linear(hidden_size, hidden_size)

        self.lin3 = nn.Linear(hidden_size, hidden_size)

        self.lin4 = nn.Linear(hidden_size, hidden_size)

        self.lin5 = nn.Linear(hidden_size, hidden_size)

        #hidden
        self.lin6 = nn.Linear(hidden_size, output_size)

    def forward(self, x):
        x = x.view(x.size(0), -1)  # Flatten input tensor
        x = self.lin1(x)
        x = self.relu(x)

        #hidden
        x = self.lin2(x)
        x = self.relu(x)

        x = self.lin3(x)
        x = self.relu(x)

        x = self.lin4(x)
        x = self.relu(x)

        x = self.lin4(x)
        x = self.relu(x)

        #hidden
        x = self.lin6(x)
        return x
    
    def get_architecture_name(self):
        name = 'MLP_v4'
        return name

# %% [markdown]
# # TRAINING

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
#print(device)

#Initialize model, loss function, and optimizer
input_size = IMG_WIDTH * IMG_HEIGHT * 3 #RGB
#n of classes
output_size = 9

#save_dir = '/home/stefanotrenti/AML/project/AOL_test'
#name = 'AOL_function_tests_MLP.txt'

optimizers = ['adam','SGD','RMSprop']
losses = ['cross_entropy','MSELoss','BCELoss']


best_model_v4, _ = Train_K_FOLDS(MLP_v4, 50, 0.0001, 10, 32, 0.01, input_size, 128, output_size, 'adam', 'cross_entropy')
filename_v4 = best_model_v4.get_architecture_name() + '.txt'
#saveResults(best_model_v4,save_dir,name,filename_v4, 'adam', 'cross_entropy')
# Out:
# cuda:0
# Epoch [1/50], Train Loss: 4.2384, Train Acc: 12.50%, Val Loss: 2.1843, Val Acc: 10.00%
# Epoch [2/50], Train Loss: 4.0015, Train Acc: 12.50%, Val Loss: 2.1518, Val Acc: 12.87%
# Epoch [3/50], Train Loss: 3.8019, Train Acc: 4.17%, Val Loss: 2.1162, Val Acc: 10.00%
# Epoch [4/50], Train Loss: 3.6354, Train Acc: 17.78%, Val Loss: 2.0377, Val Acc: 15.43%
# Epoch [5/50], Train Loss: 3.4860, Train Acc: 28.57%, Val Loss: 1.9314, Val Acc: 14.32%
# Epoch [6/50], Train Loss: 3.3246, Train Acc: 40.00%, Val Loss: 1.8145, Val Acc: 17.46%
# Epoch [7/50], Train Loss: 3.1868, Train Acc: 25.00%, Val Loss: 1.7027, Val Acc: 34.26%
# Epoch [8/50], Train Loss: 3.0486, Train Acc: 54.76%, Val Loss: 1.5756, Val Acc: 33.33%
# Epoch [9/50], Train Loss: 2.8919, Train Acc: 41.67%, Val Loss: 1.5115, Val Acc: 37.04%
# Epoch [10/50], Train Loss: 2.7488, Train Acc: 50.00%, Val Loss: 1.3158, Val Acc: 35.71%
# Epoch [46/50], Train Loss: 1.3674, Train Acc: 85.71%, Val Loss: 0.9807, Val Acc: 48.02%
# Epoch [47/50], Train Loss: 1.3289, Train Acc: 83.33%, Val Loss: 0.7469, Val Acc: 57.92%
# Epoch [48/50], Train Loss: 1.3253, Train Acc: 50.00%, Val Loss: 0.9550, Val Acc: 43.70%
# Epoch [49/50], Train Loss: 1.3301, Train Acc: 85.71%, Val Loss: 0.7799, Val Acc: 68.75%
# Epoch [50/50], Train Loss: 1.3115, Train Acc: 85.71%, Val Loss: 1.1161, Val Acc: 49.40%
# F1 Score:  0.6543430751892795
# B_acc:  0.5003928170594837
# Best model has index  0
#
# Epoch [1/50], Train Loss: 4.2436, Train Acc: 0.00%, Val Loss: 2.1763, Val Acc: 9.23%
# Epoch [2/50], Train Loss: 3.9890, Train Acc: 15.28%, Val Loss: 2.1382, Val Acc: 4.76%
# Epoch [3/50], Train Loss: 3.8065, Train Acc: 28.57%, Val Loss: 2.0955, Val Acc: 8.33%
# Epoch [4/50], Train Loss: 3.6549, Train Acc: 19.05%, Val Loss: 2.0448, Val Acc: 15.08%
# Epoch [5/50], Train Loss: 3.5165, Train Acc: 25.00%, Val Loss: 1.9496, Val Acc: 17.56%
# Epoch [6/50], Train Loss: 3.3694, Train Acc: 16.67%, Val Loss: 1.8248, Val Acc: 16.67%
# Epoch [7/50], Train Loss: 3.2257, Train Acc: 23.81%, Val Loss: 1.7599, Val Acc: 23.15%
# Epoch [8/50], Train Loss: 3.1009, Train Acc: 40.00%, Val Loss: 1.6135, Val Acc: 26.67%
# Epoch [9/50], Train Loss: 2.9610, Train Acc: 38.10%, Val Loss: 1.4726, Val Acc: 27.38%
# Epoch [10/50], Train Loss: 2.8265, Train Acc: 29.17%, Val Loss: 1.4606, Val Acc: 36.25%
# Epoch [11/50], Train Loss: 2.7013, Train Acc: 28.57%, Val Loss: 1.2202, Val Acc: 40.18%
# Epoch [12/50], Train Loss: 2.5749, Train Acc: 43.75%, Val Loss: 1.1433, Val Acc: 41.27%
# Epoch [13/50], Train Loss: 2.5454, Train Acc: 29.17%, Val Loss: 1.1223, Val Acc: 44.22%
# Epoch [14/50], Train Loss: 2.4156, Train Acc: 37.50%, Val Loss: 1.0360, Val Acc: 38.10%
# Epoch [15/50], Train Loss: 2.3015, Train Acc: 50.00%, Val Loss: 0.9821, Val Acc: 52.38%
# Epoch [16/50], Train Loss: 2.2674, Train Acc: 50.00%, Val Loss: 0.9624, Val Acc: 58.44%
# Epoch [17/50], Train Loss: 2.2118, Train Acc: 56.25%, Val Loss: 0.9168, Val Acc: 48.15%
# Epoch [18/50], Train Loss: 2.1108, Train Acc: 75.00%, Val Loss: 0.8872, Val Acc: 48.41%
# Epoch [19/50], Train Loss: 2.0908, Train Acc: 38.10%, Val Loss: 1.1800, Val Acc: 41.67%
# Epoch [20/50], Train Loss: 2.0484, Train Acc: 66.67%, Val Loss: 0.8479, Val Acc: 50.62%
# Epoch [21/50], Train Loss: 1.9956, Train Acc: 62.50%, Val Loss: 0.8975, Val Acc: 56.25%
# Epoch [49/50], Train Loss: 1.3640, Train Acc: 71.43%, Val Loss: 0.7539, Val Acc: 66.67%
# Epoch [50/50], Train Loss: 1.4687, Train Acc: 62.50%, Val Loss: 0.8343, Val Acc: 71.35%
# F1 Score:  0.7096886412260983
# B_acc:  0.6054131054131054
# Best model has index  0
#
# Epoch [1/50], Train Loss: 4.2329, Train Acc: 16.67%, Val Loss: 2.1042, Val Acc: 18.96%
# Epoch [2/50], Train Loss: 3.9971, Train Acc: 37.50%, Val Loss: 2.0764, Val Acc: 20.48%
# Epoch [3/50], Train Loss: 3.8090, Train Acc: 23.96%, Val Loss: 2.0698, Val Acc: 24.29%
# Epoch [4/50], Train Loss: 3.6568, Train Acc: 39.29%, Val Loss: 1.9977, Val Acc: 28.87%
# Epoch [5/50], Train Loss: 3.4822, Train Acc: 20.24%, Val Loss: 1.9261, Val Acc: 20.83%
# Epoch [6/50], Train Loss: 3.3723, Train Acc: 17.86%, Val Loss: 1.8264, Val Acc: 18.75%
# Epoch [7/50], Train Loss: 3.2234, Train Acc: 12.50%, Val Loss: 1.7353, Val Acc: 29.17%
# Epoch [8/50], Train Loss: 3.0652, Train Acc: 25.00%, Val Loss: 1.6320, Val Acc: 34.29%
# Epoch [9/50], Train Loss: 2.9598, Train Acc: 37.50%, Val Loss: 1.5627, Val Acc: 37.71%
# Epoch [10/50], Train Loss: 2.8257, Train Acc: 25.00%, Val Loss: 1.4551, Val Acc: 37.35%
# Epoch [11/50], Train Loss: 2.6504, Train Acc: 50.00%, Val Loss: 1.3460, Val Acc: 51.43%
# Epoch [12/50], Train Loss: 2.5448, Train Acc: 75.00%, Val Loss: 1.2802, Val Acc: 41.52%
# Epoch [13/50], Train Loss: 2.4304, Train Acc: 50.00%, Val Loss: 1.2379, Val Acc: 55.83%
# Epoch [14/50], Train Loss: 2.3445, Train Acc: 50.00%, Val Loss: 1.1534, Val Acc: 49.17%
# Epoch [15/50], Train Loss: 2.2919, Train Acc: 61.43%, Val Loss: 1.1141, Val Acc: 55.95%
# Epoch [16/50], Train Loss: 2.2588, Train Acc: 33.33%, Val Loss: 1.1154, Val Acc: 54.69%
# Epoch [17/50], Train Loss: 2.1959, Train Acc: 37.50%, Val Loss: 1.0385, Val Acc: 52.98%
# Epoch [18/50], Train Loss: 2.1047, Train Acc: 59.52%, Val Loss: 1.0465, Val Acc: 51.25%
# Epoch [19/50], Train Loss: 2.0564, Train Acc: 38.33%, Val Loss: 1.0652, Val Acc: 61.31%
# Epoch [20/50], Train Loss: 2.0313, Train Acc: 50.00%, Val Loss: 0.9946, Val Acc: 51.88%
# Epoch [21/50], Train Loss: 1.9422, Train Acc: 71.43%, Val Loss: 0.9609, Val Acc: 52.29%
# Epoch [22/50], Train Loss: 1.9256, Train Acc: 44.44%, Val Loss: 0.9483, Val Acc: 55.49%
# Epoch [23/50], Train Loss: 1.8760, Train Acc: 45.00%, Val Loss: 0.9307, Val Acc: 53.93%
# Epoch [24/50], Train Loss: 1.8754, Train Acc: 46.43%, Val Loss: 0.9246, Val Acc: 56.29%
# Epoch [25/50], Train Loss: 1.8140, Train Acc: 47.22%, Val Loss: 0.9630, Val Acc: 61.90%
# Epoch [26/50], Train Loss: 1.7628, Train Acc: 71.43%, Val Loss: 0.9484, Val Acc: 55.00%
# Epoch [27/50], Train Loss: 1.7323, Train Acc: 54.76%, Val Loss: 0.8959, Val Acc: 52.72%
# Epoch [28/50], Train Loss: 1.6930, Train Acc: 83.33%, Val Loss: 0.9394, Val Acc: 45.00%
# Epoch [29/50], Train Loss: 1.6949, Train Acc: 75.00%, Val Loss: 0.9596, Val Acc: 60.48%
# Epoch [30/50], Train Loss: 1.6765, Train Acc: 59.52%, Val Loss: 1.0232, Val Acc: 56.88%
# Epoch [31/50], Train Loss: 1.6311, Train Acc: 75.00%, Val Loss: 0.9657, Val Acc: 48.84%
# Epoch [32/50], Train Loss: 1.6375, Train Acc: 62.86%, Val Loss: 1.0206, Val Acc: 48.81%
# Epoch [33/50], Train Loss: 1.6653, Train Acc: 57.14%, Val Loss: 0.8576, Val Acc: 55.00%
# Epoch [34/50], Train Loss: 1.5714, Train Acc: 66.67%, Val Loss: 0.8769, Val Acc: 61.43%
# Epoch [35/50], Train Loss: 1.5562, Train Acc: 50.00%, Val Loss: 1.0189, Val Acc: 61.90%
# Epoch [36/50], Train Loss: 1.5348, Train Acc: 50.00%, Val Loss: 1.0339, Val Acc: 53.12%
# Epoch [37/50], Train Loss: 1.6209, Train Acc: 58.33%, Val Loss: 1.0983, Val Acc: 52.92%
# Epoch [38/50], Train Loss: 1.5287, Train Acc: 78.57%, Val Loss: 0.9694, Val Acc: 61.11%
# Epoch [39/50], Train Loss: 1.4669, Train Acc: 100.00%, Val Loss: 0.8870, Val Acc: 60.95%
# Epoch [40/50], Train Loss: 1.4209, Train Acc: 85.71%, Val Loss: 0.8368, Val Acc: 41.46%
# Epoch [41/50], Train Loss: 1.4196, Train Acc: 88.33%, Val Loss: 0.9613, Val Acc: 68.80%
# Epoch [42/50], Train Loss: 1.5451, Train Acc: 50.00%, Val Loss: 0.8360, Val Acc: 54.69%
# Epoch [43/50], Train Loss: 1.4341, Train Acc: 75.00%, Val Loss: 0.9171, Val Acc: 67.92%
# Epoch [44/50], Train Loss: 1.4211, Train Acc: 62.50%, Val Loss: 0.8599, Val Acc: 51.25%
# Epoch [45/50], Train Loss: 1.3512, Train Acc: 70.83%, Val Loss: 0.7832, Val Acc: 60.00%
# Epoch [46/50], Train Loss: 1.3463, Train Acc: 75.00%, Val Loss: 0.8255, Val Acc: 48.75%
# Epoch [47/50], Train Loss: 1.3216, Train Acc: 66.67%, Val Loss: 0.8721, Val Acc: 72.22%
# Epoch [48/50], Train Loss: 1.3144, Train Acc: 80.00%, Val Loss: 0.8534, Val Acc: 75.62%
# Epoch [49/50], Train Loss: 1.4213, Train Acc: 54.76%, Val Loss: 0.8782, Val Acc: 74.85%
# Epoch [50/50], Train Loss: 1.4702, Train Acc: 82.14%, Val Loss: 0.8132, Val Acc: 63.75%
# F1 Score:  0.6814397942440183
# B_acc:  0.5855654761904762
# Best model has index  0
#
# Epoch [1/50], Train Loss: 4.2428, Train Acc: 32.14%, Val Loss: 2.1867, Val Acc: 14.58%
# Epoch [2/50], Train Loss: 3.9858, Train Acc: 16.67%, Val Loss: 2.1888, Val Acc: 10.00%
# Epoch [3/50], Train Loss: 3.8059, Train Acc: 12.50%, Val Loss: 2.1423, Val Acc: 16.67%
# Epoch [4/50], Train Loss: 3.6395, Train Acc: 17.14%, Val Loss: 2.0975, Val Acc: 14.81%
# Epoch [5/50], Train Loss: 3.4924, Train Acc: 12.50%, Val Loss: 2.0410, Val Acc: 12.50%
# Epoch [6/50], Train Loss: 3.3447, Train Acc: 25.71%, Val Loss: 1.9710, Val Acc: 20.00%
# Epoch [7/50], Train Loss: 3.2258, Train Acc: 27.78%, Val Loss: 1.9126, Val Acc: 26.85%
# Epoch [8/50], Train Loss: 3.1255, Train Acc: 12.50%, Val Loss: 1.8553, Val Acc: 19.44%
# Epoch [9/50], Train Loss: 2.9736, Train Acc: 27.78%, Val Loss: 1.7600, Val Acc: 33.33%
# Epoch [10/50], Train Loss: 2.8082, Train Acc: 52.38%, Val Loss: 1.6547, Val Acc: 40.62%
# Epoch [11/50], Train Loss: 2.6535, Train Acc: 50.00%, Val Loss: 1.5448, Val Acc: 41.67%
# Epoch [12/50], Train Loss: 2.5169, Train Acc: 50.00%, Val Loss: 1.5040, Val Acc: 35.80%
# Epoch [13/50], Train Loss: 2.4337, Train Acc: 68.57%, Val Loss: 1.6020, Val Acc: 30.95%
# Epoch [14/50], Train Loss: 2.4186, Train Acc: 21.43%, Val Loss: 1.3654, Val Acc: 45.24%
# Epoch [15/50], Train Loss: 2.3286, Train Acc: 61.11%, Val Loss: 1.3314, Val Acc: 45.83%
# Epoch [16/50], Train Loss: 2.2330, Train Acc: 83.33%, Val Loss: 1.3210, Val Acc: 46.56%
# Epoch [17/50], Train Loss: 2.1713, Train Acc: 64.29%, Val Loss: 1.2578, Val Acc: 49.64%
# Epoch [18/50], Train Loss: 2.1077, Train Acc: 50.00%, Val Loss: 1.2785, Val Acc: 49.60%
# Epoch [19/50], Train Loss: 2.0475, Train Acc: 70.00%, Val Loss: 1.2219, Val Acc: 52.98%
# Epoch [20/50], Train Loss: 1.9865, Train Acc: 59.52%, Val Loss: 1.1607, Val Acc: 48.15%
# Epoch [21/50], Train Loss: 1.9698, Train Acc: 61.11%, Val Loss: 1.1389, Val Acc: 47.94%
# Epoch [22/50], Train Loss: 1.9015, Train Acc: 57.14%, Val Loss: 1.1389, Val Acc: 47.22%
# Epoch [23/50], Train Loss: 1.8795, Train Acc: 60.71%, Val Loss: 1.1220, Val Acc: 50.00%
# Epoch [24/50], Train Loss: 1.8450, Train Acc: 50.00%, Val Loss: 1.1131, Val Acc: 49.07%
# Epoch [25/50], Train Loss: 1.8486, Train Acc: 57.14%, Val Loss: 1.2465, Val Acc: 55.21%
# Epoch [26/50], Train Loss: 1.8354, Train Acc: 61.90%, Val Loss: 1.0683, Val Acc: 53.04%
# Epoch [27/50], Train Loss: 1.7718, Train Acc: 83.33%, Val Loss: 1.2516, Val Acc: 58.33%
# Epoch [28/50], Train Loss: 1.7638, Train Acc: 66.67%, Val Loss: 1.1072, Val Acc: 45.37%
# Epoch [29/50], Train Loss: 1.7414, Train Acc: 70.83%, Val Loss: 1.0648, Val Acc: 58.44%
# Epoch [30/50], Train Loss: 1.6713, Train Acc: 62.50%, Val Loss: 1.1769, Val Acc: 50.00%
# Epoch [31/50], Train Loss: 1.6531, Train Acc: 56.25%, Val Loss: 1.1374, Val Acc: 56.75%
# Epoch [32/50], Train Loss: 1.6467, Train Acc: 66.67%, Val Loss: 1.0092, Val Acc: 66.67%
# Epoch [33/50], Train Loss: 1.6015, Train Acc: 66.67%, Val Loss: 1.1539, Val Acc: 51.76%
# Epoch [34/50], Train Loss: 1.5962, Train Acc: 61.11%, Val Loss: 1.0662, Val Acc: 61.46%
# Epoch [35/50], Train Loss: 1.6066, Train Acc: 100.00%, Val Loss: 0.9988, Val Acc: 47.92%
# Epoch [36/50], Train Loss: 1.5706, Train Acc: 76.00%, Val Loss: 1.0527, Val Acc: 54.50%
# Epoch [37/50], Train Loss: 1.5542, Train Acc: 75.00%, Val Loss: 1.4832, Val Acc: 49.07%
# Epoch [38/50], Train Loss: 1.5933, Train Acc: 57.14%, Val Loss: 1.0929, Val Acc: 61.46%
# Epoch [39/50], Train Loss: 1.5120, Train Acc: 57.14%, Val Loss: 1.1272, Val Acc: 68.90%
# Epoch [40/50], Train Loss: 1.5418, Train Acc: 60.71%, Val Loss: 0.9977, Val Acc: 53.97%
# Epoch [41/50], Train Loss: 1.4755, Train Acc: 85.71%, Val Loss: 1.0381, Val Acc: 51.23%
# Epoch [42/50], Train Loss: 1.4522, Train Acc: 83.33%, Val Loss: 1.0713, Val Acc: 57.96%
# Epoch [43/50], Train Loss: 1.4363, Train Acc: 50.00%, Val Loss: 1.0674, Val Acc: 49.90%
# Epoch [44/50], Train Loss: 1.4461, Train Acc: 85.71%, Val Loss: 0.9952, Val Acc: 63.33%
# Epoch [45/50], Train Loss: 1.4332, Train Acc: 52.38%, Val Loss: 1.0927, Val Acc: 65.28%
# Epoch [46/50], Train Loss: 1.4443, Train Acc: 71.67%, Val Loss: 0.9430, Val Acc: 65.56%
# Epoch [47/50], Train Loss: 1.5467, Train Acc: 71.43%, Val Loss: 1.9122, Val Acc: 51.48%
# Epoch [48/50], Train Loss: 1.5868, Train Acc: 50.00%, Val Loss: 1.3403, Val Acc: 52.22%
# Epoch [49/50], Train Loss: 1.4905, Train Acc: 62.50%, Val Loss: 0.9421, Val Acc: 60.19%
# Epoch [50/50], Train Loss: 1.3876, Train Acc: 62.50%, Val Loss: 0.8844, Val Acc: 62.50%
# F1 Score:  0.6107132694419222
# B_acc:  0.596031746031746
# Best model has index  0
#
# Epoch [1/50], Train Loss: 4.2283, Train Acc: 22.86%, Val Loss: 2.1077, Val Acc: 16.84%
# Epoch [2/50], Train Loss: 3.9937, Train Acc: 22.86%, Val Loss: 2.0616, Val Acc: 29.74%
# Epoch [3/50], Train Loss: 3.8119, Train Acc: 12.86%, Val Loss: 2.0356, Val Acc: 28.12%
# Epoch [4/50], Train Loss: 3.6577, Train Acc: 21.43%, Val Loss: 1.9877, Val Acc: 23.13%
# Epoch [5/50], Train Loss: 3.5183, Train Acc: 27.78%, Val Loss: 1.9000, Val Acc: 26.55%
# Epoch [6/50], Train Loss: 3.3709, Train Acc: 28.33%, Val Loss: 1.8148, Val Acc: 31.43%
# Epoch [7/50], Train Loss: 3.2327, Train Acc: 11.11%, Val Loss: 1.7421, Val Acc: 25.19%
# Epoch [8/50], Train Loss: 3.1086, Train Acc: 28.12%, Val Loss: 1.6399, Val Acc: 32.92%
# Epoch [9/50], Train Loss: 2.9796, Train Acc: 27.08%, Val Loss: 1.5266, Val Acc: 31.35%
# Epoch [10/50], Train Loss: 2.8003, Train Acc: 63.33%, Val Loss: 1.4159, Val Acc: 37.50%
# Epoch [11/50], Train Loss: 2.6492, Train Acc: 43.75%, Val Loss: 1.2723, Val Acc: 47.14%
# Epoch [12/50], Train Loss: 2.5059, Train Acc: 47.50%, Val Loss: 1.1917, Val Acc: 45.71%
# Epoch [13/50], Train Loss: 2.3949, Train Acc: 52.78%, Val Loss: 1.1674, Val Acc: 45.24%
# Epoch [14/50], Train Loss: 2.3803, Train Acc: 70.00%, Val Loss: 1.1014, Val Acc: 55.00%
# Epoch [15/50], Train Loss: 2.2445, Train Acc: 83.33%, Val Loss: 1.0797, Val Acc: 47.92%
# Epoch [16/50], Train Loss: 2.1691, Train Acc: 50.00%, Val Loss: 1.0689, Val Acc: 44.46%
# Epoch [17/50], Train Loss: 2.1500, Train Acc: 40.00%, Val Loss: 0.9995, Val Acc: 50.00%
# Epoch [18/50], Train Loss: 2.0490, Train Acc: 61.11%, Val Loss: 1.2097, Val Acc: 45.58%
# Epoch [19/50], Train Loss: 2.0718, Train Acc: 64.29%, Val Loss: 0.9861, Val Acc: 50.62%
# Epoch [20/50], Train Loss: 1.9792, Train Acc: 78.57%, Val Loss: 0.9704, Val Acc: 38.36%
# Epoch [21/50], Train Loss: 1.9391, Train Acc: 64.29%, Val Loss: 0.9281, Val Acc: 45.00%
# Epoch [22/50], Train Loss: 1.9024, Train Acc: 57.41%, Val Loss: 0.9958, Val Acc: 45.83%
# Epoch [23/50], Train Loss: 1.8607, Train Acc: 81.25%, Val Loss: 0.9946, Val Acc: 36.98%
# Epoch [24/50], Train Loss: 1.8717, Train Acc: 58.33%, Val Loss: 0.9076, Val Acc: 40.74%
# Epoch [25/50], Train Loss: 1.9438, Train Acc: 73.33%, Val Loss: 1.1242, Val Acc: 32.72%
# Epoch [26/50], Train Loss: 1.8231, Train Acc: 52.38%, Val Loss: 1.1453, Val Acc: 58.45%
# Epoch [27/50], Train Loss: 1.7866, Train Acc: 66.67%, Val Loss: 0.9102, Val Acc: 44.38%
# Epoch [28/50], Train Loss: 1.7252, Train Acc: 76.19%, Val Loss: 0.9823, Val Acc: 37.22%
# Epoch [29/50], Train Loss: 1.7082, Train Acc: 66.67%, Val Loss: 0.9416, Val Acc: 49.59%
# Epoch [30/50], Train Loss: 1.6723, Train Acc: 61.90%, Val Loss: 0.9456, Val Acc: 41.67%
# Epoch [31/50], Train Loss: 1.6546, Train Acc: 72.22%, Val Loss: 0.9023, Val Acc: 43.33%
# Epoch [32/50], Train Loss: 1.6189, Train Acc: 66.67%, Val Loss: 0.9658, Val Acc: 47.50%
# Epoch [33/50], Train Loss: 1.6712, Train Acc: 83.33%, Val Loss: 0.9177, Val Acc: 54.05%
# Epoch [34/50], Train Loss: 1.6891, Train Acc: 59.52%, Val Loss: 1.0572, Val Acc: 45.39%
# Epoch [35/50], Train Loss: 1.6010, Train Acc: 80.00%, Val Loss: 1.1139, Val Acc: 54.86%
# Epoch [36/50], Train Loss: 1.6667, Train Acc: 58.33%, Val Loss: 1.0133, Val Acc: 44.97%
# Epoch [37/50], Train Loss: 1.6580, Train Acc: 59.05%, Val Loss: 0.8810, Val Acc: 45.00%
# Epoch [38/50], Train Loss: 1.5388, Train Acc: 62.50%, Val Loss: 0.8784, Val Acc: 55.48%
# Epoch [39/50], Train Loss: 1.5264, Train Acc: 71.43%, Val Loss: 0.9066, Val Acc: 41.48%
# Epoch [40/50], Train Loss: 1.5725, Train Acc: 64.29%, Val Loss: 0.9654, Val Acc: 39.88%
# Epoch [41/50], Train Loss: 1.7028, Train Acc: 67.86%, Val Loss: 0.8537, Val Acc: 60.71%
# Epoch [42/50], Train Loss: 1.5695, Train Acc: 66.67%, Val Loss: 0.8636, Val Acc: 54.17%
# Epoch [43/50], Train Loss: 1.4802, Train Acc: 66.67%, Val Loss: 0.9193, Val Acc: 56.29%
# Epoch [44/50], Train Loss: 1.5039, Train Acc: 64.58%, Val Loss: 1.0744, Val Acc: 51.04%
# Epoch [45/50], Train Loss: 1.4585, Train Acc: 90.00%, Val Loss: 1.0722, Val Acc: 51.87%
# Epoch [46/50], Train Loss: 1.4318, Train Acc: 100.00%, Val Loss: 0.9838, Val Acc: 74.17%
# Epoch [47/50], Train Loss: 1.4219, Train Acc: 66.67%, Val Loss: 0.9838, Val Acc: 38.89%
# Epoch [48/50], Train Loss: 1.4277, Train Acc: 75.00%, Val Loss: 1.0602, Val Acc: 53.75%
# Epoch [49/50], Train Loss: 1.4089, Train Acc: 69.44%, Val Loss: 0.8934, Val Acc: 64.88%
# Epoch [50/50], Train Loss: 1.5257, Train Acc: 71.43%, Val Loss: 0.9153, Val Acc: 68.91%
# F1 Score:  0.6864057242825706
# B_acc:  0.5567290733957401
# Best model has index  0
#
# Epoch [1/50], Train Loss: 4.2484, Train Acc: 18.75%, Val Loss: 2.1720, Val Acc: 16.67%
# Epoch [2/50], Train Loss: 3.9857, Train Acc: 0.00%, Val Loss: 2.1553, Val Acc: 9.38%
# Epoch [3/50], Train Loss: 3.7927, Train Acc: 7.14%, Val Loss: 2.1349, Val Acc: 8.33%
# Epoch [4/50], Train Loss: 3.6329, Train Acc: 10.00%, Val Loss: 2.0802, Val Acc: 15.08%
# Epoch [5/50], Train Loss: 3.4708, Train Acc: 29.17%, Val Loss: 2.0428, Val Acc: 24.87%
# Epoch [6/50], Train Loss: 3.3527, Train Acc: 25.93%, Val Loss: 1.9934, Val Acc: 22.86%
# Epoch [7/50], Train Loss: 3.2413, Train Acc: 32.14%, Val Loss: 1.9485, Val Acc: 14.81%
# Epoch [8/50], Train Loss: 3.1276, Train Acc: 39.29%, Val Loss: 1.9059, Val Acc: 21.48%
# Epoch [9/50], Train Loss: 3.0314, Train Acc: 48.57%, Val Loss: 1.8309, Val Acc: 19.44%
# Epoch [10/50], Train Loss: 2.9070, Train Acc: 28.57%, Val Loss: 1.7344, Val Acc: 36.27%
# Epoch [11/50], Train Loss: 2.7614, Train Acc: 38.89%, Val Loss: 1.6450, Val Acc: 40.74%
# Epoch [12/50], Train Loss: 2.5941, Train Acc: 57.14%, Val Loss: 1.4850, Val Acc: 58.33%
# Epoch [13/50], Train Loss: 2.4384, Train Acc: 66.67%, Val Loss: 1.3594, Val Acc: 55.83%
# Epoch [14/50], Train Loss: 2.3560, Train Acc: 66.67%, Val Loss: 1.2605, Val Acc: 47.22%
# Epoch [15/50], Train Loss: 2.2691, Train Acc: 56.25%, Val Loss: 1.1880, Val Acc: 51.43%
# Epoch [16/50], Train Loss: 2.1650, Train Acc: 55.10%, Val Loss: 1.1575, Val Acc: 52.08%
# Epoch [17/50], Train Loss: 2.0870, Train Acc: 64.29%, Val Loss: 1.0953, Val Acc: 44.76%
# Epoch [18/50], Train Loss: 2.0309, Train Acc: 53.12%, Val Loss: 1.0831, Val Acc: 55.95%
# Epoch [19/50], Train Loss: 1.9745, Train Acc: 50.00%, Val Loss: 1.0533, Val Acc: 41.67%
# Epoch [20/50], Train Loss: 1.9516, Train Acc: 71.43%, Val Loss: 1.1066, Val Acc: 51.25%
# Epoch [21/50], Train Loss: 1.9833, Train Acc: 62.50%, Val Loss: 1.1009, Val Acc: 40.74%
# Epoch [22/50], Train Loss: 1.8462, Train Acc: 78.57%, Val Loss: 1.0400, Val Acc: 51.67%
# Epoch [23/50], Train Loss: 1.8140, Train Acc: 54.76%, Val Loss: 1.0023, Val Acc: 50.19%
# Epoch [24/50], Train Loss: 1.8099, Train Acc: 60.42%, Val Loss: 1.0320, Val Acc: 50.93%
# Epoch [25/50], Train Loss: 1.7986, Train Acc: 64.29%, Val Loss: 0.9843, Val Acc: 42.71%
# Epoch [26/50], Train Loss: 1.7488, Train Acc: 62.50%, Val Loss: 0.9337, Val Acc: 55.56%
# Epoch [27/50], Train Loss: 1.7049, Train Acc: 57.14%, Val Loss: 0.8936, Val Acc: 60.42%
# Epoch [28/50], Train Loss: 1.6672, Train Acc: 68.75%, Val Loss: 0.9556, Val Acc: 42.59%
# Epoch [29/50], Train Loss: 1.6497, Train Acc: 75.00%, Val Loss: 0.8792, Val Acc: 59.58%
# Epoch [30/50], Train Loss: 1.6128, Train Acc: 68.75%, Val Loss: 0.9312, Val Acc: 63.54%
# Epoch [31/50], Train Loss: 1.5997, Train Acc: 85.71%, Val Loss: 0.9397, Val Acc: 48.33%
# Epoch [32/50], Train Loss: 1.5955, Train Acc: 71.43%, Val Loss: 1.0161, Val Acc: 67.50%
# Epoch [33/50], Train Loss: 1.5593, Train Acc: 77.78%, Val Loss: 1.0008, Val Acc: 65.00%
# Epoch [34/50], Train Loss: 1.5179, Train Acc: 94.44%, Val Loss: 0.8382, Val Acc: 57.78%
# Epoch [35/50], Train Loss: 1.5007, Train Acc: 69.05%, Val Loss: 0.8143, Val Acc: 51.85%
# Epoch [36/50], Train Loss: 1.4712, Train Acc: 62.50%, Val Loss: 0.8091, Val Acc: 64.81%
# Epoch [37/50], Train Loss: 1.4485, Train Acc: 80.00%, Val Loss: 0.7724, Val Acc: 79.76%
# Epoch [38/50], Train Loss: 1.4493, Train Acc: 80.95%, Val Loss: 0.8721, Val Acc: 55.36%
# Epoch [39/50], Train Loss: 1.5006, Train Acc: 66.67%, Val Loss: 0.8652, Val Acc: 61.11%
# Epoch [40/50], Train Loss: 1.4373, Train Acc: 77.78%, Val Loss: 0.8087, Val Acc: 77.08%
# Epoch [41/50], Train Loss: 1.3688, Train Acc: 100.00%, Val Loss: 0.8243, Val Acc: 65.19%
# Epoch [42/50], Train Loss: 1.3816, Train Acc: 68.57%, Val Loss: 0.9057, Val Acc: 44.07%
# Epoch [43/50], Train Loss: 1.3852, Train Acc: 71.43%, Val Loss: 0.8460, Val Acc: 81.88%
# Epoch [44/50], Train Loss: 1.3481, Train Acc: 66.67%, Val Loss: 0.7970, Val Acc: 54.44%
# Epoch [45/50], Train Loss: 1.3887, Train Acc: 50.00%, Val Loss: 0.7773, Val Acc: 69.79%
# Epoch [46/50], Train Loss: 1.3383, Train Acc: 83.33%, Val Loss: 0.7580, Val Acc: 70.60%
# Epoch [47/50], Train Loss: 1.3040, Train Acc: 62.50%, Val Loss: 0.7575, Val Acc: 78.12%
# Epoch [48/50], Train Loss: 1.2885, Train Acc: 70.83%, Val Loss: 0.8570, Val Acc: 58.15%
# Epoch [49/50], Train Loss: 1.2712, Train Acc: 82.14%, Val Loss: 0.6837, Val Acc: 68.60%
# Epoch [50/50], Train Loss: 1.3521, Train Acc: 66.67%, Val Loss: 0.7587, Val Acc: 70.56%
# F1 Score:  0.7512182314838861
# B_acc:  0.6284271284271283
# Best model has index  0
#
# Epoch [1/50], Train Loss: 4.2403, Train Acc: 14.29%, Val Loss: 2.1411, Val Acc: 11.11%
# Epoch [2/50], Train Loss: 3.9919, Train Acc: 16.67%, Val Loss: 2.1276, Val Acc: 19.44%
# Epoch [3/50], Train Loss: 3.8054, Train Acc: 15.62%, Val Loss: 2.0887, Val Acc: 9.52%
# Epoch [4/50], Train Loss: 3.6316, Train Acc: 8.33%, Val Loss: 2.0235, Val Acc: 10.65%
# Epoch [5/50], Train Loss: 3.4639, Train Acc: 21.43%, Val Loss: 1.9486, Val Acc: 9.26%
# Epoch [6/50], Train Loss: 3.2989, Train Acc: 27.22%, Val Loss: 1.8394, Val Acc: 14.44%
# Epoch [7/50], Train Loss: 3.1839, Train Acc: 55.56%, Val Loss: 1.8412, Val Acc: 31.67%
# Epoch [8/50], Train Loss: 3.0229, Train Acc: 50.00%, Val Loss: 1.7739, Val Acc: 36.57%
# Epoch [9/50], Train Loss: 2.8780, Train Acc: 44.44%, Val Loss: 1.5918, Val Acc: 32.80%
# Epoch [10/50], Train Loss: 2.6957, Train Acc: 66.67%, Val Loss: 1.5020, Val Acc: 42.06%
# Epoch [11/50], Train Loss: 2.5512, Train Acc: 62.00%, Val Loss: 1.3783, Val Acc: 31.57%
# Epoch [12/50], Train Loss: 2.4920, Train Acc: 61.11%, Val Loss: 1.3586, Val Acc: 49.85%
# Epoch [13/50], Train Loss: 2.3901, Train Acc: 38.89%, Val Loss: 1.2516, Val Acc: 47.96%
# Epoch [14/50], Train Loss: 2.2659, Train Acc: 66.67%, Val Loss: 1.2439, Val Acc: 39.58%
# Epoch [15/50], Train Loss: 2.2292, Train Acc: 52.38%, Val Loss: 1.2225, Val Acc: 42.86%
# Epoch [16/50], Train Loss: 2.1646, Train Acc: 54.76%, Val Loss: 1.2161, Val Acc: 49.15%
# Epoch [17/50], Train Loss: 2.1082, Train Acc: 66.67%, Val Loss: 1.2847, Val Acc: 36.11%
# Epoch [18/50], Train Loss: 2.0490, Train Acc: 58.33%, Val Loss: 1.1141, Val Acc: 40.62%
# Epoch [19/50], Train Loss: 2.0241, Train Acc: 36.46%, Val Loss: 1.2476, Val Acc: 42.13%
# Epoch [20/50], Train Loss: 2.0182, Train Acc: 51.85%, Val Loss: 1.2803, Val Acc: 48.89%
# Epoch [21/50], Train Loss: 1.9527, Train Acc: 61.11%, Val Loss: 1.1330, Val Acc: 39.17%
# Epoch [22/50], Train Loss: 1.8890, Train Acc: 60.42%, Val Loss: 1.1462, Val Acc: 33.33%
# Epoch [23/50], Train Loss: 1.8639, Train Acc: 71.43%, Val Loss: 1.1759, Val Acc: 33.60%
# Epoch [24/50], Train Loss: 1.8045, Train Acc: 57.14%, Val Loss: 1.1438, Val Acc: 58.93%
# Epoch [25/50], Train Loss: 1.7685, Train Acc: 57.29%, Val Loss: 1.0848, Val Acc: 51.54%
# Epoch [26/50], Train Loss: 1.7656, Train Acc: 50.00%, Val Loss: 1.0980, Val Acc: 60.19%
# Epoch [27/50], Train Loss: 1.7289, Train Acc: 50.00%, Val Loss: 1.0124, Val Acc: 50.56%
# Epoch [28/50], Train Loss: 1.6593, Train Acc: 66.67%, Val Loss: 1.0143, Val Acc: 53.33%
# Epoch [29/50], Train Loss: 1.6771, Train Acc: 64.29%, Val Loss: 1.0184, Val Acc: 52.04%
# Epoch [30/50], Train Loss: 1.6426, Train Acc: 47.14%, Val Loss: 1.0926, Val Acc: 51.04%
# Epoch [31/50], Train Loss: 1.6154, Train Acc: 57.14%, Val Loss: 1.2391, Val Acc: 53.89%
# Epoch [32/50], Train Loss: 1.6063, Train Acc: 52.38%, Val Loss: 1.0979, Val Acc: 56.25%
# Epoch [33/50], Train Loss: 1.5885, Train Acc: 62.50%, Val Loss: 1.6742, Val Acc: 43.54%
# Epoch [34/50], Train Loss: 1.6065, Train Acc: 70.83%, Val Loss: 1.3172, Val Acc: 45.93%
# Epoch [35/50], Train Loss: 1.5738, Train Acc: 85.71%, Val Loss: 1.1621, Val Acc: 51.56%
# Epoch [36/50], Train Loss: 1.5202, Train Acc: 58.33%, Val Loss: 1.0145, Val Acc: 62.38%
# Epoch [37/50], Train Loss: 1.4814, Train Acc: 88.33%, Val Loss: 1.0335, Val Acc: 62.22%
# Epoch [38/50], Train Loss: 1.4522, Train Acc: 50.00%, Val Loss: 1.0594, Val Acc: 55.56%
# Epoch [39/50], Train Loss: 1.4843, Train Acc: 71.43%, Val Loss: 1.5144, Val Acc: 43.84%
# Epoch [40/50], Train Loss: 1.4921, Train Acc: 67.86%, Val Loss: 1.0813, Val Acc: 56.11%
# Epoch [41/50], Train Loss: 1.4620, Train Acc: 62.50%, Val Loss: 1.0365, Val Acc: 71.43%
# Epoch [42/50], Train Loss: 1.4885, Train Acc: 66.67%, Val Loss: 1.0202, Val Acc: 49.26%
# Epoch [43/50], Train Loss: 1.4008, Train Acc: 62.50%, Val Loss: 1.0756, Val Acc: 58.15%
# Epoch [44/50], Train Loss: 1.3808, Train Acc: 76.00%, Val Loss: 1.1975, Val Acc: 64.43%
# Epoch [45/50], Train Loss: 1.3590, Train Acc: 87.50%, Val Loss: 1.0068, Val Acc: 50.31%
# Epoch [46/50], Train Loss: 1.3839, Train Acc: 87.50%, Val Loss: 1.0403, Val Acc: 60.08%
# Epoch [47/50], Train Loss: 1.4638, Train Acc: 68.75%, Val Loss: 1.6034, Val Acc: 51.85%
# Epoch [48/50], Train Loss: 1.4029, Train Acc: 100.00%, Val Loss: 1.2338, Val Acc: 66.46%
# Epoch [49/50], Train Loss: 1.3788, Train Acc: 77.78%, Val Loss: 1.0961, Val Acc: 73.30%
# Epoch [50/50], Train Loss: 1.3510, Train Acc: 67.86%, Val Loss: 0.9949, Val Acc: 55.09%
# F1 Score:  0.6088325652841782
# B_acc:  0.5761201761201762
# Best model has index  0

# %% [markdown]
# ## LOAD TEST FOLDER

# %%
import re
from torch.utils.data import Dataset

class TestDataset(Dataset):
    def get_int(self, text):
        return [int(c) if c.isdigit() else c for c in re.split('(\d+)', text)]

    def __init__(self, images_folder, transform=None):
        self.images_folder = images_folder
        self.image_files = [f for f in os.listdir(images_folder) if os.path.isfile(os.path.join(images_folder, f))]
        self.image_files.sort(key=self.get_int)
        self.transform = transform

    def __len__(self):
        return len(self.image_files)

    def __getitem__(self, idx):
        img_name = os.path.join(self.images_folder, self.image_files[idx])
        image = Image.open(img_name).convert('RGB')
        if self.transform:
            image = self.transform(image)
        return image
    
    
'''
#run if we want to use new test folder every time we use csv

transform_test_set = transforms.Compose([removeBackground,input_transform])

inference_dataset = TestDataset(images_folder=test_dataset_path, transform=transform_test_set)

test_dataset_loader = DataLoader(inference_dataset, batch_size=1, shuffle=False)
'''

#IF YOU WANT TO TAKE IMAGES FROM THE TEST FLDER WITH NO BG

test_nobg_path = 'data-students/TEST-NOBG'

inference_dataset = TestDataset(images_folder=test_nobg_path, transform=input_transform)

test_dataset_loader = DataLoader(inference_dataset, batch_size=1, shuffle=False)

# %% [markdown]
# # PREDICT AND CREATE CSV FILE FOR THE RESULTS

# %%
directory = "/home/stefanotrenti/AML/project/CSVs"

createCSV(best_model_v4, test_dataset_loader,[],"PREDICTIONS_best_model_v4.csv", directory)
# Out:
# CSV file created successfully.
